# %% [markdown]
# # **Etapa 4: Armazenamento Final dos Dados Preparados**
# Objetivo da Etapa: Finalizar o processamento dos arquivos textuais extraídos e limpos, organizando-os de forma sistemática e verificando a qualidade do resultado. Esta etapa garante que o corpus final do projeto IAVS esteja estruturado, nomeado corretamente e com conteúdo confiável para uso posterior em modelagem e análise.

# %%
#instalando biblioteca e carregando pacotes 
# %pip install language-tool-python
import os
import re
import csv
import difflib
import random
from pathlib import Path
import time
import language_tool_python
import subprocess
import unicodedata
import shutil
# Out:
# Requirement already satisfied: language-tool-python in c:\users\isisi\anaconda3\lib\site-packages (2.9.4)
# Requirement already satisfied: requests in c:\users\isisi\anaconda3\lib\site-packages (from language-tool-python) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\isisi\anaconda3\lib\site-packages (from language-tool-python) (4.67.1)
# Requirement already satisfied: psutil in c:\users\isisi\anaconda3\lib\site-packages (from language-tool-python) (5.9.0)
# Requirement already satisfied: toml in c:\users\isisi\anaconda3\lib\site-packages (from language-tool-python) (0.10.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\isisi\anaconda3\lib\site-packages (from requests->language-tool-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\isisi\anaconda3\lib\site-packages (from requests->language-tool-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\isisi\anaconda3\lib\site-packages (from requests->language-tool-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\isisi\anaconda3\lib\site-packages (from requests->language-tool-python) (2025.7.14)
# Requirement already satisfied: colorama in c:\users\isisi\anaconda3\lib\site-packages (from tqdm->language-tool-python) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Organização, Verificação e Amostragem dos Textos Limpos
#
# Este script realiza as etapas finais do processamento dos arquivos textuais utilizados no projeto IAVS, a partir da pasta textos_limpos. Ele executa três ações principais: organização por doença/tema, verificação da padronização dos nomes dos arquivos, e revisão amostral do conteúdo.
#
# - **Etapa 4.1 – Organização dos Arquivos**
# Os arquivos .txt são lidos da pasta textos_limpos. Com base no prefixo de seus nomes (antes do primeiro sublinhado), é inferido o tema ou a doença. O script então cria subpastas com esse nome dentro da pasta corpus_final e copia os arquivos para seus respectivos destinos. Isso garante que o corpus final esteja organizado de forma lógica e temática, o que facilita a navegação, o versionamento e o uso posterior em análises.
#
#  - **Etapa 4.2 – Verificação da Estrutura**
# Após a cópia, o script verifica se as subpastas foram devidamente criadas na pasta corpus_final. Se não houver nenhuma subpasta, um alerta é exibido. Caso existam, seus nomes são listados como confirmação da estrutura.
#
# - **Etapa 4.3 – Verificação de Nomenclatura e Conteúdo**
# Duas verificações adicionais são realizadas:
#
# - **Padrão de nomes dos arquivos:**
# O script utiliza uma expressão regular para verificar se os nomes seguem o formato:
# doenca_tipo_origem2023.txt, com letras minúsculas, underscores como separadores e ano com quatro dígitos ao final.
# Arquivos fora do padrão são listados com alerta.
#
# - **Amostragem de conteúdo:**
# Três subpastas são selecionadas aleatoriamente. Em cada uma, um arquivo é escolhido ao acaso e os primeiros 800 caracteres do seu conteúdo são exibidos. Essa leitura rápida serve como revisão qualitativa para identificar possíveis erros de extração ou formatação residual.

# %%
# ======================== CONFIGURAÇÃO DOS CAMINHOS ======================== #
PASTA_LIMPOS = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_limpos"
PASTA_FINAL = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"

# Cria a pasta de destino final se ainda não existir
os.makedirs(PASTA_FINAL, exist_ok=True)

# ======================== ETAPA 4.1 – ORGANIZAÇÃO ======================== #
print("\n Iniciando organização dos arquivos...\n")

# Percorre todos os arquivos da pasta de textos limpos
for arquivo in os.listdir(PASTA_LIMPOS):
    if arquivo.endswith(".txt") and "_" in arquivo:
        # Extrai o nome da doença ou tema (prefixo antes do primeiro "_")
        doenca = arquivo.split("_")[0].lower()
        
        # Cria a subpasta correspondente à doença, se não existir
        destino_pasta = os.path.join(PASTA_FINAL, doenca)
        os.makedirs(destino_pasta, exist_ok=True)

        # Define caminhos de origem e destino
        origem_arquivo = os.path.join(PASTA_LIMPOS, arquivo)
        destino_arquivo = os.path.join(destino_pasta, arquivo)

        # Copia o arquivo para a subpasta correta
        shutil.copy2(origem_arquivo, destino_arquivo)
        print(f"✅ Copiado: {arquivo} → {doenca}/")

print("\n Organização concluída.\n")

# ======================== ETAPA 4.2 e 4.3 – VERIFICAÇÃO ======================== #

# Verificação 1: lista as subpastas criadas
print(" Subpastas encontradas em corpus_final:")
subpastas = [nome for nome in os.listdir(PASTA_FINAL) if os.path.isdir(os.path.join(PASTA_FINAL, nome))]
if not subpastas:
    print("⚠️ Nenhuma subpasta encontrada. A organização não foi realizada corretamente.")
else:
    for sub in subpastas:
        print(f"  ✅ {sub}")

# Verificação 2: checagem do padrão de nomes dos arquivos
print("\n Verificando padrão de nomes dos arquivos...")
padrao_nome = re.compile(r"^[a-z0-9]+_[a-z0-9]+_[a-z0-9]+[0-9]{4}\.txt$")
erros_nome = []

# Percorre cada subpasta para validar os nomes dos arquivos
for sub in subpastas:
    caminho_sub = os.path.join(PASTA_FINAL, sub)
    for arquivo in os.listdir(caminho_sub):
        if not padrao_nome.match(arquivo):
            erros_nome.append((sub, arquivo))

# Lista os arquivos que não seguem o padrão
if erros_nome:
    print("\n Arquivos com nome fora do padrão:")
    for sub, nome in erros_nome:
        print(f"  ❌ {nome} (subpasta: {sub})")
else:
    print("✅ Todos os arquivos seguem o padrão de nomenclatura.")

# Verificação 3: leitura amostral de conteúdo para revisão manual
print("\n Amostras de conteúdo para revisão:")

# Seleciona aleatoriamente até 3 subpastas
for sub in random.sample(subpastas, min(3, len(subpastas))):
    caminho_sub = os.path.join(PASTA_FINAL, sub)
    arquivos_txt = [f for f in os.listdir(caminho_sub) if f.endswith(".txt")]
    
    if arquivos_txt:
        # Escolhe aleatoriamente um arquivo para exibição
        amostra = random.choice(arquivos_txt)
        caminho_arquivo = os.path.join(caminho_sub, amostra)
        
        print(f"\n Arquivo: {amostra} (em {sub})")
        with open(caminho_arquivo, 'r', encoding='utf-8', errors='ignore') as f:
            conteudo = f.read()
            print(conteudo[:800])  # Exibe os primeiros 800 caracteres para revisão
# Out:
#  Iniciando organização dos arquivos...
#
# ✅ Copiado: adenovírus_guia_1.txt → adenovírus/
# ✅ Copiado: arboviroses_nota_técnica_1.txt → arboviroses/
# ✅ Copiado: cancro_mole_protocolo_1.txt → cancro/
# ✅ Copiado: chikungunya_nota_técnica_1.txt → chikungunya/
# ✅ Copiado: chikungunya_protocolo_1.txt → chikungunya/
# ✅ Copiado: chikungunya_protocolo_2.txt → chikungunya/
# ✅ Copiado: chikungunya_protocolo_3.txt → chikungunya/
# ✅ Copiado: clamídia_protocolo_1.txt → clamídia/
# ✅ Copiado: coinfecção_com_hepatite_b_nota_técnica_1.txt → coinfecção/
# ✅ Copiado: coqueluche_nota_técnica_1.txt → coqueluche/
# ✅ Copiado: coqueluche_nota_técnica_2.txt → coqueluche/
# ✅ Copiado: coqueluche_nota_técnica_3.txt → coqueluche/
# ✅ Copiado: covid-19_guia_1.txt → covid-19/
# ✅ Copiado: covid-19_nota_técnica_1.txt → covid-19/
# ✅ Copiado: cólera_nota_técnica_1.txt → cólera/
# ✅ Copiado: cólera_protocolo_1.txt → cólera/
# ✅ Copiado: dengue_nota_técnica_1.txt → dengue/
# ✅ Copiado: dengue_protocolo_1.txt → dengue/
# ✅ Copiado: dengue_protocolo_2.txt → dengue/
# ✅ Copiado: dengue_protocolo_3.txt → dengue/
# ✅ Copiado: dengue_protocolo_4.txt → dengue/
# ✅ Copiado: difteria_nota_técnica_1.txt → difteria/
# ✅ Copiado: entre_outras_doenças_imunopreveníveis_nota_técnica_1.txt → entre/
# ✅ Copiado: entre_outras_protocolo_1.txt → entre/
# ✅ Copiado: entre_outras_protocolo_2.txt → entre/
# ✅ Copiado: febre_amarela_nota_técnica_1.txt → febre/
# ✅ Copiado: febre_amarela_protocolo_1.txt → febre/
# ✅ Copiado: febre_amarela_protocolo_2.txt → febre/
# ✅ Copiado: febre_amarela_protocolo_3.txt → febre/
# ✅ Copiado: febre_do_nilo_ocidental_nota_técnica_1.txt → febre/
# ✅ Copiado: gonorreia_protocolo_1.txt → gonorreia/
# ✅ Copiado: hanseníase_diretriz_nacional_1.txt → hanseníase/
# ✅ Copiado: hanseníase_nota_técnica_1.txt → hanseníase/
# ✅ Copiado: hanseníase_nota_técnica_2.txt → hanseníase/
# ✅ Copiado: hanseníase_protocolo_1.txt → hanseníase/
# ✅ Copiado: hanseníase_protocolo_2.txt → hanseníase/
# ✅ Copiado: hanseníase_protocolo_3.txt → hanseníase/
# ✅ Copiado: hantavirose_manual_1.txt → hantavirose/
# ✅ Copiado: hantavirose_manual_2.txt → hantavirose/
# ✅ Copiado: hepatites_nota_técnica_1.txt → hepatites/
# ✅ Copiado: hepatites_protocolo_1.txt → hepatites/
# ✅ Copiado: hepatite_a_nota_técnica_1.txt → hepatite/
# ✅ Copiado: hepatite_a_nota_técnica_2.txt → hepatite/
# ✅ Copiado: hepatite_a_protocolo_1.txt → hepatite/
# ✅ Copiado: hepatite_b_e_c_(ist)_protocolo_1.txt → hepatite/
# ✅ Copiado: hepatite_b_protocolo_1.txt → hepatite/
# ✅ Copiado: hepatite_c_protocolo_1.txt → hepatite/
# ✅ Copiado: hepatite_d_(delta)_nota_técnica_1.txt → hepatite/
# ✅ Copiado: hepatite_d_protocolo_1.txt → hepatite/
# ✅ Copiado: hepatite_e_protocolo_1.txt → hepatite/
# ✅ Copiado: herpes_genital_protocolo_1.txt → herpes/
# ✅ Copiado: hiv_nota_técnica_1.txt → hiv/
# ✅ Copiado: hpv_nota_técnica_1.txt → hpv/
# ✅ Copiado: hpv_protocolo_1.txt → hpv/
# ✅ Copiado: influenza_guia_1.txt → influenza/
# ✅ Copiado: influenza_guia_2.txt → influenza/
# ✅ Copiado: leishmaniose_manual_1.txt → leishmaniose/
# ✅ Copiado: leptospirose_manual_1.txt → leptospirose/
# ✅ Copiado: leptospirose_nota_técnica_1.txt → leptospirose/
# ✅ Copiado: leptospirose_nota_técnica_2.txt → leptospirose/
# ✅ Copiado: leptospirose_nota_técnica_3.txt → leptospirose/
# ✅ Copiado: leptospirose_protocolo_1.txt → leptospirose/
# ✅ Copiado: linfogranuloma_venéreo_protocolo_1.txt → linfogranuloma/
# ✅ Copiado: m._abscessus_protocolo_1.txt → m./
# ✅ Copiado: m._kansasii_protocolo_1.txt → m./
# ✅ Copiado: malária_manual_1.txt → malária/
# ✅ Copiado: malária_protocolo_1.txt → malária/
# ✅ Copiado: meningite_nota_técnica_1.txt → meningite/
# ✅ Copiado: metapneumovírus_guia_1.txt → metapneumovírus/
# ✅ Copiado: micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.txt → micobactérias/
# ✅ Copiado: outras_zoonoses_transmitidas_por_roedores_manual_1.txt → outras/
# ✅ Copiado: parainfluenza_guia_1.txt → parainfluenza/
# ✅ Copiado: peste_manual_1.txt → peste/
# ✅ Copiado: peste_manual_2.txt → peste/
# ✅ Copiado: poliomielite_nota_técnica_1.txt → poliomielite/
# ✅ Copiado: poliomielite_nota_técnica_2.txt → poliomielite/
# ✅ Copiado: poliomielite_nota_técnica_3.txt → poliomielite/
# ✅ Copiado: poliomielite_protocolo_1.txt → poliomielite/
# ✅ Copiado: raiva_humana_protocolo_1.txt → raiva/
# ✅ Copiado: raiva_humana_protocolo_2.txt → raiva/
# ✅ Copiado: rinovírus_e_outros_respiratórios_guia_1.txt → rinovírus/
# ✅ Copiado: rubéola_manual_1.txt → rubéola/
# ✅ Copiado: rubéola_nota_técnica_1.txt → rubéola/
# ✅ Copiado: rubéola_nota_técnica_2.txt → rubéola/
# ✅ Copiado: rubéola_nota_técnica_3.txt → rubéola/
# ✅ Copiado: rubéola_protocolo_1.txt → rubéola/
# ✅ Copiado: sarampo_manual_1.txt → sarampo/
# ✅ Copiado: sarampo_nota_técnica_1.txt → sarampo/
# ✅ Copiado: sarampo_nota_técnica_2.txt → sarampo/
# ✅ Copiado: sarampo_protocolo_1.txt → sarampo/
# ✅ Copiado: sarampo_protocolo_2.txt → sarampo/
# ✅ Copiado: sífilis_manual_1.txt → sífilis/
# ✅ Copiado: sífilis_protocolo_1.txt → sífilis/
# ✅ Copiado: síndrome_da_rubéola_congênita_(src)_manual_1.txt → síndrome/
# ✅ Copiado: síndrome_da_rubéola_congênita_(src)_nota_técnica_1.txt → síndrome/
# ✅ Copiado: síndrome_da_rubéola_congênita_(src)_nota_técnica_2.txt → síndrome/
# ✅ Copiado: tuberculose_protocolo_1.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_10.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_11.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_12.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_13.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_14.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_15.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_2.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_3.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_4.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_5.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_6.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_7.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_8.txt → tuberculose/
# ✅ Copiado: tuberculose_protocolo_9.txt → tuberculose/
# ✅ Copiado: tétano_nota_técnica_1.txt → tétano/
# ✅ Copiado: varicela_nota_técnica_1.txt → varicela/
# ✅ Copiado: vírus_sincicial_respiratório_(vsr)_guia_1.txt → vírus/
# ✅ Copiado: zika_nota_técnica_1.txt → zika/
# ✅ Copiado: zika_protocolo_1.txt → zika/
# ✅ Copiado: zika_protocolo_2.txt → zika/
# ✅ Copiado: zika_protocolo_3.txt → zika/
# ✅ Copiado: zoonoses_manual_1.txt → zoonoses/
#
#  Organização concluída.
#
#  Subpastas encontradas em corpus_final:
#   ✅ adenovírus
#   ✅ arboviroses
#   ✅ cancro
#   ✅ chikungunya
#   ✅ clamídia
#   ✅ coinfecção
#   ✅ coqueluche
#   ✅ covid-19
#   ✅ cólera
#   ✅ dengue
#   ✅ difteria
#   ✅ entre
#   ✅ febre
#   ✅ gonorreia
#   ✅ hanseníase
#   ✅ hantavirose
#   ✅ hepatite
#   ✅ hepatites
#   ✅ herpes
#   ✅ hiv
#   ✅ hpv
#   ✅ influenza
#   ✅ leishmaniose
#   ✅ leptospirose
#   ✅ linfogranuloma
#   ✅ m
#   ✅ malária
#   ✅ meningite
#   ✅ metapneumovírus
#   ✅ micobactérias
#   ✅ outras
#   ✅ parainfluenza
#   ✅ peste
#   ✅ poliomielite
#   ✅ raiva
#   ✅ rinovírus
#   ✅ rubéola
#   ✅ sarampo
#   ✅ sífilis
#   ✅ síndrome
#   ✅ tuberculose
#   ✅ tétano
#   ✅ varicela
#   ✅ vírus
#   ✅ zika
#   ✅ zoonoses
#
#  Verificando padrão de nomes dos arquivos...
#
#  Arquivos com nome fora do padrão:
#   ❌ adenovirus_guia_1txt_guiavsa2023.txt (subpasta: adenovírus)
#   ❌ adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023.txt (subpasta: adenovírus)
#   ❌ adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: adenovírus)
#   ❌ adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: adenovírus)
#   ❌ adenovírus_guia_1.txt (subpasta: adenovírus)
#   ❌ arboviroses_nota_tecnica_1txt_notatecnica2023.txt (subpasta: arboviroses)
#   ❌ arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt (subpasta: arboviroses)
#   ❌ arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: arboviroses)
#   ❌ arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: arboviroses)
#   ❌ arboviroses_nota_técnica_1.txt (subpasta: arboviroses)
#   ❌ cancro_mole_protocolo_1.txt (subpasta: cancro)
#   ❌ cancro_mole_protocolo_1txt_protocolo2023.txt (subpasta: cancro)
#   ❌ chikungunya_nota_tecnica_1txt_notatecnica2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_nota_técnica_1.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_1.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_1txt_protocolo2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_2.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_2txt_protocolo2023.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_3.txt (subpasta: chikungunya)
#   ❌ chikungunya_protocolo_3txt_protocolo2023.txt (subpasta: chikungunya)
#   ❌ clamidia_protocolo_1txt_protocolo2023.txt (subpasta: clamídia)
#   ❌ clamídia_protocolo_1.txt (subpasta: clamídia)
#   ❌ coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023.txt (subpasta: coinfecção)
#   ❌ coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coinfecção)
#   ❌ coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coinfecção)
#   ❌ coinfecção_com_hepatite_b_nota_técnica_1.txt (subpasta: coinfecção)
#   ❌ coqueluche_nota_tecnica_1txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_2txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_3txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_técnica_1.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_técnica_2.txt (subpasta: coqueluche)
#   ❌ coqueluche_nota_técnica_3.txt (subpasta: coqueluche)
#   ❌ covid-19_guia_1.txt (subpasta: covid-19)
#   ❌ covid-19_nota_técnica_1.txt (subpasta: covid-19)
#   ❌ covid_19_guia_1txt_guiavsa2023.txt (subpasta: covid-19)
#   ❌ covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: covid-19)
#   ❌ covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: covid-19)
#   ❌ covid_19_nota_tecnica_1txt_notatecnica2023.txt (subpasta: covid-19)
#   ❌ covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: covid-19)
#   ❌ covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: covid-19)
#   ❌ colera_nota_tecnica_1txt_notatecnica2023.txt (subpasta: cólera)
#   ❌ colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: cólera)
#   ❌ colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: cólera)
#   ❌ colera_protocolo_1txt_protocolo2023.txt (subpasta: cólera)
#   ❌ colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: cólera)
#   ❌ colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: cólera)
#   ❌ cólera_nota_técnica_1.txt (subpasta: cólera)
#   ❌ cólera_protocolo_1.txt (subpasta: cólera)
#   ❌ dengue_nota_tecnica_1txt_notatecnica2023.txt (subpasta: dengue)
#   ❌ dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: dengue)
#   ❌ dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: dengue)
#   ❌ dengue_nota_técnica_1.txt (subpasta: dengue)
#   ❌ dengue_protocolo_1.txt (subpasta: dengue)
#   ❌ dengue_protocolo_1txt_protocolo2023.txt (subpasta: dengue)
#   ❌ dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: dengue)
#   ❌ dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: dengue)
#   ❌ dengue_protocolo_2.txt (subpasta: dengue)
#   ❌ dengue_protocolo_2txt_protocolo2023.txt (subpasta: dengue)
#   ❌ dengue_protocolo_3.txt (subpasta: dengue)
#   ❌ dengue_protocolo_3txt_protocolo2023.txt (subpasta: dengue)
#   ❌ dengue_protocolo_4.txt (subpasta: dengue)
#   ❌ dengue_protocolo_4txt_protocolo2023.txt (subpasta: dengue)
#   ❌ difteria_nota_tecnica_1txt_notatecnica2023.txt (subpasta: difteria)
#   ❌ difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: difteria)
#   ❌ difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: difteria)
#   ❌ difteria_nota_técnica_1.txt (subpasta: difteria)
#   ❌ entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023.txt (subpasta: entre)
#   ❌ entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: entre)
#   ❌ entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: entre)
#   ❌ entre_outras_doenças_imunopreveníveis_nota_técnica_1.txt (subpasta: entre)
#   ❌ entre_outras_protocolo_1.txt (subpasta: entre)
#   ❌ entre_outras_protocolo_1txt_protocolo2023.txt (subpasta: entre)
#   ❌ entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: entre)
#   ❌ entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: entre)
#   ❌ entre_outras_protocolo_2.txt (subpasta: entre)
#   ❌ entre_outras_protocolo_2txt_protocolo2023.txt (subpasta: entre)
#   ❌ febre_amarela_nota_tecnica_1txt_notatecnica2023.txt (subpasta: febre)
#   ❌ febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: febre)
#   ❌ febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: febre)
#   ❌ febre_amarela_nota_técnica_1.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_1.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_1txt_protocolo2023.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_2.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_2txt_protocolo2023.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_3.txt (subpasta: febre)
#   ❌ febre_amarela_protocolo_3txt_protocolo2023.txt (subpasta: febre)
#   ❌ febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023.txt (subpasta: febre)
#   ❌ febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: febre)
#   ❌ febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: febre)
#   ❌ febre_do_nilo_ocidental_nota_técnica_1.txt (subpasta: febre)
#   ❌ gonorreia_protocolo_1.txt (subpasta: gonorreia)
#   ❌ gonorreia_protocolo_1txt_protocolo2023.txt (subpasta: gonorreia)
#   ❌ hanseniase_diretriz_nacional_1txt_documento2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_nota_tecnica_1txt_notatecnica2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_nota_tecnica_2txt_notatecnica2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_protocolo_1txt_protocolo2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_protocolo_2txt_protocolo2023.txt (subpasta: hanseníase)
#   ❌ hanseniase_protocolo_3txt_protocolo2023.txt (subpasta: hanseníase)
#   ❌ hanseníase_diretriz_nacional_1.txt (subpasta: hanseníase)
#   ❌ hanseníase_nota_técnica_1.txt (subpasta: hanseníase)
#   ❌ hanseníase_nota_técnica_2.txt (subpasta: hanseníase)
#   ❌ hanseníase_protocolo_1.txt (subpasta: hanseníase)
#   ❌ hanseníase_protocolo_2.txt (subpasta: hanseníase)
#   ❌ hanseníase_protocolo_3.txt (subpasta: hanseníase)
#   ❌ hantavirose_manual_1.txt (subpasta: hantavirose)
#   ❌ hantavirose_manual_1txt_manual2023.txt (subpasta: hantavirose)
#   ❌ hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: hantavirose)
#   ❌ hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: hantavirose)
#   ❌ hantavirose_manual_2.txt (subpasta: hantavirose)
#   ❌ hantavirose_manual_2txt_manual2023.txt (subpasta: hantavirose)
#   ❌ hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: hantavirose)
#   ❌ hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: hantavirose)
#   ❌ hepatite_a_nota_tecnica_1txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_nota_tecnica_2txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_nota_técnica_1.txt (subpasta: hepatite)
#   ❌ hepatite_a_nota_técnica_2.txt (subpasta: hepatite)
#   ❌ hepatite_a_protocolo_1.txt (subpasta: hepatite)
#   ❌ hepatite_a_protocolo_1txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_b_e_c_(ist)_protocolo_1.txt (subpasta: hepatite)
#   ❌ hepatite_b_e_c_ist_protocolo_1txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_b_protocolo_1.txt (subpasta: hepatite)
#   ❌ hepatite_b_protocolo_1txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_c_protocolo_1.txt (subpasta: hepatite)
#   ❌ hepatite_c_protocolo_1txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_d_(delta)_nota_técnica_1.txt (subpasta: hepatite)
#   ❌ hepatite_d_delta_nota_tecnica_1txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatite)
#   ❌ hepatite_d_protocolo_1.txt (subpasta: hepatite)
#   ❌ hepatite_d_protocolo_1txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_e_protocolo_1.txt (subpasta: hepatite)
#   ❌ hepatite_e_protocolo_1txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatite)
#   ❌ hepatites_nota_tecnica_1txt_notatecnica2023.txt (subpasta: hepatites)
#   ❌ hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatites)
#   ❌ hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hepatites)
#   ❌ hepatites_nota_técnica_1.txt (subpasta: hepatites)
#   ❌ hepatites_protocolo_1.txt (subpasta: hepatites)
#   ❌ hepatites_protocolo_1txt_protocolo2023.txt (subpasta: hepatites)
#   ❌ hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatites)
#   ❌ hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: hepatites)
#   ❌ herpes_genital_protocolo_1.txt (subpasta: herpes)
#   ❌ herpes_genital_protocolo_1txt_protocolo2023.txt (subpasta: herpes)
#   ❌ hiv_nota_tecnica_1txt_notatecnica2023.txt (subpasta: hiv)
#   ❌ hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hiv)
#   ❌ hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hiv)
#   ❌ hiv_nota_técnica_1.txt (subpasta: hiv)
#   ❌ hpv_nota_tecnica_1txt_notatecnica2023.txt (subpasta: hpv)
#   ❌ hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hpv)
#   ❌ hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: hpv)
#   ❌ hpv_nota_técnica_1.txt (subpasta: hpv)
#   ❌ hpv_protocolo_1.txt (subpasta: hpv)
#   ❌ hpv_protocolo_1txt_protocolo2023.txt (subpasta: hpv)
#   ❌ influenza_guia_1.txt (subpasta: influenza)
#   ❌ influenza_guia_1txt_guiavsa2023.txt (subpasta: influenza)
#   ❌ influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: influenza)
#   ❌ influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: influenza)
#   ❌ influenza_guia_2.txt (subpasta: influenza)
#   ❌ influenza_guia_2txt_guiavsa2023.txt (subpasta: influenza)
#   ❌ influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: influenza)
#   ❌ influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: influenza)
#   ❌ leishmaniose_manual_1.txt (subpasta: leishmaniose)
#   ❌ leishmaniose_manual_1txt_manual2023.txt (subpasta: leishmaniose)
#   ❌ leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: leishmaniose)
#   ❌ leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: leishmaniose)
#   ❌ leptospirose_manual_1.txt (subpasta: leptospirose)
#   ❌ leptospirose_manual_1txt_manual2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_1txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_2txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_3txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_técnica_1.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_técnica_2.txt (subpasta: leptospirose)
#   ❌ leptospirose_nota_técnica_3.txt (subpasta: leptospirose)
#   ❌ leptospirose_protocolo_1.txt (subpasta: leptospirose)
#   ❌ leptospirose_protocolo_1txt_protocolo2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: leptospirose)
#   ❌ leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: leptospirose)
#   ❌ linfogranuloma_venereo_protocolo_1txt_protocolo2023.txt (subpasta: linfogranuloma)
#   ❌ linfogranuloma_venéreo_protocolo_1.txt (subpasta: linfogranuloma)
#   ❌ m._abscessus_protocolo_1.txt (subpasta: m)
#   ❌ m._kansasii_protocolo_1.txt (subpasta: m)
#   ❌ m_abscessus_protocolo_1txt_protocolo2023.txt (subpasta: m)
#   ❌ m_kansasii_protocolo_1txt_protocolo2023.txt (subpasta: m)
#   ❌ malaria_manual_1txt_manual2023.txt (subpasta: malária)
#   ❌ malaria_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: malária)
#   ❌ malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: malária)
#   ❌ malaria_protocolo_1txt_protocolo2023.txt (subpasta: malária)
#   ❌ malária_manual_1.txt (subpasta: malária)
#   ❌ malária_protocolo_1.txt (subpasta: malária)
#   ❌ meningite_nota_tecnica_1txt_notatecnica2023.txt (subpasta: meningite)
#   ❌ meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: meningite)
#   ❌ meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: meningite)
#   ❌ meningite_nota_técnica_1.txt (subpasta: meningite)
#   ❌ metapneumovirus_guia_1txt_guiavsa2023.txt (subpasta: metapneumovírus)
#   ❌ metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: metapneumovírus)
#   ❌ metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: metapneumovírus)
#   ❌ metapneumovírus_guia_1.txt (subpasta: metapneumovírus)
#   ❌ micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023.txt (subpasta: micobactérias)
#   ❌ micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.txt (subpasta: micobactérias)
#   ❌ outras_zoonoses_transmitidas_por_roedores_manual_1.txt (subpasta: outras)
#   ❌ outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023.txt (subpasta: outras)
#   ❌ outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: outras)
#   ❌ outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: outras)
#   ❌ parainfluenza_guia_1.txt (subpasta: parainfluenza)
#   ❌ parainfluenza_guia_1txt_guiavsa2023.txt (subpasta: parainfluenza)
#   ❌ parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: parainfluenza)
#   ❌ parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: parainfluenza)
#   ❌ peste_manual_1.txt (subpasta: peste)
#   ❌ peste_manual_1txt_manual2023.txt (subpasta: peste)
#   ❌ peste_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: peste)
#   ❌ peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: peste)
#   ❌ peste_manual_2.txt (subpasta: peste)
#   ❌ peste_manual_2txt_manual2023.txt (subpasta: peste)
#   ❌ peste_manual_2txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: peste)
#   ❌ peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: peste)
#   ❌ poliomielite_nota_tecnica_1txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_2txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_3txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_técnica_1.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_técnica_2.txt (subpasta: poliomielite)
#   ❌ poliomielite_nota_técnica_3.txt (subpasta: poliomielite)
#   ❌ poliomielite_protocolo_1.txt (subpasta: poliomielite)
#   ❌ poliomielite_protocolo_1txt_protocolo2023.txt (subpasta: poliomielite)
#   ❌ raiva_humana_protocolo_1.txt (subpasta: raiva)
#   ❌ raiva_humana_protocolo_1txt_protocolo2023.txt (subpasta: raiva)
#   ❌ raiva_humana_protocolo_2.txt (subpasta: raiva)
#   ❌ raiva_humana_protocolo_2txt_protocolo2023.txt (subpasta: raiva)
#   ❌ rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023.txt (subpasta: rinovírus)
#   ❌ rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: rinovírus)
#   ❌ rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: rinovírus)
#   ❌ rinovírus_e_outros_respiratórios_guia_1.txt (subpasta: rinovírus)
#   ❌ rubeola_manual_1txt_manual2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_1txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_2txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_3txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: rubéola)
#   ❌ rubeola_protocolo_1txt_protocolo2023.txt (subpasta: rubéola)
#   ❌ rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: rubéola)
#   ❌ rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: rubéola)
#   ❌ rubéola_manual_1.txt (subpasta: rubéola)
#   ❌ rubéola_nota_técnica_1.txt (subpasta: rubéola)
#   ❌ rubéola_nota_técnica_2.txt (subpasta: rubéola)
#   ❌ rubéola_nota_técnica_3.txt (subpasta: rubéola)
#   ❌ rubéola_protocolo_1.txt (subpasta: rubéola)
#   ❌ sarampo_manual_1.txt (subpasta: sarampo)
#   ❌ sarampo_manual_1txt_manual2023.txt (subpasta: sarampo)
#   ❌ sarampo_nota_tecnica_1txt_notatecnica2023.txt (subpasta: sarampo)
#   ❌ sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: sarampo)
#   ❌ sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: sarampo)
#   ❌ sarampo_nota_tecnica_2txt_notatecnica2023.txt (subpasta: sarampo)
#   ❌ sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: sarampo)
#   ❌ sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: sarampo)
#   ❌ sarampo_nota_técnica_1.txt (subpasta: sarampo)
#   ❌ sarampo_nota_técnica_2.txt (subpasta: sarampo)
#   ❌ sarampo_protocolo_1.txt (subpasta: sarampo)
#   ❌ sarampo_protocolo_1txt_protocolo2023.txt (subpasta: sarampo)
#   ❌ sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: sarampo)
#   ❌ sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: sarampo)
#   ❌ sarampo_protocolo_2.txt (subpasta: sarampo)
#   ❌ sarampo_protocolo_2txt_protocolo2023.txt (subpasta: sarampo)
#   ❌ sifilis_manual_1txt_manual2023.txt (subpasta: sífilis)
#   ❌ sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: sífilis)
#   ❌ sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: sífilis)
#   ❌ sifilis_protocolo_1txt_protocolo2023.txt (subpasta: sífilis)
#   ❌ sífilis_manual_1.txt (subpasta: sífilis)
#   ❌ sífilis_protocolo_1.txt (subpasta: sífilis)
#   ❌ sindrome_da_rubeola_congenita_src_manual_1txt_manual2023.txt (subpasta: síndrome)
#   ❌ sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023.txt (subpasta: síndrome)
#   ❌ sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: síndrome)
#   ❌ sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: síndrome)
#   ❌ sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023.txt (subpasta: síndrome)
#   ❌ sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: síndrome)
#   ❌ sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: síndrome)
#   ❌ síndrome_da_rubéola_congênita_(src)_manual_1.txt (subpasta: síndrome)
#   ❌ síndrome_da_rubéola_congênita_(src)_nota_técnica_1.txt (subpasta: síndrome)
#   ❌ síndrome_da_rubéola_congênita_(src)_nota_técnica_2.txt (subpasta: síndrome)
#   ❌ tuberculose_protocolo_1.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_10.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_10txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_11.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_11txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_12.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_12txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_13.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_13txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_14.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_14txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_15.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_15txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_1txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_2.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_2txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_3.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_3txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_4.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_4txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_5.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_5txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_6.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_6txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_7.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_7txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_8.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_8txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_9.txt (subpasta: tuberculose)
#   ❌ tuberculose_protocolo_9txt_protocolo2023.txt (subpasta: tuberculose)
#   ❌ tetano_nota_tecnica_1txt_notatecnica2023.txt (subpasta: tétano)
#   ❌ tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: tétano)
#   ❌ tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: tétano)
#   ❌ tétano_nota_técnica_1.txt (subpasta: tétano)
#   ❌ varicela_nota_tecnica_1txt_notatecnica2023.txt (subpasta: varicela)
#   ❌ varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: varicela)
#   ❌ varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: varicela)
#   ❌ varicela_nota_técnica_1.txt (subpasta: varicela)
#   ❌ virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023.txt (subpasta: vírus)
#   ❌ virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: vírus)
#   ❌ virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt (subpasta: vírus)
#   ❌ vírus_sincicial_respiratório_(vsr)_guia_1.txt (subpasta: vírus)
#   ❌ zika_nota_tecnica_1txt_notatecnica2023.txt (subpasta: zika)
#   ❌ zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: zika)
#   ❌ zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt (subpasta: zika)
#   ❌ zika_nota_técnica_1.txt (subpasta: zika)
#   ❌ zika_protocolo_1.txt (subpasta: zika)
#   ❌ zika_protocolo_1txt_protocolo2023.txt (subpasta: zika)
#   ❌ zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: zika)
#   ❌ zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt (subpasta: zika)
#   ❌ zika_protocolo_2.txt (subpasta: zika)
#   ❌ zika_protocolo_2txt_protocolo2023.txt (subpasta: zika)
#   ❌ zika_protocolo_3.txt (subpasta: zika)
#   ❌ zika_protocolo_3txt_protocolo2023.txt (subpasta: zika)
#   ❌ zoonoses_manual_1.txt (subpasta: zoonoses)
#   ❌ zoonoses_manual_1txt_manual2023.txt (subpasta: zoonoses)
#   ❌ zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: zoonoses)
#   ❌ zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt (subpasta: zoonoses)
#
#  Amostras de conteúdo para revisão:
#
#  Arquivo: hepatites_nota_técnica_1.txt (em hepatites)
# Guia Rápido
# de Manejo
# Epidemiológico
# das DOENÇAS
# IMUNOPREVENÍVEIS
# P a r a n á – 2 0 1 5
# SECRETARIA DE ESTADO DA SAÚDE DO PARANÁ
# SUPERINTENDÊNCIA DE VIGILÂNCIA EM SAÚDE
# GUIA RÁPIDO DE MANEJO EPIDEMIOLÓGICO
# DAS DOENÇAS IMUNOPREVENÍVEIS
# 1ª edição
# CURITIBA
# SECRETARIA DE ESTADO DA SAÚDE DO PARANÁ
# 2015
# GOVERNADOR DO PARANÁ
# Beto Richa
# SECRETÁRIO DE ESTADO DA SAÚDE
# Michele Caputo Neto
# DIRETOR-GERAL
# Sezifredo Paz
# SUPERINTENDÊNCIA DE VIGILÂNCIA EM SAÚDE
# Eliane Chomatas
# DIRETORA DO CENTRO DE EPIDEMIOLOGIA
# Cleide Aparecida de Oliveira
# CHEFE DA DIVISÃO DE VIGILÂNCIA DAS DOENÇAS TRANSMISSÍVEIS
# Júlia Valéria Ferreira Cordellini
# EQUIPE TÉCNICA
# Ana Paula Stelmach da Silva Hagedorn
# Franciele Iachecen
# Leni Silva de Araújo
# Renato Antonio Teixeira Lopes
# Sandra Mara Aubrift de Lara
# Vanessa Cavalca Presa
# Wilsa R
#
#  Arquivo: sífilis_manual_1.txt (em sífilis)
# MINISTÉRIO DA SAÚDE
# MANUAL TÉCNICO PARA O
# DIAGNÓSTICO
# DA SÍFILIS
# Brasília – DF
# 2021
# MINISTÉRIO DA SAÚDE
# Secretaria de Vigilância em Saúde
# Departamento de Doenças de Condições Crônicas e
# Infecções Sexualmente Transmissíveis
# MANUAL TÉCNICO PARA O
# DIAGNÓSTICO
# DA SÍFILIS
# Brasília – DF
# 2021
# 2021 Ministério da Saúde.
# Esta obra é disponibilizada nos termos da Licença Creative Commons – Atribuição – Não Comercial –
# Compartilhamento pela mesma licença 4.0 Internacional. É permitida a reprodução parcial ou total desta obra,
# BY SA desde que citada a fonte.
# A coleção institucional do Ministério da Saúde pode ser acessada, na íntegra, na Biblioteca Virtual em Saúde do Ministério da Saúde:
# bvsms.saude.gov.br
# Tiragem 1ª edição – 2021 – versão eletrônica
# Elaboração, distribuição e informações:
# MINISTÉRIO
#
#  Arquivo: linfogranuloma_venéreo_protocolo_1.txt (em linfogranuloma)
# Consenso Protocolo Brasileiro para Infecções Sexualmente
# Transmissíveis 2020: hepatites virais
# doi: 10.1590/S1679-4974202100016.esp1
# Brazilian Protocol for Sexually Transmitted Infections 2020: viral hepatitis
# Protocolo Brasileño para Infecciones de Transmisión Sexual 2020: hepatitis virales
# Geraldo Duarte1 – orcid.org/0000-0002-1689-6142
# Paula Pezzuto2 – orcid.org/0000-0001-9570-8244
# Tiago Dahrug Barros2 – orcid.org/0000-0001-6960-3801
# Gláucio Mosimann Junior2 – orcid.org/0000-0002-1687-5026
# Flor Ernestina Martínez-Espinosa3 – orcid.org/0000-0002-0325-3674
# 1Universidade de São Paulo, Faculdade de Medicina de Ribeirão Preto, Ribeirão Preto, SP, Brasil
# 2Ministério da Saúde, Secretaria de Vigilância em Saúde, Brasília, DF, Brasil
# 3Fundação Oswaldo Cruz, Instituto Leônidas e Maria Deane, Mana

# %% [markdown]
# # Etapa de Padronização de Nomes
# **Objetivo:**
# Padronizar os nomes dos arquivos textuais organizados na pasta corpus_final, garantindo consistência, legibilidade e alinhamento com os critérios estabelecidos para o projeto IAVS.
#
# **O que o script faz:**
# - Converte todos os nomes para letras minúsculas.
#
# -  Remove acentuação, parênteses, hífens, espaços e símbolos especiais.
#
# - Substitui por underscore onde necessário.
#
# - Identifica o tipo do documento com base no nome (guia, nota_tecnica, manual, protocolo).
#
# - Define o sufixo padronizado, incluindo o tipo do documento e o ano (_guiavsa2023.txt, _manual2023.txt, etc.).
#
# - Preserva número final, se houver (_1, _2), ao reconstruir o nome limpo.
#
# - Renomeia os arquivos somente se o nome novo for diferente do atual.
#
#
# **Exemplo de renomeação:**
# Um arquivo com nome original:
#
# Guia de vigilância (Volume 1) - versão final.TXT
#
# Será renomeado para:
# vigilancia_guiavsa2023.txt

# %%
# Caminho da pasta final onde os textos já estão organizados por doença
PASTA_FINAL = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"

# --------------------------- FUNÇÃO DE PADRONIZAÇÃO --------------------------- #
def padronizar_nome(nome_antigo):
    """
    Padroniza o nome de um arquivo textual com base nas regras do projeto:
    - Converte para minúsculas
    - Remove acentos e símbolos
    - Substitui hífens/espaços por underscores
    - Define o sufixo do nome com base no tipo do documento (guia, manual etc.)
    - Adiciona o ano (2023) e o tipo do documento ao final
    """

    # Converte tudo para minúsculas
    nome_original = nome_antigo.lower()

    # 1. Remove acentuação
    nome = unicodedata.normalize('NFKD', nome_original).encode('ASCII', 'ignore').decode('utf-8')

    # 2. Remove parênteses e símbolos especiais
    nome = re.sub(r'[^\w\s\-]', '', nome)

    # 3. Substitui hífens e espaços por underscore
    nome = nome.replace('-', '_').replace(' ', '_')

    # 4. Remove múltiplos underscores consecutivos
    nome = re.sub(r'_+', '_', nome)

    # 5. Remove extensão para trabalhar com o nome-base
    nome_base = nome.replace('.txt', '')

    # 6. Separa o nome por partes para futura lógica de reconstrução
    partes = nome_base.split('_')
    
    # 7. Define tipo de documento e sufixo padrão
    tipos = ['guia', 'nota_tecnica', 'manual', 'protocolo']
    tipo = 'documento'
    sufixo = '_documento2023.txt'

    for t in tipos:
        if t in nome_base:
            tipo = t
            if t == 'guia':
                sufixo = '_guiavsa2023.txt'
            elif t == 'nota_tecnica':
                sufixo = '_notatecnica2023.txt'
            elif t == 'manual':
                sufixo = '_manual2023.txt'
            elif t == 'protocolo':
                sufixo = '_protocolo2023.txt'
            break

    # 8. Verifica se há número ao final do nome (ex: "_1", "_2")
    match = re.search(r'_(\d+)$', nome_base)
    numero = f"_{match.group(1)}" if match else ""

    # 9. Remove o tipo e o número do nome-base original, se existirem
    nome_base_limpo = re.sub(f"_{tipo}{numero}$", '', nome_base)

    # 10. Monta o novo nome padronizado
    novo_nome = f"{nome_base_limpo}{sufixo}"

    return novo_nome

# --------------------------- EXECUÇÃO DA PADRONIZAÇÃO --------------------------- #
print("\n Iniciando padronização dos nomes dos arquivos...\n")

# Percorre cada subpasta (doença) dentro de corpus_final
for subpasta in os.listdir(PASTA_FINAL):
    caminho_sub = os.path.join(PASTA_FINAL, subpasta)
    if os.path.isdir(caminho_sub):
        for arquivo in os.listdir(caminho_sub):
            if arquivo.endswith('.txt'):
                novo_nome = padronizar_nome(arquivo)
                caminho_antigo = os.path.join(caminho_sub, arquivo)
                caminho_novo = os.path.join(caminho_sub, novo_nome)

                # Renomeia o arquivo se houver diferença
                if arquivo != novo_nome:
                 if not os.path.exists(caminho_novo):
                    os.rename(caminho_antigo, caminho_novo)
                    print(f"✅ Renomeado: {arquivo} → {novo_nome}")
                 else:
                    print(f"⚠️ Ignorado (já existe com o nome final): {novo_nome}")
# Out:
#  Iniciando padronização dos nomes dos arquivos...
#
# ⚠️ Ignorado (já existe com o nome final): adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023.txt → adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⚠️ Ignorado (já existe com o nome final): adenovirus_guia_1txt_guiavsa2023.txt
# ⚠️ Ignorado (já existe com o nome final): arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt → arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): arboviroses_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): cancro_mole_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: cancro_mole_protocolo_1txt_protocolo2023.txt → cancro_mole_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt → chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): chikungunya_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): chikungunya_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: chikungunya_protocolo_1txt_protocolo2023.txt → chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): chikungunya_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: chikungunya_protocolo_2txt_protocolo2023.txt → chikungunya_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): chikungunya_protocolo_3txt_protocolo2023.txt
# ✅ Renomeado: chikungunya_protocolo_3txt_protocolo2023.txt → chikungunya_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: clamidia_protocolo_1txt_protocolo2023.txt → clamidia_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: clamídia_protocolo_1.txt → clamidia_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023.txt → coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coinfecção_com_hepatite_b_nota_técnica_1.txt → coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_1txt_notatecnica2023.txt → coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_2txt_notatecnica2023.txt → coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_3txt_notatecnica2023.txt → coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_técnica_1.txt → coqueluche_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_técnica_2.txt → coqueluche_nota_tecnica_2txt_notatecnica2023.txt
# ✅ Renomeado: coqueluche_nota_técnica_3.txt → coqueluche_nota_tecnica_3txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): covid_19_guia_1txt_guiavsa2023.txt
# ⚠️ Ignorado (já existe com o nome final): covid_19_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: covid_19_guia_1txt_guiavsa2023.txt → covid_19_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: covid_19_nota_tecnica_1txt_notatecnica2023.txt → covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: colera_nota_tecnica_1txt_notatecnica2023.txt → colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: colera_protocolo_1txt_protocolo2023.txt → colera_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: cólera_nota_técnica_1.txt → colera_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: cólera_protocolo_1.txt → colera_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: dengue_nota_tecnica_1txt_notatecnica2023.txt → dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: dengue_nota_técnica_1.txt → dengue_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): dengue_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: dengue_protocolo_1txt_protocolo2023.txt → dengue_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): dengue_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: dengue_protocolo_2txt_protocolo2023.txt → dengue_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): dengue_protocolo_3txt_protocolo2023.txt
# ✅ Renomeado: dengue_protocolo_3txt_protocolo2023.txt → dengue_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): dengue_protocolo_4txt_protocolo2023.txt
# ✅ Renomeado: dengue_protocolo_4txt_protocolo2023.txt → dengue_protocolo_4txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: difteria_nota_tecnica_1txt_notatecnica2023.txt → difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: difteria_nota_técnica_1.txt → difteria_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023.txt → entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: entre_outras_doenças_imunopreveníveis_nota_técnica_1.txt → entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): entre_outras_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: entre_outras_protocolo_1txt_protocolo2023.txt → entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): entre_outras_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: entre_outras_protocolo_2txt_protocolo2023.txt → entre_outras_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: febre_amarela_nota_tecnica_1txt_notatecnica2023.txt → febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: febre_amarela_nota_técnica_1.txt → febre_amarela_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): febre_amarela_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: febre_amarela_protocolo_1txt_protocolo2023.txt → febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): febre_amarela_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: febre_amarela_protocolo_2txt_protocolo2023.txt → febre_amarela_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): febre_amarela_protocolo_3txt_protocolo2023.txt
# ✅ Renomeado: febre_amarela_protocolo_3txt_protocolo2023.txt → febre_amarela_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023.txt → febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: febre_do_nilo_ocidental_nota_técnica_1.txt → febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): gonorreia_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: gonorreia_protocolo_1txt_protocolo2023.txt → gonorreia_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hanseniase_diretriz_nacional_1txt_documento2023.txt → hanseniase_diretriz_nacional_1txt_documento2023txt_documento2023.txt
# ✅ Renomeado: hanseniase_nota_tecnica_1txt_notatecnica2023.txt → hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hanseniase_nota_tecnica_2txt_notatecnica2023.txt → hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hanseniase_protocolo_1txt_protocolo2023.txt → hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hanseniase_protocolo_2txt_protocolo2023.txt → hanseniase_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hanseniase_protocolo_3txt_protocolo2023.txt → hanseniase_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hanseníase_diretriz_nacional_1.txt → hanseniase_diretriz_nacional_1txt_documento2023.txt
# ✅ Renomeado: hanseníase_nota_técnica_1.txt → hanseniase_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: hanseníase_nota_técnica_2.txt → hanseniase_nota_tecnica_2txt_notatecnica2023.txt
# ✅ Renomeado: hanseníase_protocolo_1.txt → hanseniase_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hanseníase_protocolo_2.txt → hanseniase_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: hanseníase_protocolo_3.txt → hanseniase_protocolo_3txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): hantavirose_manual_1txt_manual2023.txt
# ✅ Renomeado: hantavirose_manual_1txt_manual2023.txt → hantavirose_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⚠️ Ignorado (já existe com o nome final): hantavirose_manual_2txt_manual2023.txt
# ✅ Renomeado: hantavirose_manual_2txt_manual2023.txt → hantavirose_manual_2txt_manual2023txt_manual2023.txt
# ✅ Renomeado: hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023.txt → hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: hepatite_a_nota_tecnica_1txt_notatecnica2023.txt → hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_a_nota_tecnica_2txt_notatecnica2023.txt → hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_a_nota_técnica_1.txt → hepatite_a_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_a_nota_técnica_2.txt → hepatite_a_nota_tecnica_2txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatite_a_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hepatite_a_protocolo_1txt_protocolo2023.txt → hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatite_b_e_c_ist_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hepatite_b_e_c_ist_protocolo_1txt_protocolo2023.txt → hepatite_b_e_c_ist_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatite_b_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hepatite_b_protocolo_1txt_protocolo2023.txt → hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatite_c_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hepatite_c_protocolo_1txt_protocolo2023.txt → hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatite_d_delta_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_d_delta_nota_tecnica_1txt_notatecnica2023.txt → hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatite_d_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hepatite_d_protocolo_1txt_protocolo2023.txt → hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatite_e_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hepatite_e_protocolo_1txt_protocolo2023.txt → hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatites_nota_tecnica_1txt_notatecnica2023.txt → hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hepatites_nota_técnica_1.txt → hepatites_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): hepatites_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hepatites_protocolo_1txt_protocolo2023.txt → hepatites_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): herpes_genital_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: herpes_genital_protocolo_1txt_protocolo2023.txt → herpes_genital_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: hiv_nota_tecnica_1txt_notatecnica2023.txt → hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hiv_nota_técnica_1.txt → hiv_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: hpv_nota_tecnica_1txt_notatecnica2023.txt → hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: hpv_nota_técnica_1.txt → hpv_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): hpv_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: hpv_protocolo_1txt_protocolo2023.txt → hpv_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): influenza_guia_1txt_guiavsa2023.txt
# ✅ Renomeado: influenza_guia_1txt_guiavsa2023.txt → influenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⚠️ Ignorado (já existe com o nome final): influenza_guia_2txt_guiavsa2023.txt
# ✅ Renomeado: influenza_guia_2txt_guiavsa2023.txt → influenza_guia_2txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⚠️ Ignorado (já existe com o nome final): leishmaniose_manual_1txt_manual2023.txt
# ✅ Renomeado: leishmaniose_manual_1txt_manual2023.txt → leishmaniose_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⚠️ Ignorado (já existe com o nome final): leptospirose_manual_1txt_manual2023.txt
# ✅ Renomeado: leptospirose_manual_1txt_manual2023.txt → leptospirose_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_1txt_notatecnica2023.txt → leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_2txt_notatecnica2023.txt → leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_3txt_notatecnica2023.txt → leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_técnica_1.txt → leptospirose_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_técnica_2.txt → leptospirose_nota_tecnica_2txt_notatecnica2023.txt
# ✅ Renomeado: leptospirose_nota_técnica_3.txt → leptospirose_nota_tecnica_3txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): leptospirose_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: leptospirose_protocolo_1txt_protocolo2023.txt → leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: linfogranuloma_venereo_protocolo_1txt_protocolo2023.txt → linfogranuloma_venereo_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: linfogranuloma_venéreo_protocolo_1.txt → linfogranuloma_venereo_protocolo_1txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): m_abscessus_protocolo_1txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): m_kansasii_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: m_abscessus_protocolo_1txt_protocolo2023.txt → m_abscessus_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: m_kansasii_protocolo_1txt_protocolo2023.txt → m_kansasii_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: malaria_manual_1txt_manual2023.txt → malaria_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: malaria_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: malaria_protocolo_1txt_protocolo2023.txt → malaria_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: malária_manual_1.txt → malaria_manual_1txt_manual2023.txt
# ✅ Renomeado: malária_protocolo_1.txt → malaria_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: meningite_nota_tecnica_1txt_notatecnica2023.txt → meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: meningite_nota_técnica_1.txt → meningite_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: metapneumovirus_guia_1txt_guiavsa2023.txt → metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: metapneumovírus_guia_1.txt → metapneumovirus_guia_1txt_guiavsa2023.txt
# ✅ Renomeado: micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023.txt → micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.txt → micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023.txt
# ✅ Renomeado: outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023.txt → outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⚠️ Ignorado (já existe com o nome final): parainfluenza_guia_1txt_guiavsa2023.txt
# ✅ Renomeado: parainfluenza_guia_1txt_guiavsa2023.txt → parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⚠️ Ignorado (já existe com o nome final): peste_manual_1txt_manual2023.txt
# ✅ Renomeado: peste_manual_1txt_manual2023.txt → peste_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: peste_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⚠️ Ignorado (já existe com o nome final): peste_manual_2txt_manual2023.txt
# ✅ Renomeado: peste_manual_2txt_manual2023.txt → peste_manual_2txt_manual2023txt_manual2023.txt
# ✅ Renomeado: peste_manual_2txt_manual2023txt_manual2023txt_manual2023.txt → peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_1txt_notatecnica2023.txt → poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_2txt_notatecnica2023.txt → poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_3txt_notatecnica2023.txt → poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_técnica_1.txt → poliomielite_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_técnica_2.txt → poliomielite_nota_tecnica_2txt_notatecnica2023.txt
# ✅ Renomeado: poliomielite_nota_técnica_3.txt → poliomielite_nota_tecnica_3txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): poliomielite_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: poliomielite_protocolo_1txt_protocolo2023.txt → poliomielite_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): raiva_humana_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: raiva_humana_protocolo_1txt_protocolo2023.txt → raiva_humana_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): raiva_humana_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: raiva_humana_protocolo_2txt_protocolo2023.txt → raiva_humana_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023.txt → rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: rinovírus_e_outros_respiratórios_guia_1.txt → rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023.txt
# ✅ Renomeado: rubeola_manual_1txt_manual2023.txt → rubeola_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_1txt_notatecnica2023.txt → rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_2txt_notatecnica2023.txt → rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_3txt_notatecnica2023.txt → rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: rubeola_protocolo_1txt_protocolo2023.txt → rubeola_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: rubéola_manual_1.txt → rubeola_manual_1txt_manual2023.txt
# ✅ Renomeado: rubéola_nota_técnica_1.txt → rubeola_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: rubéola_nota_técnica_2.txt → rubeola_nota_tecnica_2txt_notatecnica2023.txt
# ✅ Renomeado: rubéola_nota_técnica_3.txt → rubeola_nota_tecnica_3txt_notatecnica2023.txt
# ✅ Renomeado: rubéola_protocolo_1.txt → rubeola_protocolo_1txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): sarampo_manual_1txt_manual2023.txt
# ✅ Renomeado: sarampo_manual_1txt_manual2023.txt → sarampo_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: sarampo_nota_tecnica_1txt_notatecnica2023.txt → sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sarampo_nota_tecnica_2txt_notatecnica2023.txt → sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sarampo_nota_técnica_1.txt → sarampo_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: sarampo_nota_técnica_2.txt → sarampo_nota_tecnica_2txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): sarampo_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: sarampo_protocolo_1txt_protocolo2023.txt → sarampo_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): sarampo_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: sarampo_protocolo_2txt_protocolo2023.txt → sarampo_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: sifilis_manual_1txt_manual2023.txt → sifilis_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: sifilis_protocolo_1txt_protocolo2023.txt → sifilis_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: sífilis_manual_1.txt → sifilis_manual_1txt_manual2023.txt
# ✅ Renomeado: sífilis_protocolo_1.txt → sifilis_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: sindrome_da_rubeola_congenita_src_manual_1txt_manual2023.txt → sindrome_da_rubeola_congenita_src_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: síndrome_da_rubéola_congênita_(src)_manual_1.txt → sindrome_da_rubeola_congenita_src_manual_1txt_manual2023.txt
# ✅ Renomeado: síndrome_da_rubéola_congênita_(src)_nota_técnica_1.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: síndrome_da_rubéola_congênita_(src)_nota_técnica_2.txt → sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_1txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_10txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_10txt_protocolo2023.txt → tuberculose_protocolo_10txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_11txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_11txt_protocolo2023.txt → tuberculose_protocolo_11txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_12txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_12txt_protocolo2023.txt → tuberculose_protocolo_12txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_13txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_13txt_protocolo2023.txt → tuberculose_protocolo_13txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_14txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_14txt_protocolo2023.txt → tuberculose_protocolo_14txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_15txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_15txt_protocolo2023.txt → tuberculose_protocolo_15txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_1txt_protocolo2023.txt → tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_2txt_protocolo2023.txt → tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_3txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_3txt_protocolo2023.txt → tuberculose_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_4txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_4txt_protocolo2023.txt → tuberculose_protocolo_4txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_5txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_5txt_protocolo2023.txt → tuberculose_protocolo_5txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_6txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_6txt_protocolo2023.txt → tuberculose_protocolo_6txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_7txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_7txt_protocolo2023.txt → tuberculose_protocolo_7txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_8txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_8txt_protocolo2023.txt → tuberculose_protocolo_8txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): tuberculose_protocolo_9txt_protocolo2023.txt
# ✅ Renomeado: tuberculose_protocolo_9txt_protocolo2023.txt → tuberculose_protocolo_9txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: tetano_nota_tecnica_1txt_notatecnica2023.txt → tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: tétano_nota_técnica_1.txt → tetano_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: varicela_nota_tecnica_1txt_notatecnica2023.txt → varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: varicela_nota_técnica_1.txt → varicela_nota_tecnica_1txt_notatecnica2023.txt
# ✅ Renomeado: virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023.txt → virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt → virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ✅ Renomeado: vírus_sincicial_respiratório_(vsr)_guia_1.txt → virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023.txt
# ✅ Renomeado: zika_nota_tecnica_1txt_notatecnica2023.txt → zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt → zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ✅ Renomeado: zika_nota_técnica_1.txt → zika_nota_tecnica_1txt_notatecnica2023.txt
# ⚠️ Ignorado (já existe com o nome final): zika_protocolo_1txt_protocolo2023.txt
# ✅ Renomeado: zika_protocolo_1txt_protocolo2023.txt → zika_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ✅ Renomeado: zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt → zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): zika_protocolo_2txt_protocolo2023.txt
# ✅ Renomeado: zika_protocolo_2txt_protocolo2023.txt → zika_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): zika_protocolo_3txt_protocolo2023.txt
# ✅ Renomeado: zika_protocolo_3txt_protocolo2023.txt → zika_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⚠️ Ignorado (já existe com o nome final): zoonoses_manual_1txt_manual2023.txt
# ✅ Renomeado: zoonoses_manual_1txt_manual2023.txt → zoonoses_manual_1txt_manual2023txt_manual2023.txt
# ✅ Renomeado: zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023.txt → zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ✅ Renomeado: zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt → zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt

# %% [markdown]
# # Verificação de trechos aleatórios e consistência dos textos
#
# Este é um verificador inteligente de qualidade textual, voltado para amostragens manuais e automáticas. Ele:
#
# - Lê 2 arquivos aleatórios por subpasta.
#
# -  Em cada arquivo, exibe até 3 trechos aleatórios.
#
# - Checa nesses trechos a presença de padrões indesejáveis como:
#     - "página X de Y"
#
#     - espaços em branco excessivos
#
#     - conteúdo de teste (ex: xxxxx, lorem ipsum)
#
#     - resíduos técnicos ou erros de OCR
#
#     - Informa no terminal se encontrou algo estranho, com o trecho destacado.

# %%
# Caminho para a pasta com os textos finais organizados por subpasta (por doença ou tema)
PASTA_FINAL = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"

# Lista de padrões suspeitos que indicam problemas no texto
PADROES_PROBLEMAS = [
    "página [0-9]+ de [0-9]+",         # numeração de página residual
    "confidencial",                   # marcações internas
    "xxxxx",                          # preenchimentos de teste ou censura
    "lorem ipsum",                    # textos fictícios
    "^\s*$",                          # linha em branco
    r'\b(pdf|doc|versao|versão|arquivo)\b',  # termos técnicos que podem indicar resíduos
    r'\.{5,}',                        # sequências longas de pontos (ex: ".....")
]

print("\n INÍCIO DA VERIFICAÇÃO DE TRECHOS ALEATÓRIOS DOS TEXTOS\n")

# ---------------------- Função para revisar um arquivo ---------------------- #
def revisar_arquivo(caminho_arquivo):
    """
    Lê um arquivo e imprime até 3 trechos aleatórios com 5 linhas cada,
    verificando se há padrões suspeitos no conteúdo.
    """
    with open(caminho_arquivo, 'r', encoding='utf-8', errors='ignore') as f:
        linhas = f.readlines()
        total_linhas = len(linhas)

        # Seleciona até 3 trechos aleatórios
        indices = random.sample(range(total_linhas), min(3, total_linhas))
        print(f" {os.path.basename(caminho_arquivo)} — {total_linhas} linhas")

        for i in indices:
            trecho = ''.join(linhas[i:i+5]).strip()
            print(f"\n Trecho aleatório a partir da linha {i+1}:\n{trecho}\n")

            # Verifica se o trecho contém algum padrão problemático
            for padrao in PADROES_PROBLEMAS:
                if re.search(padrao, trecho, re.IGNORECASE):
                    print(f"⚠️ Padrão suspeito detectado: \"{padrao}\"\n")

        print("-" * 80)

# ---------------------- Laço principal: revisão por subpasta ---------------------- #
# Para cada subpasta (tema/doença), seleciona até 2 arquivos para revisão
for subpasta in os.listdir(PASTA_FINAL):
    caminho_sub = os.path.join(PASTA_FINAL, subpasta)
    if os.path.isdir(caminho_sub):
        arquivos_txt = [f for f in os.listdir(caminho_sub) if f.endswith(".txt")]
        amostras = random.sample(arquivos_txt, min(2, len(arquivos_txt)))

        for nome_arquivo in amostras:
            caminho_arquivo = os.path.join(caminho_sub, nome_arquivo)
            revisar_arquivo(caminho_arquivo)

print("\n✅ Verificação finalizada.\n")
# Out:
#  INÍCIO DA VERIFICAÇÃO DE TRECHOS ALEATÓRIOS DOS TEXTOS
#
#  adenovírus_guia_1.txt — 5266 linhas
#
#  Trecho aleatório a partir da linha 4113:
# tempo, a confirmação da identificação etiológica se baseia em diagnóstico laboratorial (Brasil, 2023k).
# Cabe ressaltar que a vigilância das síndromes gripais no Brasil é voltada para o vírus influenza e o
# SARS-CoV-2. A identificação de outros vírus respiratórios, portanto, é realizada por meio de diagnóstico
# diferencial para influenza e SARS-CoV-2. Dessa forma, a detecção de OVR ocorre de maneira amostral
# e por conveniência, a depender da disponibilidade de insumos disponíveis nas unidades federadas
#
#
#  Trecho aleatório a partir da linha 3216:
# Epidemiológica – Não detectável
# Municipal, Estadual,
# Distrital H1N1 Yamagata Isolamento* viral
# Resultados e
# H3N2 Victoria Resistência Caracterização informações
#
#
#  Trecho aleatório a partir da linha 408:
# nacional, também conhecido como Centro Nacional de Influenza (do inglês, National Influenza Center
# – NIC) (Brasil, 2023c).
# Com o início da pandemia da covid-19 na China, a SVSA já possuía a vigilância da influenza
# estabelecida e consolidada no País. Assim, esta foi utilizada para receber a notificação dos casos
# de Srag hospitalizados suspeitos de covid-19, bem como dos óbitos por Srag, independentemente
#
# --------------------------------------------------------------------------------
#  adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt — 5266 linhas
#
#  Trecho aleatório a partir da linha 2519:
# dispneia (21%) aos 9 a <12 meses; e fadiga, dispneia, distúrbio do sono e mialgia (41%, 31%, 30% e
# 22%, respectivamente, no acompanhamento >12 meses).
# ` CONDIÇÕES PÓS-COVID NO BRASIL
# No contexto brasileiro, foi realizada uma revisão sistemática sobre a incidência e os fatores de risco de
# condições pós-covid a partir de estudos realizados no território nacional pela Secretaria de Ciência,
#
#
#  Trecho aleatório a partir da linha 3816:
# em que pode ser pesquisado mais de um agente etiológico.
# Assim, como consequência da circulação intensa e concomitante do SARS-CoV-2 e dos vírus
# influenza, casos de codetecção têm sido mais identificados pelas redes laboratoriais e de vigilância
# (Brasil, 2023k).
# DEFINIÇÃO DE CASO OU ÓBITO DE CODETECÇÃO DE INFLUENZA E SARS-COV-2
#
#
#  Trecho aleatório a partir da linha 5196:
# IDADE
# (BATIMENTOS/MIN) (BATIMENTOS/MIN)
# Neonatos 100 a 205 90 a 160
# Bebê 100 a 180 90 a 160
# 1 a 3 anos 98 a 140 80 a 120
#
# --------------------------------------------------------------------------------
#  arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 788 linhas
#
#  Trecho aleatório a partir da linha 320:
# 5) AVALIAÇÃO DOS RESULTADOS ESPERADOS (com base na execução do plano de trabalho anual)
# Resultado Esperado (RE) (definido na Matriz Lógica)
# Esferas de gestão do SUS fortalecidas para o enfrentamento da dengue, por
# Nº do RE/Descrição do RE: 5
# meio de ações intersetoriais articuladas e reforçadas.
#
#
#  Trecho aleatório a partir da linha 640:
# (PSF, ACE, ACS.);
# * Numero de municípios monitorados com instrumento padronizado
# nacionalmente;
# * Nº de reuniões do Comitê Técnico Assessor Nacional , do Comitê Intersetorial e do
# Descrição do(s) indicador(es)
#
#
#  Trecho aleatório a partir da linha 324:
# meio de ações intersetoriais articuladas e reforçadas.
# Indicador(es)
# *Número de municípios com compatibilização de territórios integrados em saúde
# (PSF, ACE, ACS.);
# * Numero de municípios monitorados com instrumento padronizado
#
# --------------------------------------------------------------------------------
#  arboviroses_nota_tecnica_1txt_notatecnica2023.txt — 788 linhas
#
#  Trecho aleatório a partir da linha 15:
# Objeto do TC:
# estratégias relevantes na consolidação das políticas públicas preconizadas para o PNCD. (Em revisão)
# Número do processo: 25000.046967/2010-49 Número do SIAFI: 662115
# Data de início 10/08/2010 Data de término:
# 09/08/2025
#
#
#  Trecho aleatório a partir da linha 8:
# 62
# Prevenção e Controle da Dengue no contexto da GI
# Relatório Técnico - Anual 2021
# 1. IDENTIFICAÇÃO DO TC/TA
# NÚMERO DO TC: 62
#
#
#  Trecho aleatório a partir da linha 352:
# cancelados devida à pandemia de COVID-19 e afetaram a execução do Plano de Trabalho. De qualquer forma foi
# realizada visita técnica emergencial para apoiar o estado do Acre e os municípios de Rio Branco, Cruzeiro do Sul e
# Tarauacá e Reunião de Apoio as Ações Urgentes de Controle das Arboviroses para o enfrentamento do próximo
# período sazonal das arboviroses 2020/21.
# O TC sempre apoiou alianças estratégicas para o enfrentamento das arboviroses apoiando diversos eventos e
#
# --------------------------------------------------------------------------------
#  cancro_mole_protocolo_1.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 719:
# 70. Nelson NP, Weng MK, Hofmeister MG, Moore KL,
# [cited 2020 Oct 15]; 32(4):307-13. Available from: Doshani M, Kamili S, et al. Prevention of hepatitis
# https://doi.org/10.1097/INF.0b013e31827bd1b0 A virus infection in the united states: recommenda-
# tions of the advisory committee on immunization
# 62. Yeo YH, Le MH, Chang ET, Henry L, Nguyen MH.
#
#
#  Trecho aleatório a partir da linha 193:
# a detecção, podendo se prolongar por até seis meses. O hepatite C deve ser solicitada para todos os indivíduos
# anti-HBc IgM evolui para negatividade após controle em situações de risco para a infecção.12,52
# da infecção aguda, mas, em casos de reagudização da
# hepatite B, pode ser detectado.48 Tratamento
# O HBeAg é marcador da intensa replicação viral
#
#
#  Trecho aleatório a partir da linha 542:
# critical role of preventing perinatal transmis-
# Radix A, et al. Assessing routes of hepatitis C trans-
# sion. Biologicals [Internet]. 2017 Nov [cited
# mission in HIV-infected men who have sex with men
# 2020 Oct 15]; 50:3-19. Available from: https://
#
# --------------------------------------------------------------------------------
#  cancro_mole_protocolo_1txt_protocolo2023txt_protocolo2023.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 74:
# a via percutânea e o contato sexual são as formas de
# Aspectos epidemiológicos
# maior risco de contaminação.18
# As hepatites virais A, B e C são causadas por vírus O vírus da hepatite C (hepatitis C virus, HCV) per-
# que apresentam tropismo primário pelo tecido he- tence à família Flaviviridae, cujo material genético é
#
#
#  Trecho aleatório a partir da linha 104:
# Brasil. Destes, 168.036 (25%) foram referentes à hepa- sexual, a presença de outras IST, a exemplo da infec-
# tite A, 247.890 (36,8%) à hepatite B, 253.307 (37,6%) à ção pelo vírus da imunodeficiência humana (human
# hepatite C e 4.156 (0,6%) à hepatite D.7 immunodeficiency virus, HIV) e práticas sexuais
# 2 Epidemiol. Serv. Saude, Brasília, 30(Esp.1):e2020834, 2021
# Geraldo Duarte e colaboradores
#
#
#  Trecho aleatório a partir da linha 586:
# FV. The hepatitis B virus persists for decades Foster GR, Main J, et al. Hepatitis C and cog-
# after patients' recovery from acute viral hepatitis nitive impairment in a cohort of patients with
# despite active maintenance of a cytotoxic T-lym- mild liver disease. Hepatology [Internet]. 2002
# phocyte response. Nat Med [Internet]. 1996 Oct [cited 2020 Oct 15]; 35:433. Available from:
# [cited 2020 Oct 15]; 2(10):1104-8. Available https://doi.org/10.1053/jhep.2002.30688
#
# --------------------------------------------------------------------------------
#  chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 788 linhas
#
#  Trecho aleatório a partir da linha 544:
# Aedes por laboratório pertencente a Rede Brasileira de Laboratórios Analíticos em Saúde (REBLAS) da Agência
# Nacional de Vigilância Sanitária (ANVISA) e capacitação dos estados para sua incorporação e uso. Também foi
# articulada pela OPAS a coleta de Malathion em desconformidade e substituição de CIELO ULV. Ainda sobre inseticidas
# foi realizada qualificação de Termo de Referencia para aquisição de larvicida e estudos de avaliação da técnica de
# aplicação espacial de adulticidas. O TC vem apoiando na atualização das "Diretrizes para projetos de unidades de
#
#
#  Trecho aleatório a partir da linha 519:
# * equipes de saúde da família e agentes de endemias capacitadas na área de
# vigilância em saúde, com enfoque para a vigilância epidemiológica e manejo
# integrado de vetores;
# Descrição do(s) indicador(es) * equipes de saúde da família com ACE incorporado a equipe;
# * estudos e pesquisas realizados na análise e identificação de fatores de risco
#
#
#  Trecho aleatório a partir da linha 774:
# Secretaria de Atenção à Saúde do Ministério da Saúde.
# As atividades de cooperação estreitaram as relações com instituições afins como a Fundação Oswaldo Cruz (FIOCRUZ), o
# Instituto Evandro Chagas (IEC) entre outros.
# O TC contribui para o desenvolvimento de novas tecnologias para o controle vetorial do Aedes e aportou significativo apoio
# na avaliação de qualidade dos inseticidas utilizados no controle vetorial.
#
# --------------------------------------------------------------------------------
#  chikungunya_protocolo_3txt_protocolo2023txt_protocolo2023.txt — 3572 linhas
#
#  Trecho aleatório a partir da linha 1008:
# com o objetivo de capacitação e alinhamento das recomendações;
#  Estabelecer critérios (indicadores) de monitoramento e avaliação do
# plano, visando à elaboração de estratégias para seu aperfeiçoamento;
#  Acompanhar o desenvolvimento das ações dos demais componentes;
#  Verificar a necessidade de atualização de documentos existentes, bem
#
#
#  Trecho aleatório a partir da linha 169:
# 7.2.1 Estágio operacional: Mobilização 43
# 7.2.2 Estágio operacional: Alerta 47
# 7.2.3 Estágio operacional: Situação de epidemia 51
# 8
# COMUNICAÇÃO DE RISCO E PARTICIPAÇÃO COMUNITÁRIA (CRPC) 54
#
#
#  Trecho aleatório a partir da linha 3216:
# PLANO DE CONTINGÊNCIA MUNICIPAL
# MOBILIZAÇÃO
# CENÁRIO 1: MUNICÍPIO COM AUMENTO DE INCIDÊNCIA DE CASOS PROVÁVEIS
# DE DENGUE, CHIKUNGUNYA OU ZIKA, DENTRO DO LIMITE ENDÊMICO.
# Indicadores
#
# --------------------------------------------------------------------------------
#  clamidia_protocolo_1txt_protocolo2023.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 9:
# Gláucio Mosimann Junior2 – orcid.org/0000-0002-1687-5026
# Flor Ernestina Martínez-Espinosa3 – orcid.org/0000-0002-0325-3674
# 1Universidade de São Paulo, Faculdade de Medicina de Ribeirão Preto, Ribeirão Preto, SP, Brasil
# 2Ministério da Saúde, Secretaria de Vigilância em Saúde, Brasília, DF, Brasil
# 3Fundação Oswaldo Cruz, Instituto Leônidas e Maria Deane, Manaus, AM, Brasil
#
#
#  Trecho aleatório a partir da linha 782:
# exposed to hepatitis B virus in a post-vaccination
# hepatitis B among pregnant women and its impact on
# serological testing program in four provinces
# pregnancy and newborn complications at a tertiary
# in China. Infect Dis Poverty [Internet]. 2019 Jul
#
#
#  Trecho aleatório a partir da linha 870:
# Hepatites virais
# Abstract Resumen
# This article discusses viral hepatitis, a theme addressed Este artículo aborda las hepatitis virales, tema que
# by the Clinical Protocol and Therapeutic Guidelines to hace parte del Protocolo Clínico y Directrices Terapéuticas
# Comprehensive Care for People with Sexually Transmitted para la Atención Integral a Personas con Infecciones de
#
# --------------------------------------------------------------------------------
#  clamidia_protocolo_1txt_protocolo2023txt_protocolo2023.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 792:
# 85. Huang H, Xu C, Liu L, Chen L, Zhu X, Chen J, et al.
# 77. Pan CQ, Duan ZP, Bhamidimarri KR, Zou HB, Liang
# Increased protection of earlier use of immunopro-
# XF, Li J, et al. An algorithm for risk assessment and
# phylaxis in preventing perinatal transmission
#
#
#  Trecho aleatório a partir da linha 565:
# 27. Lemon SM. Type A viral hepatitis. New developments an endemic area (Senegal). J Med Virol [Internet].
# in an old disease. N Engl J Med [Internet]. 1985 Oct 1987 May [cited 2020 Oct 15]; 22(1):1-5. Available
# [cited 2020 Oct 15]; 313(17):1059-67. Available from: from: https://doi.org/10.1002/jmv.1890220102
# https://doi.org/10.1056/NEJM198510243131706
# 36. Alter MJ. Epidemiology of hepatitis C virus infec-
#
#
#  Trecho aleatório a partir da linha 545:
# mission in HIV-infected men who have sex with men
# 2020 Oct 15]; 50:3-19. Available from: https://
# using single genome sequencing. PLoS One [Internet].
# doi.org/10.1016/j.biologicals.2017.08.008
# 2020 Jul [cited 2020 Oct 15]; 15(7):e0235237. Availab-
#
# --------------------------------------------------------------------------------
#  coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023.txt — 157 linhas
#
#  Trecho aleatório a partir da linha 64:
# LACENs
# Ø Imediatamente após o recebimento do tubo nos LACENs, o soro deve ser aliquotado em
# criotubos ou microtubos (2 alíquotas de 1 mL) idenficados com o nome completo do
# paciente, sua data de nascimento e po de amostra (soro). O volume mínimo de material
# biológico para realização do exame de CV-HDV é de 1 mL para soro.
#
#
#  Trecho aleatório a partir da linha 51:
# 3.2.1. Fluxo preferencial da amostra (aplica-se para unidades coletoras com disponibilidade de
# centrífuga)
# Unidade Coletora
# Ø O exame requer a coleta de uma amostra de sangue total em tubo sem ancoagulante com
# gel separador (tampa amarela). Deve ser coletado a quandade de tubos suficiente para a
#
#
#  Trecho aleatório a partir da linha 35:
# minimamente os campos obrigatórios sinalizados pelo asterisco (*), do formulário de solicitação do
# exame (hps://www.gov.br/aids/pt-br/sistemas-de-informacao/gal). Salienta-se que o preenchimento
# inadequado do formulário de solicitação implicará na incapacidade de registro da requisição do exame no
# sistema Gerenciador de Ambiente Laboratorial – GAL (hp://gal.datasus.gov.br/GALL/index.php), pela
# unidade de cadastro (instuição solicitante/coletora), e/ou avaliação dos critérios de realização do exame,
#
# --------------------------------------------------------------------------------
#  coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 157 linhas
#
#  Trecho aleatório a partir da linha 157:
# https://sei.saude.gov.br/sei/controlador.php?acao=documento_imprimir_web&acao_origem=arvore_visualizar&id_documento=45219446&infra_si… 5/5
#
#
#  Trecho aleatório a partir da linha 50:
# 23/07/2024, 09:07 SEI/MS - 0042050781 - Nota Técnica
# 3.2.1. Fluxo preferencial da amostra (aplica-se para unidades coletoras com disponibilidade de
# centrífuga)
# Unidade Coletora
# Ø O exame requer a coleta de uma amostra de sangue total em tubo sem ancoagulante com
#
#
#  Trecho aleatório a partir da linha 16:
# 2.2. O rastreamento da hepate D deve ser realizado por meio de imunoensaio laboratorial
# para a detecção de ancorpos totais an-HDV (an-HDV total) e está indicado para indivíduos HBsAg
# reagente nas seguintes situações:
# Ø Em indivíduos ou filhos de indivíduos provenientes dos estados da Região Amazônica
# (Amazonas, Acre, Roraima, Rondônia, Amapá, Pará, Tocanns, Maranhão e Mato Grosso) ou
#
# --------------------------------------------------------------------------------
#  coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 2014:
# Amostra Clínica Coletada
# 8 - Enterovírus 9 - Outras__________ 10 - Não Detectado
# 53 Especifique Intervalo de Tempo
# Menor de 5 anos | | 1 - Em até 72 horas
# | | 2- Após 72 horas
#
#
#  Trecho aleatório a partir da linha 1211:
# samotnis
# ,atla erbeF
# éta
# otatnoC
# /
#
#
#  Trecho aleatório a partir da linha 2282:
# óbitos e surtos.
# A Varicela é uma infecção viral primária, aguda, altamente contagiosa, caracterizada pelo surgimento de exan-
# tema maculopapular e polimorfismo regional (pápulas, vesículas, pústulas e crostas num mesmo dimídio),
# acompanhados de febre baixa e prurido intenso.
# A transmissão se dá por meio do contato direto ou de secreções respiratórias (disseminação aérea de partí-
#
# --------------------------------------------------------------------------------
#  coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt — 171 linhas
#
#  Trecho aleatório a partir da linha 28:
# sistema integrado de vigilância do sarampo e da rubéola.
# 3.2. Trata-se de um instrumento de controle de qualidade da vigilância epidemiológica de rotina,
# por manter o alerta para o risco de transmissão do vírus endêmico de um local para outro, bem como a
# importação de casos, estabelecendo as medidas de controle necessárias (isolamento do paciente e
# demais ações pertinentes frente à identificação de casos suspeitos), em tempo oportuno, para evitar a
#
#
#  Trecho aleatório a partir da linha 122:
# sarampo e rubéola e não informou a ausência de casos suspeitos (notificação negativa).
# 7. CONCLUSÃO
# 7.1. O 4° Dia “S” de 2025, ocorrerá em 17 de junho, cujo período de execução das atividades de
# busca ativa seguirá o cronograma abaixo:
# a)Busca Ativa Institucional (BAI): buscar por casos atendidos nos serviços de saúde de 17/05
#
#
#  Trecho aleatório a partir da linha 165:
# acao=documento_conferir&id_orgao_acesso_externo=0, informando o código verificador 0047742253 e o
# código CRC 4E5CC266.
# Referência: Processo nº 25000.071730/2025-82 SEI nº 0047742253
# Coordenação-Geral de Vigilância das Doenças Imunopreveníveis - CGVDI
# SRTVN 701, Via W5 Norte Edifício PO700, 6º andar - Bairro Asa Norte, Brasília/DF, CEP 70719-040
#
# --------------------------------------------------------------------------------
#  covid-19_nota_técnica_1.txt — 788 linhas
#
#  Trecho aleatório a partir da linha 523:
# * estudos e pesquisas realizados na análise e identificação de fatores de risco
# socioambientais para a dengue;
# * proporção de municípios realizando o Levantamento Rápido de índice de
# Infestação por Aedes aegypti (LIRAa) entre os selecionados;
# * proporção de municípios entre os selecionados com informações sobre o status
#
#
#  Trecho aleatório a partir da linha 676:
# c) Relacionar o progresso das ações programadas no PTA com o alcance do resultado esperado, considerando os
# indicadores e as metas:
# As atividades realizadas corroboram para os indicadores de Proporção de estados e capitais acompanhados pelo
# Programa Nacional de Controle da Dengue (PNCD) e para a proporção de municípios acompanhados pelas SES em
# cada unidade federada, considerando a nova estrutura do Ministério da Saúde onde não existe o PNCD e sim a
#
#
#  Trecho aleatório a partir da linha 320:
# 5) AVALIAÇÃO DOS RESULTADOS ESPERADOS (com base na execução do plano de trabalho anual)
# Resultado Esperado (RE) (definido na Matriz Lógica)
# Esferas de gestão do SUS fortalecidas para o enfrentamento da dengue, por
# Nº do RE/Descrição do RE: 5
# meio de ações intersetoriais articuladas e reforçadas.
#
# --------------------------------------------------------------------------------
#  covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt — 5266 linhas
#
#  Trecho aleatório a partir da linha 4869:
# Acesso em: 31 jan. 2024.
# BRASIL. Ministério da Saúde. Secretaria de Vigilância em Saúde e Ambiente. Estratégia de
# Vacinação Contra a Covid-19 – 2024. Brasília, DF: MS, 2024a. Disponível em: https://www.
# gov.br/saude/pt-br/vacinacao/informes-e-notas-tecnicas/estrategia-de-vacinacao-contra-a-
# covid-19-2013-2024. Acesso em: 31 jan. 2024.
#
#
#  Trecho aleatório a partir da linha 1278:
# Os casos de covid-19 relacionados ao trabalho, ou seja, aqueles em que o indivíduo tenha sido contaminado
# durante a realização de suas atividades laborais ou a caminho do local de trabalho ou ainda a serviço de
# seu empregador, devem ser também notificados na Ficha de Acidente de Trabalho do Sinan.
# ` QUEM DEVE NOTIFICAR?
# Profissionais de saúde ou responsáveis pelas instituições de saúde do setor público ou privado, em
#
#
#  Trecho aleatório a partir da linha 4016:
# ser utilizados pelo profissional de saúde durante o procedimento de assistência ao paciente.
# • Manter paciente, preferencialmente, em quarto privativo ou, quando não disponível, isolamento
# de coorte. Embora a covid-19 e a influenza sejam doenças para as quais se implementam
# medidas de precaução semelhantes, não se devem colocar na mesma coorte pacientes com
# covid-19 e pacientes com influenza, para evitar a disseminação das diferentes doenças entre
#
# --------------------------------------------------------------------------------
#  colera_protocolo_1txt_protocolo2023.txt — 9618 linhas
#
#  Trecho aleatório a partir da linha 5371:
# principalmente na Região Norte (Santos et al., 2017). O gênero é o único, até o momento, responsável
# por manifestações sistêmicas caracterizadas por quadros hemorrágicos. São conhecidas por diversos
# nomes populares, entre eles taturana, oruga e ruga (Fundação Nacional de Saúde, 2001).
# Alimentam-se durante a noite, permanecendo nos troncos das árvores durante o dia. Os
# megalopigídeos são solitários, enquanto os saturnídeos têm hábitos gregários, fazendo com que
#
#
#  Trecho aleatório a partir da linha 319:
# em duas amostras de soro
# PRIMEIRA SEGUNDA
# INTERPRETAÇÃO E COMENTÁRIO
# AMOSTRAa AMOSTRAb
# Não
#
#
#  Trecho aleatório a partir da linha 6880:
# Brasília, DF: Editora do Ministério da Saúde, 2006b. 36 p. (Série A. Normas e Manuais
# Técnicos). Disponível em: http://www.fiocruz.br/biosseguranca/Bis/manuais/
# classificacaoderiscodosagentesbiologicos.pdf. Acesso em: 25 maio 2021.
# BRASIL. Ministério da Saúde. Secretaria de Vigilância em Saúde. Departamento de Vigilância
# Epidemiológica. Normas técnicas de profilaxia da raiva humana. Brasília, DF: MS, 2014. 60 p.,
#
# ⚠️ Padrão suspeito detectado: "\b(pdf|doc|versao|versão|arquivo)\b"
#
# --------------------------------------------------------------------------------
#  colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 193 linhas
#
#  Trecho aleatório a partir da linha 35:
# 10/04/2024
# 3. CENÁRIO EPIDEMIOLÓGICO
# 3.1. No Brasil, os últimos casos autóctones ocorreram em Pernambuco
# entre os anos de 2004 e 2005, com 21 e cinco casos confirmados,
# respectivamente. A partir de 2006, não houve casos de cólera autóctones,
#
#
#  Trecho aleatório a partir da linha 58:
# 4.1. A cólera é causada pela enterotoxina do Vibrio cholerae O1 ou O139
# e compõe as doenças diarreicas agudas (DDA)[1]. A grande maioria das pessoas
# infectadas permanece assintomática (aproximadamente 75%) e, daquelas que
# desenvolvem a doença, a maioria apresenta sintomas leves ou moderados, e
# apenas de 10% a 20% desenvolvem a forma severa, que, se não for tratada
#
#
#  Trecho aleatório a partir da linha 13:
# e VE-cólera).
# 1. OBJETIVO
# 1.1. Comunicar e esclarecer sobre o caso de cólera autóctone confirmado
# laboratorialmente no estado da Bahia e recomendar ações para o fortalecimento
# das VE-DDA e VE-cólera.
#
# --------------------------------------------------------------------------------
#  dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt — 788 linhas
#
#  Trecho aleatório a partir da linha 622:
# Vários eventos e atividades relacionados a este componente de ações educativas são realizados e vinculados
# diretamente na sua área fim, como atenção ao Paciente, vigilância epidemiológica e manejo integrado de vetores.
# A principal dificuldade para a execução do plano de trabalho foi a reorganização das modalidades de capacitação e
# divulgação devido a pandemia de COVID-2 e as mudanças na gestão da Secretaria de Vigilância em Saúde.
# c) Relacionar o progresso das ações programadas no PTA com o alcance do resultado esperado, considerando os
#
#
#  Trecho aleatório a partir da linha 496:
# Trabalho Anual.
# A situação epidemiológica de circulação da dengue no país, predominantemente do sorotipo DENV 2, e a ocorrência
# de casos de febre amarela e os surtos de chikungunya também direcionaram esforços dos gestores para o
# enfrentamento destas enfermidades
# c) Relacionar o progresso das ações programadas no PTA com o alcance do resultado esperado, considerando os
#
#
#  Trecho aleatório a partir da linha 632:
# Relatório Técnico - Anual 2021
# 5) AVALIAÇÃO DOS RESULTADOS ESPERADOS (com base na execução do plano de trabalho anual)
# Resultado Esperado (RE) (definido na Matriz Lógica)
# Esferas de gestão do SUS fortalecidas para o enfrentamento da dengue, por
# Nº do RE/Descrição do RE: 5
#
# --------------------------------------------------------------------------------
#  dengue_protocolo_4txt_protocolo2023txt_protocolo2023.txt — 3572 linhas
#
#  Trecho aleatório a partir da linha 106:
# EPI Equipamento de proteção individual
# eSB Equipe de Saúde Bucal
# ESF Estratégia Saúde da Família
# eSF Equipe de Saúde da Família
# eSFR Equipe de Saúde da Família Ribeirinha
#
#
#  Trecho aleatório a partir da linha 2825:
# e definição do plano de investimento;
# Desenvolver ações articuladas entre as diferentes áreas técnicas que compõem
# a Secretaria de Atenção Primária no âmbito do Estado; e
# Viabilizar, junto aos municípios, a criação de unidades de referência, em caráter
# excepcional, para a oferta de hidratação venosa.
#
#
#  Trecho aleatório a partir da linha 3553:
# atendimento à emergência; e
# Proceder à articulação intersetorial e interinstitucional com as áreas envolvidas na
# intensificação das medidas propostas para enfrentamento de epidemias de dengue,
# chikungunya e Zika, para cada nível de alerta.
# 101 Plano de contingência nacional para dengue, chikungunya e Zika
#
# --------------------------------------------------------------------------------
#  difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 602:
# Evolução de Classificação Final;
# • As Unidades Sentinelas devem realizar coleta de amostra clínica (swab de nasofaringe)
# para o caso suspeito e um comunicante.
# • Realizar a coleta de amostra laboratorial antes do início da antibioticoterapia ou,
# no máximo, em até três dias após seu início. A amostra deverá ser encaminhada
#
#
#  Trecho aleatório a partir da linha 317:
# 10 mg/kg (máximo 500 mg) 1x/dia no 1º dia e
# Maiores / iguais a seis meses
# 5 mg/kg (máximo 250 mg) do 2º ao 5º dia, 1x/dia
# Adultos 500 mg/1x/dia por cinco dias
# EM CASO DE INTOLERÂNCIA OU INDISPONIBILIDADE DA AZITROMICINA, VIDE ORIENTAÇÃO DOS
#
#
#  Trecho aleatório a partir da linha 3138:
# 28 Outras bactérias
# 75 Não identificado
# 51 Nenhum agente
# 70 Adenovírus
# 56 Echovírus
#
# --------------------------------------------------------------------------------
#  difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 3225:
# Método de cálculo da x 100
# medida de desempenho Nº de casos notificados de Meningites
# Sistema de Informação de Agravos de Notificação – Sinan-NET (FIE Meningite
# Fonte de dados
# Campo nº 46 – punção lombar).
#
#
#  Trecho aleatório a partir da linha 1316:
# 42
# étA
# ,)amacsed
# euq(
# ametnaxe
#
#
#  Trecho aleatório a partir da linha 1830:
# Realizar vacinação com a vacina Sarampo, Caxumba e Rubéola (SCR) nas puérperas ainda
# não vacinadas;
# Não coletar sorologia: Do 8º ao 56º dias após a vacina SCR e em gestante (Nota Técnica do MS
# Nº 17/2013);
# Realizar capacitações para os técnicos de Vigilância Epidemiológica Municipal;
#
# --------------------------------------------------------------------------------
#  entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt — 3811 linhas
#
#  Trecho aleatório a partir da linha 1750:
# 70%, clorexidina alcoólica a 0,5% ou PVPI para evitar contaminação com a
# microbiota da pele ao redor do ponto de inserção;
#  Remover o cateter e, assepticamente, cortar 05 cm da parte mais distal, ou seja, a
# que está mais profundamente introduzida na pele. Não usar tesouras embebidas em
# soluções antissépticas;
#
#
#  Trecho aleatório a partir da linha 242:
# O material é encaminhado por meio da Vigilância Epidemiológica, para realização de
# ensaios para elucidação de casos suspeitos de doenças de notificação compulsória e outros
# agravos de interesse da saúde pública e devem ser acompanhadas da respectiva Ficha
# Epidemiológica (Anexo B) e/ou Formulário de Encaminhamento de Amostras.
# 3. PREENCHIMENTO DO CADASTRO DO PACIENTE (GAL)
#
#
#  Trecho aleatório a partir da linha 309:
# Figura 01: Aplicação do Torniquete
# 4.10. PROCEDIMENTOS DIAGNÓSTICOS
# A administração de contrastes para exames radiológicos ou tomográficos,
# eletroneuromiografia e/ou terapêuticos como cirurgias, hemodiálise, transfusão
# sanguínea, devem ser lembrados como outras causas de variações dos resultados
#
# --------------------------------------------------------------------------------
#  entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 2160:
# com complicações ou óbito, e pertença a um dos seguintes grupos de risco supracitados.
# Lembrando:
# 1. Um caso em ambiente hospitalar é considerado surto. Nesse caso, o tempo hábil para administração da vacina
# é de 120 horas, e o da imunoglobulina antivaricela-zóster é de 96 horas após o contato com o caso suspeito de
# Varicela.
#
#
#  Trecho aleatório a partir da linha 2618:
# funcionários do sistema prisional;
# • Indivíduos com 60 anos ou mais
# de idade.
# Tabela 6* – Comorbidades: categorias de risco clínico com indicação da vacina Influenza.
# CATEGORIA DE RISCO CLÍNICO INDICAÇÕES
#
#
#  Trecho aleatório a partir da linha 1310:
# )91B
# surívovraP(
# .)adaetefobse
# ANITALRACSE
# -sóp
#
# --------------------------------------------------------------------------------
#  febre_amarela_protocolo_3.txt — 1574 linhas
#
#  Trecho aleatório a partir da linha 358:
# de áreas afetadas e ampliadas e de corredores ecológicos, e o direcionamento de medidas
# preventivas às populações sob maior risco, visando evitar a ocorrência de casos, surtos e óbitos.
# Ainda, o monitoramento da doença em PNH permite dimensionar a magnitude da área afetada,
# conhecer as características epidemiológicas da transmissão, além de conferir maior acurácia
# aos modelos de risco e de predição de emergências (BRASIL, 2017a).
#
#
#  Trecho aleatório a partir da linha 360:
# Ainda, o monitoramento da doença em PNH permite dimensionar a magnitude da área afetada,
# conhecer as características epidemiológicas da transmissão, além de conferir maior acurácia
# aos modelos de risco e de predição de emergências (BRASIL, 2017a).
# A FA silvestre é endêmica na região amazônica, onde casos esporádicos são registrados anualmente,
# geralmente em indivíduos não vacinados e que se expõem em áreas de mata nas quais o vírus
#
#
#  Trecho aleatório a partir da linha 198:
# e superam o número de casos confirmados desde a descrição do ciclo silvestre, em 1932, até
# 2013 (BRASIL, 2019a).
# Figura 1 • DISTRIBUIçãO DOS MUNICíPIOS COM CASOS HUMANOS E/OU EPIZOOTIAS EM PNH
# ConFirmAdos durAnte reemerGênCiA extrA-AmAzôniCA dA FeBre AmArelA, Por Período de
# monitorAmento (julHo A junHo), 2014/2015 A 2019/2020, BrAsil
#
# --------------------------------------------------------------------------------
#  febre_amarela_nota_tecnica_1txt_notatecnica2023.txt — 788 linhas
#
#  Trecho aleatório a partir da linha 774:
# Secretaria de Atenção à Saúde do Ministério da Saúde.
# As atividades de cooperação estreitaram as relações com instituições afins como a Fundação Oswaldo Cruz (FIOCRUZ), o
# Instituto Evandro Chagas (IEC) entre outros.
# O TC contribui para o desenvolvimento de novas tecnologias para o controle vetorial do Aedes e aportou significativo apoio
# na avaliação de qualidade dos inseticidas utilizados no controle vetorial.
#
#
#  Trecho aleatório a partir da linha 522:
# Descrição do(s) indicador(es) * equipes de saúde da família com ACE incorporado a equipe;
# * estudos e pesquisas realizados na análise e identificação de fatores de risco
# socioambientais para a dengue;
# * proporção de municípios realizando o Levantamento Rápido de índice de
# Infestação por Aedes aegypti (LIRAa) entre os selecionados;
#
#
#  Trecho aleatório a partir da linha 574:
# estruturação do Ministério da Saúde. Atualmente o Brasil já normatizou a inclusão dos Agentes de Combate as
# Endemias aos programas de saúde da família, e vinculou a realização do Levantamento Rápido de índice de Infestação
# por Aedes aegypti (LIRAa) ao Programa de Qualificação das Ações de Vigilância em Saúde (PQAVS).
# b) Detalhar as dificuldades, intervenções requeridas e/ou sugestões para execução do plano de trabalho, se existentes
# As atividades realizadas pelo TC foram para além das programadas especialmente o tema estratégico e prioritário de
#
# --------------------------------------------------------------------------------
#  gonorreia_protocolo_1.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 155:
# cerca de 50% a 85% das pessoas evoluem para a forma Na hepatite B aguda, o HBsAg, HBeAg, anti-HBc
# crônica da infecção, apresentando manifestações clí- IgM e o HBV-DNA são os primeiros marcadores a se-
# nicas inespecíficas como cansaço, alterações do sono, rem detectados. A presença do HBsAg é confirmação
# náusea, diarreia, dor abdominal, anorexia, mialgia, da infecção, podendo ser detectada de duas a 12 se-
# artralgia, fraqueza, alterações comportamentais e per- manas após a exposição ao vírus. Sua negativação,
#
#
#  Trecho aleatório a partir da linha 574:
# 37. Ministério da Saúde (BR). Secretaria de Vigilância
# Available from: https://www.cdc.gov/hepatitis/
# em Saúde. Departamento de Vigilância, Prevenção e
# statistics/2013surveillance/index.htm.
# Controle das Infecções Sexualmente Transmissíveis,
#
#
#  Trecho aleatório a partir da linha 67:
# de transmissão predominantes variam de acordo com
# quais 66% são decorrentes da hepatite B,
# a prevalência da infecção pelo HBV. Em áreas com alta
# 30% da hepatite C e 4% da hepatite A.
# prevalência, a via perinatal e a horizontal por contato
#
# --------------------------------------------------------------------------------
#  gonorreia_protocolo_1txt_protocolo2023txt_protocolo2023.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 256:
# ao agravo. Aquelas cujos resultados forem negativos fatores de risco para a progressão da doença (idade e
# devem ser encaminhadas para vacinação.16,44 histórico familiar de hepatocarcinoma).37,55 A biopsia
# Na infecção pelo HCV a maioria das pessoas infec- hepática pode ser útil para avaliar o grau de agressão
# tadas é assintomática e o rastreamento é feito pela tecidual e para os casos em que seja necessário descar-
# detecção de anticorpos anti-HCV utilizando teste de tar doença hepática de base.57 A definição de terapia
#
#
#  Trecho aleatório a partir da linha 697:
# 67. Duarte G. Extensão da assistência pré-natal ao
# e eventos de saúde pública nos serviços de saúde
# parceiro como estratégia de aumento da adesão
# públicos e privados em todo o território nacional, ao pré-natal e redução da transmissão vertical de
# nos termos do anexo, e dá outras providências infecções. Rev Bras Ginecol Obstet [Internet]. 2007
#
#
#  Trecho aleatório a partir da linha 832:
# Portaria_SCTIE_N42_05_10_2018.pdf [cited 2020 Oct 15]; 84(3):F201-4. Available from:
# https://dx.doi.org/10.1136%2Ffn.84.3.F201
# 89. Jhaveri R, Broder T, Bhattacharya D, Peters MG,
# Kim AY, Jonas MM. Universal screening of pregnant 97. Page CM, Hughes BL, Rhee EHJ, Kuller JA. Hepa-
# women for hepatitis C: the time is now. Clin Infect Dis titis C in pregnancy: review of current knowledge
#
# ⚠️ Padrão suspeito detectado: "\b(pdf|doc|versao|versão|arquivo)\b"
#
# --------------------------------------------------------------------------------
#  hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt — 4088 linhas
#
#  Trecho aleatório a partir da linha 1282:
# tado em condições que assegurem:
# • estabilidade hemodinâmica;
# • parâmetros ventilatórios adequados, com oxigenioterapia;
# • acesso venoso, sem a administração excessiva de líquidos por via endovenosa – EV;
# • controle cardiovascular;
#
#
#  Trecho aleatório a partir da linha 1963:
# aludnâlg
# ,saercnâp
# anfiarap
# orberéc
# ,airátiutip )odagíf
#
#
#  Trecho aleatório a partir da linha 3850:
# sesorivatnaH
# sad
# elortnoC
# e
# oãçneverP
#
# --------------------------------------------------------------------------------
#  hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 344 linhas
#
#  Trecho aleatório a partir da linha 249:
# 11.4. Notificar as autoridades competentes sobre as suspeitas de eventos adversos e queixas técnicas,
# de produtos para a saúde que possam comprometer ou colocar em risco a saúde do usuário -
# Tecnovigilância.
# 12. RESPONSABILIDADES DA GESTÃO MUNICIPAL E DO DISTRITO FEDERAL
# 12.1. Receber e armazenar os insumos em local apropriado, em conformidade com a sua validade,
#
#
#  Trecho aleatório a partir da linha 301:
# incorporar, no âmbito do Sistema Único de Saúde - SUS, o teste rápido imunocromatográfico para
# determinação qualitativa de anticorpos IgM anti-Mycobacterium leprae para diagnóstico complementar de
# hanseníase. Brasília, DF:MS,2021. Disponível em: https://www.gov.br/conitec/pt-
# br/midias/relatorios/portaria/2021/20220103_portaria_84.pdf.
# 7. BRASIL. Ministério da Saúde. Secretária de Atenção Especializada à Saúde. Departamento de
#
# ⚠️ Padrão suspeito detectado: "\b(pdf|doc|versao|versão|arquivo)\b"
#
#
#  Trecho aleatório a partir da linha 130:
# Hanseníase
# Solicitar baciloscopia do raspado
# intradérmico
# Se, IB = 0,0 (Baciloscopia negativa)
# Encaminhar para investigação de contatos
#
# --------------------------------------------------------------------------------
#  hantavirose_manual_1.txt — 5566 linhas
#
#  Trecho aleatório a partir da linha 1229:
# ED
# ODADILOSNOC
# _____________
# :LANOIGER
# ______________________________________________________________:OIPÍCINUM
#
#
#  Trecho aleatório a partir da linha 4167:
# dade, e dá outras providências.
# 6.1.1 sistemas de abastecimento de água e soluções alternativas
# Nas regiões de risco ou na vigência de uma epidemia de cólera, a primeira preocupação das
# autoridades sanitárias deve ser, evidentemente, a preservação da qualidade da água fornecida
# ao público, mediante uma vigilância constante do funcionamento e da administração de toda
#
#
#  Trecho aleatório a partir da linha 3467:
# Cenoura
# cozida 1s 3s NA NA NA
# Couve-de-
# cozida 1d a 2d 3d a 7d NA NA NA
# bruxelas
#
# --------------------------------------------------------------------------------
#  hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt — 2473 linhas
#
#  Trecho aleatório a partir da linha 1585:
# como objetivos:
# • Evitar a infecção de humanos pelo controle dos focos naturais.
# • Reduzir a letalidade e impedir a ocorrência de epidemias.
# • Avaliar continuamente o risco de transmissão para humanos.
# • Impedir a reintrodução da peste urbana através de portos e aeroportos.
#
#
#  Trecho aleatório a partir da linha 1548:
# 8.2.5 Análises nas pulgas
# A identificação das pulgas deve ser realizada diretamente em lâmina com salina ou álcool 70%. O mé-
# todo dispensa a montagem permanente com Bálsamo do Canadá, que destrói os bacilos e impossibilita o
# isolamento da Y. pestis.
# Alguns espécimes devem ser conservados em álcool 70% ou montados pelas técnicas convencionais de
#
#
#  Trecho aleatório a partir da linha 821:
# urinário. Podem também ocorrer lesões arteriolares, determinando obstrução e necrose do segmento atin-
# gido. Evolui com um quadro avassalador: comprometimento de múltiplos órgãos, choque e morte precoce
# se o tratamento não for instalado prontamente, o que justifica a ausência das lesões patológicas típicas da
# doença. A detecção de grandes bacteriemias ao exame do sangue periférico constitui uma manifestação de
# péssimo prognóstico.
#
# --------------------------------------------------------------------------------
#  hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 171 linhas
#
#  Trecho aleatório a partir da linha 7:
# 1. ASSUNTO
# 1.1. Orientações para estados e municípios acerca da realização do 4° Dia “S” – Dia de mobilização
# nacional para realização das buscas ativas (institucional e comunitária) e busca ativa laboratorial, para
# aumentar a sensibilidade da captação de casos suspeitos de sarampo e rubéola em 2025.
# 2. JUSTIFICATIVA E RECOMENDAÇÃO
#
#
#  Trecho aleatório a partir da linha 86:
# Identificar casos primários e elaborar a cadeia de transmissão;
# Identificar casos secundários não detectados na vigilância de rotina;
# Documentar a ausência de sarampo e/ou rubéola em “áreas silenciosas”, onde a
# vigilância de rotina não notificou nenhum caso;
# Fortalecer a vigilância epidemiológica, como parte das atividades de resposta a um
#
#
#  Trecho aleatório a partir da linha 93:
# encerramento de um surto de sarampo ou rubéola. Nesse caso, a busca deve ser realizada
# após 12 semanas (três meses) a partir da data de início do exantema do último caso
# confirmado.
# Observação: o fato de aguardar 12 semanas, a partir da data de início do exantema do último caso
# confirmado, permite:
#
# --------------------------------------------------------------------------------
#  hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt — 2245 linhas
#
#  Trecho aleatório a partir da linha 768:
# CONDIÇÕES CRÔNICAS E INFECÇÕES
# SEXUALMENTE TRANSMISSÍVEIS
# Quadro 2 – Situações que podem gerar resultados falso-reagentes nos testes não
# treponêmicos
# Situações que podem gerar resultados Situações que podem gerar resultados
#
#
#  Trecho aleatório a partir da linha 610:
# complementar), para o monitoramento da resposta ao tratamento e para o controle
# de cura (BRASIL, 2020; LARSEN; STEINER; RUDOLPH, 1995; WORKOWSKI; BOLAN, 2015).
# Os testes não treponêmicos detectam anticorpos IgM e IgG anticardiolipina não
# específicos para T. pallidum. A cardiolipina consiste em material liberado pelas células
# humanas danificadas em decorrência da sífilis, e também pelo treponema durante a sua
#
#
#  Trecho aleatório a partir da linha 1436:
# Doenças de Condições Crônicas e Infecções Sexualmente Transmissíveis. Protocolo
# Clínico e Diretrizes Terapêuticas para Prevenção da Transmissão Vertical do HIV,
# Sífilis e Hepatites Virais. Brasília, DF: Ministério da Saúde, 2019a.
# BRASIL. Ministério da Saúde. Secretaria de Vigilância em Saúde. Coordenação-Geral
# de Desenvolvimento da Epidemiologia em Serviços. Guia de Vigilância em Saúde:
#
# --------------------------------------------------------------------------------
#  hepatites_protocolo_1.txt — 3811 linhas
#
#  Trecho aleatório a partir da linha 2765:
# 4. Xerox da carteira do conselho do responsável técnico pela empresa;
# 5. O pagamento da taxa, prevista na Lei Nº 15.838, de 27/07/2015, através de DAE,
# retirado no site da Fazenda estadual www.sefaz.ce.gov.br (serviços online → DAE →
# emissão de DAE – taxas )
# • Análise de testemunho
#
#
#  Trecho aleatório a partir da linha 934:
# Método: RT-PCR em tempo real
# Material: 2,0 mL de soro
# Critérios de Rejeição de Amostras: Amostras sem identificação ou com identificação
# ilegível; Amostras sem o acompanhamento da ficha de notificação.
# Período da Coleta: Coletar até o 5º dia do início dos sintomas.
#
#
#  Trecho aleatório a partir da linha 3103:
# a) identificar a amostra no saco plástico para evitar troca do mesmo;
# b) lavar as mãos com água e sabão;
# c) desenrolar o swab e amarrar o cordão em arbustos, árvores ou cercas, longe dos
# curiosos;
# d) deixar os swabs por três (3) dias ou setenta e duas horas (72 h);
#
# --------------------------------------------------------------------------------
#  hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt — 3811 linhas
#
#  Trecho aleatório a partir da linha 2918:
# deve ser encarado como uma fonte de informações quanto ao padrão de identidade e
# qualidade do produto analisado das unidades amostrais, que possibilitará, caso necessário,
# uma ação da Vigilância Sanitária.
# 3.1. Cuidados na amostragem
# A amostragem de um produto deve resultar em uma amostra que preserve suas
#
#
#  Trecho aleatório a partir da linha 2246:
# Procedimento para coleta
#  Solicite ao paciente para retrair o prepúcio;
#  Limpe a secreção emergente com gaze estéril;
#  Introduza o swab alginatado, cerca de 2 cm, no canal uretral, atravessando a fossa
# navicular;
#
#
#  Trecho aleatório a partir da linha 3797:
# TC: AMOSTRA:
# ( ) Incompleto ( ) Amostra violada
# ( ) Incorreto ( ) Acondicionamento inadequado
# ( ) Ilegível ( ) Identificação incorreta
# ( ) Quantidade/Volume insuficientes
#
# --------------------------------------------------------------------------------
#  herpes_genital_protocolo_1txt_protocolo2023txt_protocolo2023.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 293:
# para determinadas populações, a comodidade posoló-
# hepatite B até o ano 2030.6,63
# gica, o controle mais acessível e o custo. A terapia tem
# As orientações e cuidados com as pessoas usuárias
# como objetivo a resposta virológica sustentada, que
#
#
#  Trecho aleatório a partir da linha 384:
# Notas: a) HBsAg – antígeno de superfície do HBV; b) HBV – vírus da hepatite B; c) HBeAg – antígeno “e” do HBV; d) Iniciar terapia prolongada com fumarato de tenofovir desoproxila, pois entecavir
# não é seguro para lactante.80,81
# Figura 4 – Algoritmo das intervenções preventivas para prevenção da transmissão vertical do vírus da hepatite B
# calendário de duas doses adicionais administradas no avaliação entre 30 e 60 dias após a última dose da va-
# segundo e sexto meses de vida do recém-nascido.83-85 cina anti-HBV.74
#
#
#  Trecho aleatório a partir da linha 864:
# ridou M, Pavlopoulou I, Nicolaidou P, et al. Mother Effects of mode of delivery and infant feeding on
# to child transmission of hepatitis C virus: rate of the risk of mother-to-child transmission of hepa-
# infection and risk factors. Scand J Infect Dis [Inter- titis C virus. BJOG [Internet]. 2001 Apr [cited 2020
# net]. 2005 [cited 202 Oct 15]; 37(5):350-3. Available Oct 15]; 108(4):371-7. Available from: https://
# from: https://doi.org/10.1080/00365540510032105 doi.org/10.1111/j.1471-0528.2001.00088.x
#
# --------------------------------------------------------------------------------
#  herpes_genital_protocolo_1.txt — 896 linhas
#
#  Trecho aleatório a partir da linha 118:
# baixa em pessoas com hábitos heterossexuais, ela se
# -se na detecção de marcadores sorológicos (antígenos
# eleva entre aquelas com grande número de parcerias
# virais e anticorpos específicos) e molecular (ácido
# sexuais ou que praticam sexo anal.21
#
#
#  Trecho aleatório a partir da linha 231:
# (anti-HBc IgG negativos), a presença de anticorpos an-
# necessidade de terapia medicamentosa. O tratamento
# ti-HBs indica imunidade pela resposta vacinal contra
# da forma crônica da hepatite B tem como principal
# a hepatite B.51
#
#
#  Trecho aleatório a partir da linha 29:
# Epidemiol. Serv. Saude, Brasília, 30(Esp.1):e2020834, 2021 1
# Hepatites virais
# Apresentação O vírus da hepatite A (hepatitis A virus, HAV) perten-
# ce à família Picornaviridae e seu genoma é composto
# As hepatites virais constituem um dos temas que
#
# --------------------------------------------------------------------------------
#  hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt — 171 linhas
#
#  Trecho aleatório a partir da linha 32:
# demais ações pertinentes frente à identificação de casos suspeitos), em tempo oportuno, para evitar a
# ocorrência de um surto e aparecimento de casos secundários.
# 3.3. As nomenclaturas que deverão ser utilizadas foram estabelecidas pela OPAS e padronizadas
# na Região das Américas, conforme a seguir:
# a)Busca Ativa Institucional (BAI): revisão sistemática de prontuários clínicos em
#
#
#  Trecho aleatório a partir da linha 103:
# 6.1. Recomenda-se a realização das buscas ativas em todos os municípios, porém, havendo
# alguma impossibilidade temporária, deve-se empregar os seguintes critérios de priorização, que se
# Nota Técnica Conjunta 197 (0047742253) SEI 25000.071730/2025-82 / pg. 2
# referem a eventos ocorridos no último ano. A presença de um único critério equivale a um ponto. Prioriza-
# se os municípios e/ou áreas que acumularem as maiores pontuações (pontuação máxima: 8 pontos).
#
#
#  Trecho aleatório a partir da linha 131:
# suspeitos detalhados anteriormente, com amostras clínicas coletadas entre 02/06 a
# 17/06/2025
# ...
# Sarampo/Rubéola.
# Investigação
#
# --------------------------------------------------------------------------------
#  sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023.txt — 171 linhas
#
#  Trecho aleatório a partir da linha 23:
# Intergestora Tripartite (CIT).
# 3. BUSCA ATIVA DE CASOS SUSPEITOS DE SARAMPO E RUBÉOLA
# 3.1. A busca ativa é uma estratégia fundamental na vigilância do sarampo e da rubéola. É definida
# como uma ação que permite avaliar a sensibilidade dos sistemas de vigilância, por meio da captação
# precoce de casos suspeitos, que não acessaram o sistema de saúde ou que não foram detectados pelo
#
#
#  Trecho aleatório a partir da linha 65:
# notificar casos suspeitos que podem não ter sido identificados na rotina da vigilância passiva.
# Adicionalmente, orientam a população sobre os sinais e sintomas e a importância do diagnóstico precoce.
# 4.3. Na BAI, os profissionais de saúde são orientados a resgatar os registros de atendimentos dos
# últimos 30 dias nos serviços de saúde, a fim de identificar se algum indivíduo atendeu à definição de caso
# suspeito de sarampo e rubéola e não foi notificado.
#
#
#  Trecho aleatório a partir da linha 68:
# últimos 30 dias nos serviços de saúde, a fim de identificar se algum indivíduo atendeu à definição de caso
# suspeito de sarampo e rubéola e não foi notificado.
# 4.4. Os profissionais dos Laboratórios Centrais de Saúde Pública (LACEN) são orientados a
# selecionar amostras com resultados negativos para arboviroses dos últimos 15 dias e realizar sorologia de
# sarampo e rubéola em amostras de pacientes que apresentaram sintomas clínicos compatíveis com a
#
# --------------------------------------------------------------------------------
#  tuberculose_protocolo_2.txt — 167 linhas
#
#  Trecho aleatório a partir da linha 55:
# 10º Orientar ao paciente para inspirar profundamente, reter o ar por alguns segundos e
# expirar. Repetir esses procedimentos três vezes e tossir profundamente;
# 11º Imediatamente após o ato da tosse produtiva, o paciente deverá expectorar a
# secreção dentro do coletor sem encostar os lábios ou tocar a parte interna com os
# dedos, pois há o risco de contaminação da amostra;
#
#
#  Trecho aleatório a partir da linha 86:
# flora bucal. Não utilizar creme dental ou antisséptico bucal;
# 8º Abrir o frasco, tirando a tampa e colocando-a virada para cima;
# 9º Preparar a solução salina 3% e realizar a nebulização durante 5-20 minutos. Ao final,
# pedir ao paciente para tossir e expectorar no coletor sem encostar os lábios ou tocar
# a parte interna com os dedos, pois há o risco de contaminação da amostra (Figura
#
#
#  Trecho aleatório a partir da linha 62:
# Fonte: Ministério da Saúde.Guia de Orientações para coleta de escarro, 2014.
# Publicação: Portaria nº 213, de 09 de outubro de 2023 – Boletim de Serviço nº 409, de 26 de outubro de 2023.
# Tipo do POP.DENF.032 – Página 3/5
# PROCEDIMENTO / ROTINA
# Documento
#
# --------------------------------------------------------------------------------
#  tuberculose_protocolo_12txt_protocolo2023txt_protocolo2023.txt — 1173 linhas
#
#  Trecho aleatório a partir da linha 1091:
# inclusive nos finais de semana.
# 41
# 8 SISTEMA DE INFORMAÇÃO E
# NOTIFICAÇÃO
# Todos os casos confirmados de tuberculose devem ser notificados no Sistema
#
#
#  Trecho aleatório a partir da linha 78:
# Figura 6 – Algoritmo para avaliação da resistência nos casos de retratamento de
# tuberculose, baseado no TRM-TB ....................................23
# LISTA DE QUADROS
# Quadro 1 – Indicação de tratamento da ILTB ...................................12
# Quadro 2 – Esquema de tratamento da ILTB ...................................13
#
# ⚠️ Padrão suspeito detectado: "\.{5,}"
#
#
#  Trecho aleatório a partir da linha 343:
# torno do qual a avaliação de contato é centrada, embora nem sempre cor-
# responda ao caso fonte (caso infectante).
# Caso fonte: é o caso infectante, não necessariamente o primeiro caso
# identificado (caso índice).
# Contato: toda pessoa que foi exposta ao caso índice ou caso fonte, no mo-
#
# --------------------------------------------------------------------------------
#  tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 1482:
# a aossep
# ed
# oterid
# otatnoc
# rop
#
#
#  Trecho aleatório a partir da linha 2016:
# 53 Especifique Intervalo de Tempo
# Menor de 5 anos | | 1 - Em até 72 horas
# | | 2- Após 72 horas
# | | 9- Ignorado
# 4 - Data da Última Dose da
#
#
#  Trecho aleatório a partir da linha 1581:
# edadilibissimsnart
# áh oãN
# ,saesuán
# ,aierraid
# ,aielafec
#
# --------------------------------------------------------------------------------
#  tetano_nota_tecnica_1txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 1462:
# olep
# avilas
# ad
# sanames
# 2 saneuqep
#
#
#  Trecho aleatório a partir da linha 860:
# vertical, em recipientes plásticos com tampa de rosca.
# Transporte: Encaminhar o mais rápido possível ao Lacen/PR, em caixa de isopor à temperatura ambiente, em
# no máximo 24 horas após a coleta.
# Importante: Amostras devem ser coletadas também de pacientes convalescentes e de contatos.
# Identificar se o material é de doente, controle pós-tratamento, convalescente ou de contatos.
#
#
#  Trecho aleatório a partir da linha 2669:
# AÇÃO
# em pacientes internados (leito regular e/ou UTI), óbitos e/ou pessoas com Doença
# Respiratória Aguda (DRA) com história de contato com suínos e/ou aves.
# Notificar no SINAN Influenza Web os casos de pacientes:
# • Internados com SRAG em leitos regulares e/ou UTI
#
# --------------------------------------------------------------------------------
#  varicela_nota_tecnica_1txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 3265:
# Dados Complementares do Caso
# 31Data da Investigação 32Ocupação
# | | | || | | |
# socigóloimedipEsetnedecetnA
# FICHA DE INVESTIGAÇÃO MENINGITE
#
#
#  Trecho aleatório a partir da linha 2673:
# • Internados com SRAG em leitos regulares e/ou UTI
# • Casos de óbitos por SRAG
# Notificar no Formulário de Notificação de Risco para a Saúde Pública Nacional:
# http://formsus.datasus.gov.br/site/formulario.php?idaplicacao=5376.
# Descrição da ação
#
#
#  Trecho aleatório a partir da linha 2123:
# | | Tríplice Viral (sarampo, caxumba e rubéola) Rubéola (monovalente) Dupla Viral (sarampo, rubéola)
# 46Data da Última Dose da Vacina 47Sinais e Sintomas
# | | | | | | | 1 - Apresentou Sintomas de Rubéola 2 - Não Apresentou Sintomas de Rubéola 9 - Ignorado
# 48 Período da Gestação em que foi Acometida/Exposta
# 1 - 1º Trimestre 2 - 2º Trimestre 3 - 3º Trimestre 9 - Ignorado
#
# --------------------------------------------------------------------------------
#  varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt — 4499 linhas
#
#  Trecho aleatório a partir da linha 2457:
# Se circularem, usar máscara cirúrgica. Limitar aglomeração, considerando a possibilidade de servir refeição no quarto.
# Restringir movimentação dos profissionais que atuam em áreas onde há doentes para áreas não atingidas pelo surto.
# Evitar novas admissões ou transferência de sintomáticos.
# 70 GUIA RÁPIDO INFLUENZA
# 4.3 DIAGNÓSTICO DIFERENCIAL DA INFLUENZA
#
#
#  Trecho aleatório a partir da linha 3727:
# 99
# 7.2 PERÍODO DE INCUBAÇÃO E CLASSIFICAÇÃO
# POR GRAU DE GRAVIDADE
# Identificar o foco tetânico é fundamental para estabelecer o período de incubação e progressão da doença.
# CLASSIFICAÇÃO
#
#
#  Trecho aleatório a partir da linha 3011:
# Duas doses: aos 2 e 4 meses + um reforço aos 12 meses.
# Vacina Meningocócica C conjugada: (Meningo C).
# Duas doses: aos 3 e 5 meses + um reforço aos 12 meses.
# 5.4.3 Esquema vacinal preventivo para meningites – adulto/idoso
# Vacina Pneumocócica 23 valente:
#
# --------------------------------------------------------------------------------
#  virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023.txt — 5266 linhas
#
#  Trecho aleatório a partir da linha 1884:
# informação no primeiro contato realizado durante a fase de monitoramento. O CPF é a chave única
# para vincular registros no sistema e-SUS Notifica, permitindo recuperar informações provenientes,
# por exemplo, dos exames realizados em laboratórios da rede privada (Brasil, 2022c).
# GUIA DE VIGILÂNCIA INTEGRADA DA COVID-19, INFLUENZA E OUTROS
# 51
#
#
#  Trecho aleatório a partir da linha 5262:
# SECRETARIA DE VIGILÂNCIA EM SAÚDE E AMBIENTE
# 146
# MINISTÉRIO DA SAÚDE
# Biblioteca Virtual em Saúde do Ministério da Saúde
# bvsms.saude.gov.br
#
#
#  Trecho aleatório a partir da linha 1155:
# Dessa forma, em 13 de maio de 2022, foi publicada a Portaria GM/MS n.º 1.102, que incluiu, além da
# covid-19, a SG suspeita de covid, a Srag por SARS-CoV-2, a síndrome inflamatória multissistêmica
# pediátrica (SIM-P) e a síndrome inflamatória multissistêmica em adultos (SIM-A) na Lista Nacional
# de Notificação Compulsória, exigindo a sua notificação compulsória e imediata no sistema de
# informação correspondente (Brasil, 2022e).
#
# --------------------------------------------------------------------------------
#  virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt — 5266 linhas
#
#  Trecho aleatório a partir da linha 3280:
# todos os casos de SG que tenham condições e fatores de risco para complicações, independentemente
# da situação vacinal, mesmo em atendimento ambulatorial.
# Essa indicação fundamenta-se no benefício que a terapêutica precoce proporciona, tanto na redução
# da duração dos sintomas quanto na ocorrência de complicações da infecção pelos vírus da influenza,
# em pacientes com condições e fatores de risco para complicações.
#
#
#  Trecho aleatório a partir da linha 1852:
# Essa estratégia se torna mais efetiva quanto menor for o número de casos no território, devido ao
# fato de que, em locais com elevada incidência, os esforços das equipes de saúde estarão voltados,
# principalmente, para impedir o esgotamento dos serviços de saúde. Nessa situação, recomenda-se
# que o rastreamento e o monitoramento de contatos sejam realizados conforme a capacidade local,
# priorizando-se os locais com populações em maior risco para desenvolvimento de doença grave,
#
#
#  Trecho aleatório a partir da linha 3977:
# CONTRAINDICAÇÃO
# a. Menores de 6 meses de idade.
# b. Indivíduos que, após vacinação anterior, apresentaram hipersensibilidade imediata (reação anafilática).
# 3.7.2 MEDIDAS NÃO FARMACOLÓGICAS
# PRECAUÇÕES-PADRÃO
#
# --------------------------------------------------------------------------------
#  zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt — 3811 linhas
#
#  Trecho aleatório a partir da linha 2654:
# perito da empresa.
# 1.1.8. Laudo de análise
# Documento emitido pelo laboratório oficial, em que constam os resultados e a conclusão
# da análise fiscal/orientação, conforme disposto na legislação pertinente.
# 1.1.9. Laboratório oficial
#
#
#  Trecho aleatório a partir da linha 2719:
# quando resultarem provadas, em análises laboratoriais ou no exame de processos, ações
# fraudulentas que impliquem em falsificação ou adulteração (art.10, inciso II e III, Lei nº
# 6.437/77). O termo de coleta deve informar se o produto está interditado, a causa da
# interdição e a suspeita de irregularidades. Quanto ao tempo de duração da interdição do
# produto e do estabelecimento, a medida cautelar confere um espaço de tempo necessário
#
#
#  Trecho aleatório a partir da linha 93:
# resultados questionáveis .............................................................................................. 71
# 4. Critérios de rejeição de amostras clínicas enviadas ao laboratório de microbiologia71
# 5. Modelo de requisição de análise microbiológica e identificação de amostras .......... 72
# 6. Transporte das amostras .............................................................................................. 73
# 7. Exames microbiológicos realizados no LACEN-CE ....................................................... 73
#
# ⚠️ Padrão suspeito detectado: "\.{5,}"
#
# --------------------------------------------------------------------------------
#  zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt — 3811 linhas
#
#  Trecho aleatório a partir da linha 1391:
# LACEN.
# b) Sorologia para Zika IgG
# Método: Ensaio Imunoenzimático - ELISA
# Material: 2,0 mL de soro ou líquor
# Período da Coleta: A partir do 30º dia do início dos sintomas. As amostras devem ser
#
#
#  Trecho aleatório a partir da linha 594:
# manga longa com elástico no punho, comprimento mínimo na altura dos joelhos,
# abertura frontal e de tecido preferencialmente de algodão ou tecido não inflamável;
# (Figura 13)
# Figura 13
#  Luvas: para coleta, manuseio e acondicionamento de materiais biológicos; pode ser de
#
#
#  Trecho aleatório a partir da linha 3520:
# Data da entrada no LACEN: ______/______/_____ Hora de entrada:______________
# Nº do protocolo: Bacteriológico________________ Físico-químico:_______________
# Responsável pelo recebimento da amostra no LACEN ______________________________
# 2. ENSAIOS SOLICITADOS:
# MICROBIOLÓGICO: ( ) FÍSICO-QUÍMICO: ( ) OUTROS: ( )
#
# --------------------------------------------------------------------------------
#  zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt — 4876 linhas
#
#  Trecho aleatório a partir da linha 1958:
# regional/estadual em caixas apropriadas para acondicionamento de lâminas.
# Pesquisa de flebotomíneos
# Consiste na aplicação de técnicas de coleta de flebotomíneos, visando à realização de atividades
# entomológicas que compreendem a investigação, o levantamento e/ou o monitoramento entomo-
# lógico. Cada uma das atividades tem objetivos específicos constantes no Manual de Vigilância e
#
#
#  Trecho aleatório a partir da linha 770:
# adotar também as ações de controle, a fim de reduzir ou eliminar os casos humanos.
# 1.5.1 Ações de vigilância e prevenção
# 1. Realizar a Vigilância Entomológica (implementação de estudos bioecológicos das espécies
# apontadas como vetoras).
# 2. Realizar a pesquisa entomológica nos focos e o monitoramento entomológico por meio de
#
#
#  Trecho aleatório a partir da linha 3485:
# responsável pela inspeção zoossanitária realizar a interlocução pertinente.
# 5.1.3 Procedimentos
# 5.1.3.1 Triagem das solicitações
# As solicitações para realizar a inspeção zoossanitária devem ser triadas por pertinência e prioridade
# e, após avaliação de necessidade de visita ao local, estabelecer roteiros segundo rotina operacional
#
# --------------------------------------------------------------------------------
#  zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt — 4876 linhas
#
#  Trecho aleatório a partir da linha 3559:
# ao Estado (Poder Executivo), bem como a outros setores da sociedade.
# A área de vigilância de zoonoses deve propor, articular, apoiar, colaborar e realizar parcerias
# sistemáticas formais ou informais, intra e interinstitucionais, com órgãos e instituições públicas e
# privadas, visando às ações de interface entre a saúde humana, a saúde animal e o meio ambiente,
# para viabilizar o cumprimento das atribuições legais e o desenvolvimento de atividades conjuntas
#
#
#  Trecho aleatório a partir da linha 1248:
# Nos laboratórios e na sala de Jaleco, luva impermeável, calça, calçado, máscara, óculos de segurança,
# bioensaio. cestos de lixo segregados para descarte apropriado de materiais, entre
# outros.
# Preparo e aplicação de Luvas impermeáveis, óculos de segurança, respirador e purificador de ar, bota
# inseticida impermeável de cano médio, bota impermeável com prolongamento até a
#
#
#  Trecho aleatório a partir da linha 4540:
# CAMPINAS (São Paulo). Prefeitura Municipal de Campinas. Secretaria Municipal de Saúde.
# Manual de controle integrado de pragas. Disponível em: <http://campinas.sp.gov.br/sa/
# impressos/adm/FO086.pdf>. Acesso em: 15 ago. 2014.
# CARDOSO, J. L. C. Animais peçonhentos no Brasil. 2. ed. São Paulo: Sarvier, 2009.
# CHAPMAN, A. S et al. Diagnosis and management of tickborne rickettsial diseases: rocky
#
# ⚠️ Padrão suspeito detectado: "\b(pdf|doc|versao|versão|arquivo)\b"
#
# --------------------------------------------------------------------------------
#
# ✅ Verificação finalizada.

# %% [markdown]
# # Correção final de resíduos e geração de log
#
# **Objetivo:**
# Executar uma limpeza criteriosa dos arquivos finais de texto (.txt) que foram previamente organizados, eliminando linhas e trechos residuais resultantes da conversão de PDF ou erros comuns de digitalização. A etapa também registra todas as ocorrências em um log estruturado para posterior auditoria.
#
# **O que o script faz:**
# Percorre todas as subpastas de corpus_final, onde estão os textos separados por doença ou tema.
#
# Em cada arquivo .txt, realiza as seguintes ações:
#
# - Remove linhas contendo:
#
# - links
#
# - rodapés de documentos
#
# - assinaturas eletrônicas
#
# - datas soltas
#
# - códigos técnicos
#
# - sequências de símbolos ou pontos
#
# - linhas com apenas números ou brancos
#
# - Corrige pequenos resíduos (ex: espaços duplicados, travessões irregulares).
#
# - Cria uma nova estrutura espelhada em textos_corrigidos, onde salva os arquivos processados.
#
# - Gera um log detalhado em CSV, que inclui:
#
# - Nome do arquivo
#
# - Quantidade de linhas removidas
#
# - Padrões suspeitos detectados
#
# - Caminho do arquivo original
#
# - Caminho do arquivo corrigido

# %%
# === CONFIGURAÇÃO DE CAMINHOS === #
PASTA_ORIGEM = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"
PASTA_DESTINO = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos"
CAMINHO_LOG = os.path.join(PASTA_DESTINO, 'log_correcoes.csv')
os.makedirs(PASTA_DESTINO, exist_ok=True)

# === PADRÕES SUSPEITOS A REMOVER === #
PADROES_LINHAS_REMOVER = [
    r'https?:\/\/\S+',                                # links
    r'documento assinado eletronicamente',            # assinatura eletrônica
    r'nota técnica \d+',                              # rodapés duplicados
    r'código\s+crc\s+\w+',                            # códigos SEI
    r'pg\.?\s*\d+',                                   # "pg. 3"
    r'página\s+\d+\s+de\s+\d+',                       # "Página 3 de 12"
    r'^\s*$',                                         # linhas em branco
    r'^[\W_]{10,}$',                                  # linhas com só símbolos
    r'^[0-9]+[ \t]+[0-9]+$',                          # duas colunas numéricas soltas
    r'^\d{2}/\d{2}/\d{4}$',                           # datas soltas
    r'\.{4,}',                                        # sequência de pontos
]

# === FUNÇÃO DE LIMPEZA E LOG DE OCORRÊNCIAS === #
def limpar_texto(texto, arquivo_nome):
    linhas = texto.splitlines()
    linhas_corrigidas = []
    removidas = 0
    padroes_detectados = set()

    for linha in linhas:
        linha_original = linha
        for padrao in PADROES_LINHAS_REMOVER:
            if re.search(padrao, linha, re.IGNORECASE):
                padroes_detectados.add(padrao)
                linha = ''
                break

        linha = re.sub(r'[ \t]+', ' ', linha)
        linha = re.sub(r'–', '-', linha)
        linha = re.sub(r'_+', '_', linha)
        linha = linha.strip()
        if linha:
            linhas_corrigidas.append(linha)
        else:
            removidas += 1

    texto_corrigido = '\n'.join(linhas_corrigidas)
    return texto_corrigido, removidas, list(padroes_detectados)

# === CRIAR/ESCREVER O CSV DE LOG === #
with open(CAMINHO_LOG, 'w', newline='', encoding='utf-8') as log_file:
    writer = csv.writer(log_file)
    writer.writerow(['Arquivo', 'Linhas Removidas', 'Padrões Detectados', 'Original', 'Corrigido'])

    print("\n🔧 Iniciando correção e comparação...")

    for subpasta in os.listdir(PASTA_ORIGEM):
        caminho_sub = os.path.join(PASTA_ORIGEM, subpasta)
        if os.path.isdir(caminho_sub):
            nova_sub = os.path.join(PASTA_DESTINO, subpasta)
            os.makedirs(nova_sub, exist_ok=True)

            for arquivo in os.listdir(caminho_sub):
                if arquivo.endswith(".txt"):
                    caminho_arquivo = os.path.join(caminho_sub, arquivo)

                    with open(caminho_arquivo, 'r', encoding='utf-8', errors='ignore') as f:
                        original = f.read()

                    # Corrigir e registrar padrões encontrados
                    corrigido, linhas_removidas, padroes = limpar_texto(original, arquivo)

                    # Salvar texto corrigido
                    caminho_corrigido = os.path.join(nova_sub, arquivo)
                    with open(caminho_corrigido, 'w', encoding='utf-8') as f_out:
                        f_out.write(corrigido)

                    print(f"✅ Corrigido: {arquivo} | Linhas removidas: {linhas_removidas}")

                    # Escrever no log
                    writer.writerow([arquivo, linhas_removidas, '; '.join(padroes), caminho_arquivo, caminho_corrigido])

print("\n Log salvo em:", CAMINHO_LOG)
print(" Todos os textos foram processados e corrigidos.")
# Out:
# 🔧 Iniciando correção e comparação...
# ✅ Corrigido: adenovirus_guia_1txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: adenovírus_guia_1.txt | Linhas removidas: 244
# ✅ Corrigido: arboviroses_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: arboviroses_nota_técnica_1.txt | Linhas removidas: 1
# ✅ Corrigido: cancro_mole_protocolo_1.txt | Linhas removidas: 70
# ✅ Corrigido: cancro_mole_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: chikungunya_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: chikungunya_nota_técnica_1.txt | Linhas removidas: 1
# ✅ Corrigido: chikungunya_protocolo_1.txt | Linhas removidas: 42
# ✅ Corrigido: chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 42
# ✅ Corrigido: chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: chikungunya_protocolo_2.txt | Linhas removidas: 93
# ✅ Corrigido: chikungunya_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: chikungunya_protocolo_3.txt | Linhas removidas: 33
# ✅ Corrigido: chikungunya_protocolo_3txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 33
# ✅ Corrigido: clamidia_protocolo_1txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: clamidia_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 7
# ✅ Corrigido: coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 7
# ✅ Corrigido: coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 7
# ✅ Corrigido: coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 7
# ✅ Corrigido: coqueluche_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: coqueluche_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: coqueluche_nota_tecnica_3txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: covid-19_guia_1.txt | Linhas removidas: 244
# ✅ Corrigido: covid-19_nota_técnica_1.txt | Linhas removidas: 1
# ✅ Corrigido: covid_19_guia_1txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: colera_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: colera_protocolo_1txt_protocolo2023.txt | Linhas removidas: 99
# ✅ Corrigido: colera_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 4
# ✅ Corrigido: colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 4
# ✅ Corrigido: colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 4
# ✅ Corrigido: dengue_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: dengue_protocolo_1.txt | Linhas removidas: 11
# ✅ Corrigido: dengue_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 11
# ✅ Corrigido: dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: dengue_protocolo_2.txt | Linhas removidas: 42
# ✅ Corrigido: dengue_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 42
# ✅ Corrigido: dengue_protocolo_3.txt | Linhas removidas: 93
# ✅ Corrigido: dengue_protocolo_3txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: dengue_protocolo_4.txt | Linhas removidas: 33
# ✅ Corrigido: dengue_protocolo_4txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 33
# ✅ Corrigido: difteria_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: entre_outras_protocolo_1.txt | Linhas removidas: 93
# ✅ Corrigido: entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: entre_outras_protocolo_2.txt | Linhas removidas: 93
# ✅ Corrigido: entre_outras_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: febre_amarela_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: febre_amarela_protocolo_1.txt | Linhas removidas: 63
# ✅ Corrigido: febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 63
# ✅ Corrigido: febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: febre_amarela_protocolo_2.txt | Linhas removidas: 22
# ✅ Corrigido: febre_amarela_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 22
# ✅ Corrigido: febre_amarela_protocolo_3.txt | Linhas removidas: 22
# ✅ Corrigido: febre_amarela_protocolo_3txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 22
# ✅ Corrigido: febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: gonorreia_protocolo_1.txt | Linhas removidas: 70
# ✅ Corrigido: gonorreia_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: hanseniase_diretriz_nacional_1txt_documento2023.txt | Linhas removidas: 9
# ✅ Corrigido: hanseniase_diretriz_nacional_1txt_documento2023txt_documento2023.txt | Linhas removidas: 9
# ✅ Corrigido: hanseniase_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 23
# ✅ Corrigido: hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 23
# ✅ Corrigido: hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 23
# ✅ Corrigido: hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 23
# ✅ Corrigido: hanseniase_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 12
# ✅ Corrigido: hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 12
# ✅ Corrigido: hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 12
# ✅ Corrigido: hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 12
# ✅ Corrigido: hanseniase_protocolo_1txt_protocolo2023.txt | Linhas removidas: 10
# ✅ Corrigido: hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 4
# ✅ Corrigido: hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 4
# ✅ Corrigido: hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 4
# ✅ Corrigido: hanseniase_protocolo_2txt_protocolo2023.txt | Linhas removidas: 69
# ✅ Corrigido: hanseniase_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 69
# ✅ Corrigido: hanseniase_protocolo_3txt_protocolo2023.txt | Linhas removidas: 69
# ✅ Corrigido: hanseniase_protocolo_3txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 69
# ✅ Corrigido: hantavirose_manual_1.txt | Linhas removidas: 40
# ✅ Corrigido: hantavirose_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 40
# ✅ Corrigido: hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: hantavirose_manual_2.txt | Linhas removidas: 17
# ✅ Corrigido: hantavirose_manual_2txt_manual2023txt_manual2023.txt | Linhas removidas: 17
# ✅ Corrigido: hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 17
# ✅ Corrigido: hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 17
# ✅ Corrigido: hepatite_a_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hepatite_a_protocolo_1.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_b_e_c_(ist)_protocolo_1.txt | Linhas removidas: 70
# ✅ Corrigido: hepatite_b_e_c_ist_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: hepatite_b_protocolo_1.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_c_protocolo_1.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_d_(delta)_nota_técnica_1.txt | Linhas removidas: 7
# ✅ Corrigido: hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 7
# ✅ Corrigido: hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 7
# ✅ Corrigido: hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 7
# ✅ Corrigido: hepatite_d_protocolo_1.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_e_protocolo_1.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 192
# ✅ Corrigido: hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 68
# ✅ Corrigido: hepatites_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: hepatites_protocolo_1.txt | Linhas removidas: 93
# ✅ Corrigido: hepatites_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: herpes_genital_protocolo_1.txt | Linhas removidas: 70
# ✅ Corrigido: herpes_genital_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: hiv_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hpv_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: hpv_protocolo_1.txt | Linhas removidas: 70
# ✅ Corrigido: hpv_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: influenza_guia_1.txt | Linhas removidas: 244
# ✅ Corrigido: influenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: influenza_guia_2.txt | Linhas removidas: 18
# ✅ Corrigido: influenza_guia_2txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 18
# ✅ Corrigido: influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 18
# ✅ Corrigido: influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 18
# ✅ Corrigido: leishmaniose_manual_1.txt | Linhas removidas: 99
# ✅ Corrigido: leishmaniose_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 99
# ✅ Corrigido: leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 102
# ✅ Corrigido: leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 102
# ✅ Corrigido: leptospirose_manual_1.txt | Linhas removidas: 146
# ✅ Corrigido: leptospirose_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: leptospirose_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_3txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: leptospirose_protocolo_1.txt | Linhas removidas: 93
# ✅ Corrigido: leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: linfogranuloma_venereo_protocolo_1txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: linfogranuloma_venereo_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: m._abscessus_protocolo_1.txt | Linhas removidas: 20
# ✅ Corrigido: m._kansasii_protocolo_1.txt | Linhas removidas: 20
# ✅ Corrigido: m_abscessus_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 20
# ✅ Corrigido: m_kansasii_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 20
# ✅ Corrigido: malaria_manual_1txt_manual2023.txt | Linhas removidas: 4
# ✅ Corrigido: malaria_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 4
# ✅ Corrigido: malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 4
# ✅ Corrigido: malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 4
# ✅ Corrigido: malaria_protocolo_1txt_protocolo2023.txt | Linhas removidas: 18
# ✅ Corrigido: malaria_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 18
# ✅ Corrigido: meningite_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 6
# ✅ Corrigido: meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 6
# ✅ Corrigido: meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 6
# ✅ Corrigido: meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 6
# ✅ Corrigido: metapneumovirus_guia_1txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023.txt | Linhas removidas: 20
# ✅ Corrigido: micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 20
# ✅ Corrigido: outras_zoonoses_transmitidas_por_roedores_manual_1.txt | Linhas removidas: 146
# ✅ Corrigido: outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: parainfluenza_guia_1.txt | Linhas removidas: 244
# ✅ Corrigido: parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: peste_manual_1.txt | Linhas removidas: 40
# ✅ Corrigido: peste_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 40
# ✅ Corrigido: peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 146
# ✅ Corrigido: peste_manual_2.txt | Linhas removidas: 17
# ✅ Corrigido: peste_manual_2txt_manual2023txt_manual2023.txt | Linhas removidas: 17
# ✅ Corrigido: peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 17
# ✅ Corrigido: peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 17
# ✅ Corrigido: poliomielite_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_3txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: poliomielite_protocolo_1.txt | Linhas removidas: 25
# ✅ Corrigido: poliomielite_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 25
# ✅ Corrigido: raiva_humana_protocolo_1.txt | Linhas removidas: 20
# ✅ Corrigido: raiva_humana_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 20
# ✅ Corrigido: raiva_humana_protocolo_2.txt | Linhas removidas: 13
# ✅ Corrigido: raiva_humana_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 13
# ✅ Corrigido: rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: rubeola_manual_1txt_manual2023.txt | Linhas removidas: 30
# ✅ Corrigido: rubeola_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 30
# ✅ Corrigido: rubeola_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: rubeola_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_nota_tecnica_3txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: rubeola_protocolo_1txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: rubeola_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: sarampo_manual_1.txt | Linhas removidas: 30
# ✅ Corrigido: sarampo_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 30
# ✅ Corrigido: sarampo_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: sarampo_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sarampo_protocolo_1.txt | Linhas removidas: 36
# ✅ Corrigido: sarampo_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 36
# ✅ Corrigido: sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: sarampo_protocolo_2.txt | Linhas removidas: 36
# ✅ Corrigido: sarampo_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 36
# ✅ Corrigido: sifilis_manual_1txt_manual2023.txt | Linhas removidas: 68
# ✅ Corrigido: sifilis_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 68
# ✅ Corrigido: sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 68
# ✅ Corrigido: sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 68
# ✅ Corrigido: sifilis_protocolo_1txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: sifilis_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 70
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_manual_1txt_manual2023.txt | Linhas removidas: 30
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 30
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 14
# ✅ Corrigido: tuberculose_protocolo_1.txt | Linhas removidas: 28
# ✅ Corrigido: tuberculose_protocolo_10.txt | Linhas removidas: 9
# ✅ Corrigido: tuberculose_protocolo_10txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 9
# ✅ Corrigido: tuberculose_protocolo_11.txt | Linhas removidas: 9
# ✅ Corrigido: tuberculose_protocolo_11txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 9
# ✅ Corrigido: tuberculose_protocolo_12.txt | Linhas removidas: 46
# ✅ Corrigido: tuberculose_protocolo_12txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 46
# ✅ Corrigido: tuberculose_protocolo_13.txt | Linhas removidas: 0
# ✅ Corrigido: tuberculose_protocolo_13txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 0
# ✅ Corrigido: tuberculose_protocolo_14.txt | Linhas removidas: 93
# ✅ Corrigido: tuberculose_protocolo_14txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: tuberculose_protocolo_15.txt | Linhas removidas: 93
# ✅ Corrigido: tuberculose_protocolo_15txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 28
# ✅ Corrigido: tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 17
# ✅ Corrigido: tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 17
# ✅ Corrigido: tuberculose_protocolo_2.txt | Linhas removidas: 3
# ✅ Corrigido: tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 3
# ✅ Corrigido: tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: tuberculose_protocolo_3.txt | Linhas removidas: 214
# ✅ Corrigido: tuberculose_protocolo_3txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 214
# ✅ Corrigido: tuberculose_protocolo_4.txt | Linhas removidas: 1
# ✅ Corrigido: tuberculose_protocolo_4txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 1
# ✅ Corrigido: tuberculose_protocolo_5.txt | Linhas removidas: 28
# ✅ Corrigido: tuberculose_protocolo_5txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 28
# ✅ Corrigido: tuberculose_protocolo_6.txt | Linhas removidas: 28
# ✅ Corrigido: tuberculose_protocolo_6txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 28
# ✅ Corrigido: tuberculose_protocolo_7.txt | Linhas removidas: 6
# ✅ Corrigido: tuberculose_protocolo_7txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 6
# ✅ Corrigido: tuberculose_protocolo_8.txt | Linhas removidas: 1
# ✅ Corrigido: tuberculose_protocolo_8txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 1
# ✅ Corrigido: tuberculose_protocolo_9.txt | Linhas removidas: 7
# ✅ Corrigido: tuberculose_protocolo_9txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 7
# ✅ Corrigido: tetano_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: varicela_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 177
# ✅ Corrigido: virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt | Linhas removidas: 244
# ✅ Corrigido: zika_nota_tecnica_1txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt | Linhas removidas: 1
# ✅ Corrigido: zika_protocolo_1.txt | Linhas removidas: 42
# ✅ Corrigido: zika_protocolo_1txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 42
# ✅ Corrigido: zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: zika_protocolo_2.txt | Linhas removidas: 93
# ✅ Corrigido: zika_protocolo_2txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 93
# ✅ Corrigido: zika_protocolo_3.txt | Linhas removidas: 33
# ✅ Corrigido: zika_protocolo_3txt_protocolo2023txt_protocolo2023.txt | Linhas removidas: 33
# ✅ Corrigido: zoonoses_manual_1.txt | Linhas removidas: 38
# ✅ Corrigido: zoonoses_manual_1txt_manual2023txt_manual2023.txt | Linhas removidas: 38
# ✅ Corrigido: zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 38
# ✅ Corrigido: zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt | Linhas removidas: 38
#
#  Log salvo em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\log_correcoes.csv
#  Todos os textos foram processados e corrigidos.

# %% [markdown]
# # LanguageTool
#
# Este script automatiza a limpeza e correção linguística de arquivos .txt utilizando o LanguageTool em servidor local, com integração via biblioteca language-tool-python.
#
# O primeiro passo do script é garantir que a biblioteca language-tool-python esteja instalada. Em seguida, ele define os caminhos necessários para a execução: PASTA_ORIGEM (onde estão os textos brutos), PASTA_DESTINO (onde os textos corrigidos serão salvos), PASTA_LTX (pasta contendo o arquivo .jar, o .bat e o arquivo de porta do LanguageTool), PORTA_FILE (caminho até o arquivo porta_languagetool.txt que armazena a porta em uso) e BAT_FILE (arquivo .bat que inicia o servidor local do LanguageTool).
#
# A função conectar_languagetool() é o núcleo do processo de conexão. Caso o arquivo de porta ainda não exista, o script executa automaticamente o .bat para iniciar o servidor. Depois, tenta ler a porta disponível no arquivo .txt e conecta-se ao servidor local (http://localhost:{porta}), realizando até 10 tentativas com intervalos de espera. Se não conseguir estabelecer a conexão, o script gera um erro indicando que não foi possível se conectar ao LanguageTool.
#
# Esse processo garante que o servidor do LanguageTool esteja rodando antes de qualquer tentativa de uso do corretor ortográfico no restante do script, de forma robusta e automatizada.
#
# **Requisitos obrigatórios:**
# - Java instalado (Java 11 ou superior) – O LanguageTool requer Java para ser executado. É necessário verificar se o Java está instalado usando o comando java -version.
#
# - Pasta do LanguageTool corretamente configurada – Essa pasta deve conter:
#
# - languagetool-server.jar
#
# - iniciar_languagetool.bat (para VS code é necessário inciar manualmente)
#
# - porta_languagetool.txt
#
# - Arquivo .bat com caminho correto – O iniciar_languagetool.bat deve conter o caminho real da pasta onde o .jar está localizado e ser capaz de identificar uma porta livre para inicializar o servidor. Ele grava automaticamente o número da porta no arquivo porta_languagetool.txt.
#
# - Porta local disponível – O servidor será iniciado localmente na porta 8081 (ou na próxima disponível). É importante que não haja bloqueios no firewall que impeçam o uso da porta.
#
# Se todos os requisitos estiverem atendidos, o script executa automaticamente todo o processo de inicialização do servidor e conexão ao corretor gramatical. Esse tipo de estrutura permite que novos arquivos sejam adicionados e processados de forma contínua, mantendo um fluxo de trabalho automatizado, eficiente e reutilizável.
#
# Atenção: Se algum desses requisitos estiver ausente, o script apresentará erro de conexão e não conseguirá aplicar correções linguísticas.
# java: https://www.oracle.com/java/technologies/javase/jdk17-archive-downloads.html
# languagetool: https://languagetool.org/download/

# %%
# === CONFIGURAÇÕES DE CAMINHOS === #
PASTA_ORIGEM = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"
PASTA_DESTINO = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos"
PASTA_LTX = r"C:\Users\isisi\Documents\IAVS_PROJETO\LanguageTool"
CAMINHO_LOG = os.path.join(PASTA_DESTINO, 'log_correcoes.csv')
PORTA_FILE = os.path.join(PASTA_LTX, "porta_languagetool.txt")
BAT_FILE = os.path.join(PASTA_LTX, "iniciar_languagetool.bat")

os.makedirs(PASTA_DESTINO, exist_ok=True)

# === TENTATIVA DE CONEXÃO COM LANGUAGETOOL === #
def conectar_languagetool():
    if not os.path.exists(PORTA_FILE):
        print("⚙️ Arquivo de porta não encontrado. Tentando iniciar o servidor LanguageTool...")
        subprocess.Popen(BAT_FILE, shell=True)
        time.sleep(5)  # espera o servidor levantar

    # Após tentar iniciar, tenta ler a porta
    for tentativa in range(10):
        if os.path.exists(PORTA_FILE):
            with open(PORTA_FILE, "r", encoding="utf-8") as f:
                porta = f.read().strip()
                print(f"🌐 Conectando ao LanguageTool na porta {porta}...")
                try:
                    return language_tool_python.LanguageTool('pt-BR', remote_server=f"http://localhost:{porta}")
                except Exception as e:
                    print(f"⏳ Tentativa {tentativa+1}/10 falhou: {e}")
                    time.sleep(3)
        else:
            time.sleep(2)

    raise RuntimeError("❌ Não foi possível iniciar ou conectar ao LanguageTool.")

# Conexão com LanguageTool
tool = conectar_languagetool()
# Out:
# 🌐 Conectando ao LanguageTool na porta 8081...

# %% [markdown]
# # Visualização de Diferenças entre Textos Originais e Corrigidos
# Este script foi desenvolvido para comparar visualmente os textos antes e depois da correção linguística, utilizando a biblioteca difflib do Python. A saída é um arquivo .html interativo que destaca as diferenças entre os textos, facilitando a validação do processo de correção.
#
# **Objetivo**
# Selecionar um arquivo aleatório por subpasta da pasta corpus_final, localizar sua versão corrigida em textos_corrigidos e gerar um arquivo HTML com as diferenças entre o original e o corrigido.
#
# Organização de Pastas Esperada
# corpus_final/ → Contém os arquivos .txt originais, organizados por subpastas (ex.: dengue, sarampo, etc.).
#
# textos_corrigidos/ → Contém os arquivos corrigidos com a mesma estrutura de subpastas.
#
# **O que o script faz**
# Percorre todas as subpastas de corpus_final.
#
# Em cada subpasta:
#
# - Escolhe aleatoriamente um arquivo .txt.
#
# - Localiza o arquivo correspondente na subpasta equivalente de textos_corrigidos.
#
# - Gera um arquivo .html chamado comparacao_visual_<nome_do_arquivo>.html contendo:
#
# - Texto original (à esquerda)
#
# - Texto corrigido (à direita)
#
# - Destaques coloridos das diferenças.
#
# - O arquivo .html é salvo na mesma subpasta dentro de textos_corrigidos.
#
# Requisitos
# O script usa somente bibliotecas padrão do Python (os, random, pathlib, difflib), não requer instalação de pacotes adicionais.
#
# Os arquivos .txt originais e corrigidos devem ter exatamente o mesmo nome e estarem organizados na mesma estrutura de pastas.

# %%
# -*- coding: utf-8 -*-
"""
Script para limpeza e correção linguística de arquivos .txt do projeto IAVS.
Somente novos arquivos ou arquivos ainda não processados são tratados.
Versão otimizada para velocidade e reaproveitamento de resultados anteriores.
"""
# === CONFIGURAÇÃO DE CAMINHOS === #
PASTA_ORIGEM = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"
PASTA_DESTINO = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos"
CAMINHO_LOG = os.path.join(PASTA_DESTINO, 'log_correcoes.csv')
os.makedirs(PASTA_DESTINO, exist_ok=True)

# === CONFIGURAÇÃO DO CORRETOR ORTOGRÁFICO === #
tool = language_tool_python.LanguageTool('pt-BR', remote_server='http://localhost:8081')
MAX_CARACTERES = 20000  # Tamanho máximo por bloco (evita sobrecarregar API gratuita)

# === PADRÕES DE LINHAS A REMOVER === #
PADROES_LINHAS_REMOVER = [
    r'https?:\/\/\S+',                            # Links
    r'documento assinado eletronicamente',        # Assinatura eletrônica
    r'nota técnica \d+',                          # Rodapés
    r'código\s+crc\s+\w+',                        # Códigos SEI
    r'pg\.?\s*\d+',                               # Página abreviada
    r'página\s+\d+\s+de\s+\d+',                   # Página X de Y
    r'^\s*$',                                     # Linhas vazias
    r'^[\W_]{10,}$',                              # Somente símbolos
    r'^[0-9]+[ \t]+[0-9]+$',                      # Colunas numéricas
    r'^\d{2}/\d{2}/\d{4}$',                       # Datas soltas
    r'\.{4,}',                                    # Muitos pontos
]

# === FUNÇÃO PARA LIMPAR TEXTO === #
def limpar_texto(texto):
    linhas = texto.splitlines()
    linhas_corrigidas = []
    removidas = 0
    padroes_detectados = set()

    for linha in linhas:
        for padrao in PADROES_LINHAS_REMOVER:
            if re.search(padrao, linha, flags=re.IGNORECASE):
                padroes_detectados.add(padrao)
                linha = ''
                break

        linha = re.sub(r'[ \t]+', ' ', linha)
        linha = re.sub(r'–', '-', linha)
        linha = re.sub(r'_+', '_', linha)
        linha = linha.strip()

        if linha:
            linhas_corrigidas.append(linha)
        else:
            removidas += 1

    return '\n'.join(linhas_corrigidas), removidas, list(padroes_detectados)

# === FUNÇÃO PARA CORRIGIR ORTOGRAFIA EM BLOCOS === #
def aplicar_correcoes_linguisticas(texto):
    blocos_corrigidos = []
    for i in range(0, len(texto), MAX_CARACTERES):
        bloco = texto[i:i+MAX_CARACTERES]
        try:
            matches = tool.check(bloco)
            bloco_corrigido = language_tool_python.utils.correct(bloco, matches)
            blocos_corrigidos.append(bloco_corrigido)
        except Exception as e:
            print(f"⚠️ Erro ao corrigir bloco: {e}")
            blocos_corrigidos.append(bloco)
    return '\n'.join(blocos_corrigidos)

# === COLETA DE ARQUIVOS JÁ CORRIGIDOS === #
print("📂 Verificando arquivos já corrigidos...")
arquivos_corrigidos = set()
for subdir, _, arquivos in os.walk(PASTA_DESTINO):
    for arq in arquivos:
        if arq.endswith(".txt"):
            arquivos_corrigidos.add(arq)

# === ABRE O LOG DE CORREÇÃO PARA ESCREVER NOVOS REGISTROS === #
with open(CAMINHO_LOG, 'w', newline='', encoding='utf-8') as log_file:
    writer = csv.writer(log_file)
    writer.writerow(['Arquivo', 'Linhas Removidas', 'Padrões Detectados', 'Original', 'Corrigido'])

    print("🔧 Iniciando correção de novos arquivos...")

    for subpasta in os.listdir(PASTA_ORIGEM):
        caminho_sub = os.path.join(PASTA_ORIGEM, subpasta)
        if not os.path.isdir(caminho_sub):
            continue

        nova_sub = os.path.join(PASTA_DESTINO, subpasta)
        os.makedirs(nova_sub, exist_ok=True)

        for arquivo in os.listdir(caminho_sub):
            if not arquivo.endswith(".txt"):
                continue

            if arquivo in arquivos_corrigidos:
                print(f"⏩ {arquivo} já corrigido. Pulando.")
                continue

            caminho_arquivo = os.path.join(caminho_sub, arquivo)
            caminho_corrigido = os.path.join(nova_sub, arquivo)

            try:
                with open(caminho_arquivo, 'r', encoding='utf-8', errors='ignore') as f:
                    texto_original = f.read()

                texto_limpo, linhas_removidas, padroes = limpar_texto(texto_original)
                texto_corrigido = aplicar_correcoes_linguisticas(texto_limpo)

                with open(caminho_corrigido, 'w', encoding='utf-8') as f_out:
                    f_out.write(texto_corrigido)

                print(f"✅ {arquivo} | {linhas_removidas} linhas removidas | {len(texto_corrigido)} caracteres corrigidos")

                writer.writerow([
                    arquivo,
                    linhas_removidas,
                    '; '.join(padroes),
                    caminho_arquivo,
                    caminho_corrigido
                ])

            except Exception as e:
                print(f"❌ Erro ao processar {arquivo}: {e}")

print("\n✅ FIM! Log salvo em:", CAMINHO_LOG)
print("✅ Correção linguística e estrutural finalizada.")
# Out:
# 📂 Verificando arquivos já corrigidos...
# 🔧 Iniciando correção de novos arquivos...
# ⏩ adenovirus_guia_1txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ adenovírus_guia_1.txt já corrigido. Pulando.
# ⏩ arboviroses_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ arboviroses_nota_técnica_1.txt já corrigido. Pulando.
# ⏩ cancro_mole_protocolo_1.txt já corrigido. Pulando.
# ⏩ cancro_mole_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ chikungunya_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ chikungunya_nota_técnica_1.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_1.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_2.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_3.txt já corrigido. Pulando.
# ⏩ chikungunya_protocolo_3txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ clamidia_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ clamidia_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_3txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ covid-19_guia_1.txt já corrigido. Pulando.
# ⏩ covid-19_nota_técnica_1.txt já corrigido. Pulando.
# ⏩ covid_19_guia_1txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ colera_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ colera_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ colera_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ dengue_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_1.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_2.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_3.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_3txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_4.txt já corrigido. Pulando.
# ⏩ dengue_protocolo_4txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ difteria_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ entre_outras_protocolo_1.txt já corrigido. Pulando.
# ⏩ entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ entre_outras_protocolo_2.txt já corrigido. Pulando.
# ⏩ entre_outras_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_1.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_2.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_3.txt já corrigido. Pulando.
# ⏩ febre_amarela_protocolo_3txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ gonorreia_protocolo_1.txt já corrigido. Pulando.
# ⏩ gonorreia_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_diretriz_nacional_1txt_documento2023.txt já corrigido. Pulando.
# ⏩ hanseniase_diretriz_nacional_1txt_documento2023txt_documento2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_2txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_3txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hanseniase_protocolo_3txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_1.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_2.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_2txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_protocolo_1.txt já corrigido. Pulando.
# ⏩ hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_b_e_c_(ist)_protocolo_1.txt já corrigido. Pulando.
# ⏩ hepatite_b_e_c_ist_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_b_protocolo_1.txt já corrigido. Pulando.
# ⏩ hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_c_protocolo_1.txt já corrigido. Pulando.
# ⏩ hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_d_(delta)_nota_técnica_1.txt já corrigido. Pulando.
# ⏩ hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatite_d_protocolo_1.txt já corrigido. Pulando.
# ⏩ hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_e_protocolo_1.txt já corrigido. Pulando.
# ⏩ hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatites_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hepatites_protocolo_1.txt já corrigido. Pulando.
# ⏩ hepatites_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ herpes_genital_protocolo_1.txt já corrigido. Pulando.
# ⏩ herpes_genital_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ hiv_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hpv_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ hpv_protocolo_1.txt já corrigido. Pulando.
# ⏩ hpv_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ influenza_guia_1.txt já corrigido. Pulando.
# ⏩ influenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ influenza_guia_2.txt já corrigido. Pulando.
# ⏩ influenza_guia_2txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ leishmaniose_manual_1.txt já corrigido. Pulando.
# ⏩ leishmaniose_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ leptospirose_manual_1.txt já corrigido. Pulando.
# ⏩ leptospirose_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_3txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ leptospirose_protocolo_1.txt já corrigido. Pulando.
# ⏩ leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ linfogranuloma_venereo_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ linfogranuloma_venereo_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ m._abscessus_protocolo_1.txt já corrigido. Pulando.
# ⏩ m._kansasii_protocolo_1.txt já corrigido. Pulando.
# ⏩ m_abscessus_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ m_kansasii_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ malaria_manual_1txt_manual2023.txt já corrigido. Pulando.
# ⏩ malaria_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ malaria_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ malaria_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ meningite_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ metapneumovirus_guia_1txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ outras_zoonoses_transmitidas_por_roedores_manual_1.txt já corrigido. Pulando.
# ⏩ outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ parainfluenza_guia_1.txt já corrigido. Pulando.
# ⏩ parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ peste_manual_1.txt já corrigido. Pulando.
# ⏩ peste_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ peste_manual_2.txt já corrigido. Pulando.
# ⏩ peste_manual_2txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_3txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ poliomielite_protocolo_1.txt já corrigido. Pulando.
# ⏩ poliomielite_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ raiva_humana_protocolo_1.txt já corrigido. Pulando.
# ⏩ raiva_humana_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ raiva_humana_protocolo_2.txt já corrigido. Pulando.
# ⏩ raiva_humana_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ rubeola_manual_1txt_manual2023.txt já corrigido. Pulando.
# ⏩ rubeola_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_3txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ rubeola_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ rubeola_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ sarampo_manual_1.txt já corrigido. Pulando.
# ⏩ sarampo_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sarampo_protocolo_1.txt já corrigido. Pulando.
# ⏩ sarampo_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ sarampo_protocolo_2.txt já corrigido. Pulando.
# ⏩ sarampo_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ sifilis_manual_1txt_manual2023.txt já corrigido. Pulando.
# ⏩ sifilis_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ sifilis_protocolo_1txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ sifilis_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_manual_1txt_manual2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_1.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_10.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_10txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_11.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_11txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_12.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_12txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_13.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_13txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_14.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_14txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_15.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_15txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_2.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_3.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_3txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_4.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_4txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_5.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_5txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_6.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_6txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_7.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_7txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_8.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_8txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_9.txt já corrigido. Pulando.
# ⏩ tuberculose_protocolo_9txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ tetano_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ varicela_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt já corrigido. Pulando.
# ⏩ zika_nota_tecnica_1txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt já corrigido. Pulando.
# ⏩ zika_protocolo_1.txt já corrigido. Pulando.
# ⏩ zika_protocolo_1txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ zika_protocolo_2.txt já corrigido. Pulando.
# ⏩ zika_protocolo_2txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ zika_protocolo_3.txt já corrigido. Pulando.
# ⏩ zika_protocolo_3txt_protocolo2023txt_protocolo2023.txt já corrigido. Pulando.
# ⏩ zoonoses_manual_1.txt já corrigido. Pulando.
# ⏩ zoonoses_manual_1txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
# ⏩ zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt já corrigido. Pulando.
#
# ✅ FIM! Log salvo em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\log_correcoes.csv
# ✅ Correção linguística e estrutural finalizada.

# %% [markdown]
# **Correção linguística com LanguageTool**
#
# **Objetivo:**
# Executar a correção ortográfica e gramatical automatizada de todos os arquivos finais do projeto, integrando a verificação linguística do LanguageTool com a limpeza estrutural já aplicada anteriormente.
#
# **O que essa etapa faz:**
# - Conexão com o servidor local do LanguageTool:
#
# - Lê a porta de conexão do arquivo porta_languagetool.txt.
#
# - Se necessário, executa o arquivo .bat de inicialização do servidor.
#
# - Limpeza estrutural dos arquivos:
#
# - Remove links, rodapés, páginas, assinaturas eletrônicas, datas soltas, sequências de símbolos, entre outros ruídos.
#
# - Uniformiza espaçamentos, travessões e underlines.
#
# - Correção linguística com LanguageTool:
#
# - Os arquivos são divididos em blocos de até 20.000 caracteres para não ultrapassar os limites do servidor.
#
# - Cada bloco é verificado por erros de ortografia, concordância, pontuação e gramática.
#
# - As sugestões do LanguageTool são aplicadas automaticamente.
#
# - Salvamento dos arquivos corrigidos:
#
# - Os textos corrigidos são armazenados em textos_corrigidos, em subpastas espelhadas.
#
# **Registro em log:**
# - Um arquivo CSV log_correcoes.csv armazena para cada arquivo:
#
# - Quantidade de linhas removidas
#
# - Padrões detectados
#
# - Caminho original
#
# - Caminho do texto corrigido

# %%
# === CONFIGURAÇÃO DE CAMINHOS === #
PASTA_ORIGEM = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"
PASTA_DESTINO = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos"
CAMINHO_LOG = os.path.join(PASTA_DESTINO, 'log_correcoes.csv')
PORTA_FILE = r"C:\Users\isisi\Documents\IAVS_PROJETO\LanguageTool\porta_languagetool.txt"
BAT_FILE = r"C:\Users\isisi\Documents\LanguageTool\iniciar_languagetool.bat"

# Garante que a pasta de destino exista
os.makedirs(PASTA_DESTINO, exist_ok=True)

# === FUNÇÃO PARA CONECTAR AO SERVIDOR DO LANGUAGETOOL === #
def conectar_languagetool():
    if not os.path.exists(PORTA_FILE):
        print("⚠️ Arquivo de porta não encontrado.")
        if os.path.exists(BAT_FILE):
            print(" Tentando iniciar o servidor com o arquivo .bat...")
            subprocess.Popen(['start', '', BAT_FILE], shell=True)
            print(" Aguardando 10 segundos para o servidor iniciar...")
            time.sleep(10)
        else:
            raise FileNotFoundError(f"❌ Arquivo .bat não encontrado em: {BAT_FILE}")
    
    if os.path.exists(PORTA_FILE):
        with open(PORTA_FILE, "r", encoding="utf-8") as f:
            porta = f.read().strip()
        print(f"🌐 Conectando ao LanguageTool na porta {porta}...")
        return language_tool_python.LanguageTool('pt-BR', remote_server=f"http://localhost:{porta}")
    else:
        raise FileNotFoundError("❌ Falha ao localizar o arquivo da porta após tentativa de inicialização.")

# Estabelece conexão com o servidor local do LanguageTool
tool = conectar_languagetool()
MAX_CARACTERES = 20000  # Limite de caracteres por bloco a ser corrigido

# === PADRÕES SUSPEITOS A REMOVER === #
PADROES_LINHAS_REMOVER = [
    r'https?:\/\/\S+',
    r'documento assinado eletronicamente',
    r'nota técnica \d+',
    r'código\s+crc\s+\w+',
    r'pg\.?\s*\d+',
    r'página\s+\d+\s+de\s+\d+',
    r'^\s*$',
    r'^[\W_]{10,}$',
    r'^[0-9]+[ \t]+[0-9]+$',
    r'^\d{2}/\d{2}/\d{4}$',
    r'\.{4,}',
]

# === FUNÇÃO PARA LIMPAR RESÍDUOS TEXTUAIS === #
def limpar_texto(texto):
    linhas = texto.splitlines()
    linhas_corrigidas = []
    removidas = 0
    padroes_detectados = set()

    for linha in linhas:
        for padrao in PADROES_LINHAS_REMOVER:
            if re.search(padrao, linha, flags=re.IGNORECASE):
                padroes_detectados.add(padrao)
                linha = ''
                break
        linha = re.sub(r'[ \t]+', ' ', linha)
        linha = re.sub(r'–', '-', linha)
        linha = re.sub(r'_+', '_', linha)
        linha = linha.strip()

        if linha:
            linhas_corrigidas.append(linha)
        else:
            removidas += 1

    return '\n'.join(linhas_corrigidas), removidas, list(padroes_detectados)

# === FUNÇÃO PARA APLICAR CORREÇÕES LINGUÍSTICAS POR BLOCOS === #
def aplicar_correcoes_linguisticas(texto):
    blocos_corrigidos = []
    for i in range(0, len(texto), MAX_CARACTERES):
        bloco = texto[i:i+MAX_CARACTERES]
        try:
            matches = tool.check(bloco)
            bloco_corrigido = language_tool_python.utils.correct(bloco, matches)
            blocos_corrigidos.append(bloco_corrigido)
        except Exception as e:
            print(f"⚠️ Erro ao corrigir bloco: {e}")
            blocos_corrigidos.append(bloco)  # Se falhar, mantém o bloco original
    return '\n'.join(blocos_corrigidos)

# === EXECUÇÃO PRINCIPAL === #
start_time = time.time()

with open(CAMINHO_LOG, 'w', newline='', encoding='utf-8') as log_file:
    writer = csv.writer(log_file)
    writer.writerow(['Arquivo', 'Linhas Removidas', 'Padrões Detectados', 'Original', 'Corrigido'])

    print("\n🔧 Iniciando processamento com correção linguística...")

    for subpasta in os.listdir(PASTA_ORIGEM):
        caminho_sub = os.path.join(PASTA_ORIGEM, subpasta)
        if os.path.isdir(caminho_sub):
            nova_sub = os.path.join(PASTA_DESTINO, subpasta)
            os.makedirs(nova_sub, exist_ok=True)

            for arquivo in os.listdir(caminho_sub):
                if arquivo.endswith(".txt"):
                    caminho_arquivo = os.path.join(caminho_sub, arquivo)
                    caminho_corrigido = os.path.join(nova_sub, arquivo)

                    # Pula o arquivo se já estiver corrigido
                    if os.path.exists(caminho_corrigido):
                        print(f"⏩ Pulando (já corrigido): {arquivo}")
                        continue

                    # Leitura e limpeza estrutural
                    with open(caminho_arquivo, 'r', encoding='utf-8', errors='ignore') as f:
                        texto_original = f.read()
                    texto_limpo, linhas_removidas, padroes = limpar_texto(texto_original)

                    # Correção linguística com LanguageTool
                    texto_corrigido = aplicar_correcoes_linguisticas(texto_limpo)

                    # Salvando o novo texto corrigido
                    with open(caminho_corrigido, 'w', encoding='utf-8') as f_out:
                        f_out.write(texto_corrigido)

                    print(f"✅ {arquivo} | {linhas_removidas} linhas removidas | {len(texto_corrigido)} caracteres corrigidos")
                    writer.writerow([arquivo, linhas_removidas, '; '.join(padroes), caminho_arquivo, caminho_corrigido])

# === ENCERRAMENTO === #
tempo_total = time.time() - start_time
print(f"\n Tempo total de execução: {tempo_total:.2f} segundos")
print(" Log completo salvo em:", CAMINHO_LOG)
print(" Correção linguística e estrutural finalizada.")
# Out:
# 🌐 Conectando ao LanguageTool na porta 8081...
#
# 🔧 Iniciando processamento com correção linguística...
# ⏩ Pulando (já corrigido): adenovirus_guia_1txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): adenovírus_guia_1.txt
# ⏩ Pulando (já corrigido): arboviroses_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): arboviroses_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): arboviroses_nota_técnica_1.txt
# ⏩ Pulando (já corrigido): cancro_mole_protocolo_1.txt
# ⏩ Pulando (já corrigido): cancro_mole_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): chikungunya_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): chikungunya_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): chikungunya_nota_técnica_1.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_1.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_2.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_3.txt
# ⏩ Pulando (já corrigido): chikungunya_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): clamidia_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): clamidia_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_3txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): coqueluche_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): covid-19_guia_1.txt
# ⏩ Pulando (já corrigido): covid-19_nota_técnica_1.txt
# ⏩ Pulando (já corrigido): covid_19_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): covid_19_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): covid_19_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): colera_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): colera_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): colera_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): colera_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): colera_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): dengue_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): dengue_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_1.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_2.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_3.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_4.txt
# ⏩ Pulando (já corrigido): dengue_protocolo_4txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): difteria_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): difteria_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): entre_outras_protocolo_1.txt
# ⏩ Pulando (já corrigido): entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): entre_outras_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): entre_outras_protocolo_2.txt
# ⏩ Pulando (já corrigido): entre_outras_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_1.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_2.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_3.txt
# ⏩ Pulando (já corrigido): febre_amarela_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): gonorreia_protocolo_1.txt
# ⏩ Pulando (já corrigido): gonorreia_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_diretriz_nacional_1txt_documento2023.txt
# ⏩ Pulando (já corrigido): hanseniase_diretriz_nacional_1txt_documento2023txt_documento2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_2txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_3txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hanseniase_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_1.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_2.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_2txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_protocolo_1.txt
# ⏩ Pulando (já corrigido): hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_b_e_c_(ist)_protocolo_1.txt
# ⏩ Pulando (já corrigido): hepatite_b_e_c_ist_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_b_protocolo_1.txt
# ⏩ Pulando (já corrigido): hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_b_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_c_protocolo_1.txt
# ⏩ Pulando (já corrigido): hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_c_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_d_(delta)_nota_técnica_1.txt
# ⏩ Pulando (já corrigido): hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_d_delta_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatite_d_protocolo_1.txt
# ⏩ Pulando (já corrigido): hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_d_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_e_protocolo_1.txt
# ⏩ Pulando (já corrigido): hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatite_e_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatites_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatites_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hepatites_protocolo_1.txt
# ⏩ Pulando (já corrigido): hepatites_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hepatites_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): herpes_genital_protocolo_1.txt
# ⏩ Pulando (já corrigido): herpes_genital_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): hiv_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hpv_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): hpv_protocolo_1.txt
# ⏩ Pulando (já corrigido): hpv_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): influenza_guia_1.txt
# ⏩ Pulando (já corrigido): influenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): influenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): influenza_guia_2.txt
# ⏩ Pulando (já corrigido): influenza_guia_2txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): influenza_guia_2txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): leishmaniose_manual_1.txt
# ⏩ Pulando (já corrigido): leishmaniose_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): leishmaniose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): leptospirose_manual_1.txt
# ⏩ Pulando (já corrigido): leptospirose_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): leptospirose_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_3txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): leptospirose_protocolo_1.txt
# ⏩ Pulando (já corrigido): leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): leptospirose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): linfogranuloma_venereo_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): linfogranuloma_venereo_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): m._abscessus_protocolo_1.txt
# ⏩ Pulando (já corrigido): m._kansasii_protocolo_1.txt
# ⏩ Pulando (já corrigido): m_abscessus_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): m_kansasii_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): malaria_manual_1txt_manual2023.txt
# ⏩ Pulando (já corrigido): malaria_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): malaria_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): malaria_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): meningite_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): metapneumovirus_guia_1txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): outras_zoonoses_transmitidas_por_roedores_manual_1.txt
# ⏩ Pulando (já corrigido): outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): parainfluenza_guia_1.txt
# ⏩ Pulando (já corrigido): parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): parainfluenza_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): peste_manual_1.txt
# ⏩ Pulando (já corrigido): peste_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): peste_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): peste_manual_2.txt
# ⏩ Pulando (já corrigido): peste_manual_2txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_3txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): poliomielite_protocolo_1.txt
# ⏩ Pulando (já corrigido): poliomielite_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): raiva_humana_protocolo_1.txt
# ⏩ Pulando (já corrigido): raiva_humana_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): raiva_humana_protocolo_2.txt
# ⏩ Pulando (já corrigido): raiva_humana_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): rubeola_manual_1txt_manual2023.txt
# ⏩ Pulando (já corrigido): rubeola_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_3txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): rubeola_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): rubeola_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): rubeola_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): sarampo_manual_1.txt
# ⏩ Pulando (já corrigido): sarampo_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sarampo_protocolo_1.txt
# ⏩ Pulando (já corrigido): sarampo_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): sarampo_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): sarampo_protocolo_2.txt
# ⏩ Pulando (já corrigido): sarampo_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): sifilis_manual_1txt_manual2023.txt
# ⏩ Pulando (já corrigido): sifilis_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): sifilis_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): sifilis_protocolo_1txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): sifilis_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_manual_1txt_manual2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): sindrome_da_rubeola_congenita_src_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_1.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_10.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_10txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_11.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_11txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_12.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_12txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_13.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_13txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_14.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_14txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_15.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_15txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_2.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_2txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_3.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_4.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_4txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_5.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_5txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_6.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_6txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_7.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_7txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_8.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_8txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_9.txt
# ⏩ Pulando (já corrigido): tuberculose_protocolo_9txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): tetano_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): varicela_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.txt
# ⏩ Pulando (já corrigido): zika_nota_tecnica_1txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): zika_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.txt
# ⏩ Pulando (já corrigido): zika_protocolo_1.txt
# ⏩ Pulando (já corrigido): zika_protocolo_1txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): zika_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): zika_protocolo_2.txt
# ⏩ Pulando (já corrigido): zika_protocolo_2txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): zika_protocolo_3.txt
# ⏩ Pulando (já corrigido): zika_protocolo_3txt_protocolo2023txt_protocolo2023.txt
# ⏩ Pulando (já corrigido): zoonoses_manual_1.txt
# ⏩ Pulando (já corrigido): zoonoses_manual_1txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
# ⏩ Pulando (já corrigido): zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.txt
#
#  Tempo total de execução: 0.02 segundos
#  Log completo salvo em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\log_correcoes.csv
#  Correção linguística e estrutural finalizada.

# %% [markdown]
# # Visualização de Diferenças entre Textos Originais e Corrigidos
# Este script foi desenvolvido para comparar visualmente os textos antes e depois da correção linguística, utilizando a biblioteca difflib do Python. A saída é um arquivo .html interativo que destaca as diferenças entre os textos, facilitando a validação do processo de correção.
#
# **Objetivo**
# Selecionar um arquivo aleatório por subpasta da pasta corpus_final, localizar sua versão corrigida em textos_corrigidos e gerar um arquivo HTML com as diferenças entre o original e o corrigido.
#
# **Organização de Pastas Esperada**
# corpus_final/ → Contém os arquivos .txt originais, organizados por subpastas (ex.: dengue, sarampo, etc.).
#
# textos_corrigidos/ → Contém os arquivos corrigidos com a mesma estrutura de subpastas.
#
# **O que o script faz**
# Percorre todas as subpastas de corpus_final.
#
# **Em cada subpasta:**
#
# - Escolhe aleatoriamente um arquivo .txt.
#
# - ocaliza o arquivo correspondente na subpasta equivalente de textos_corrigidos.
#
# - Gera um arquivo .html chamado comparacao_visual_<nome_do_arquivo>.html contendo:
#
# - Texto original (à esquerda)
#
# - Texto corrigido (à direita)
#
# - Destaques coloridos das diferenças.
#
# - O arquivo .html é salvo na mesma subpasta dentro de textos_corrigidos.
#
# **Requisitos**
# O script usa somente bibliotecas padrão do Python (os, random, pathlib, difflib), não requer instalação de pacotes adicionais.
#
# Os arquivos .txt originais e corrigidos devem ter exatamente o mesmo nome e estarem organizados na mesma estrutura de pastas.

# %%
# === CONFIGURAÇÕES DE CAMINHO ===
PASTA_ORIGEM = Path(r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final")
PASTA_CORRIGIDA = Path(r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos")

# === Função para comparar e salvar HTML ===
def gerar_diferencas_html(orig_path, corr_path, output_path):
    with open(orig_path, 'r', encoding='utf-8', errors='ignore') as f1:
        original = f1.readlines()
    with open(corr_path, 'r', encoding='utf-8', errors='ignore') as f2:
        corrigido = f2.readlines()

    d = difflib.HtmlDiff(wrapcolumn=120)
    html_diff = d.make_file(original, corrigido, fromdesc='Original', todesc='Corrigido')

    with open(output_path, 'w', encoding='utf-8') as out:
        out.write(html_diff)
    print(f"✅ Diferença salva em: {output_path}")

# === Loop por subpastas e seleção aleatória de um arquivo por pasta ===
for subdir, _, files in os.walk(PASTA_ORIGEM):
    rel_path = Path(subdir).relative_to(PASTA_ORIGEM)
    pasta_corrigida_sub = PASTA_CORRIGIDA / rel_path

    arquivos_txt = [f for f in files if f.endswith(".txt")]
    if arquivos_txt:
        nome_arquivo = random.choice(arquivos_txt)
        caminho_original = Path(subdir) / nome_arquivo
        caminho_corrigido = pasta_corrigida_sub / nome_arquivo

        if caminho_corrigido.exists():
            nome_saida = f"comparacao_visual_{nome_arquivo.replace('.txt', '')}.html"
            caminho_html = pasta_corrigida_sub / nome_saida
            gerar_diferencas_html(caminho_original, caminho_corrigido, caminho_html)
        else:
            print(f"⚠️ Arquivo corrigido não encontrado para: {nome_arquivo}")
# Out:
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\adenovírus\comparacao_visual_adenovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\arboviroses\comparacao_visual_arboviroses_nota_técnica_1.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\cancro\comparacao_visual_cancro_mole_protocolo_1txt_protocolo2023txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\chikungunya\comparacao_visual_chikungunya_protocolo_2txt_protocolo2023txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\clamídia\comparacao_visual_clamidia_protocolo_1txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\coinfecção\comparacao_visual_coinfeccao_com_hepatite_b_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\coqueluche\comparacao_visual_coqueluche_nota_tecnica_2txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\covid-19\comparacao_visual_covid-19_guia_1.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\cólera\comparacao_visual_colera_protocolo_1txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\dengue\comparacao_visual_dengue_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\difteria\comparacao_visual_difteria_nota_tecnica_1txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\entre\comparacao_visual_entre_outras_doencas_imunopreveniveis_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\febre\comparacao_visual_febre_do_nilo_ocidental_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\gonorreia\comparacao_visual_gonorreia_protocolo_1.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\hanseníase\comparacao_visual_hanseniase_nota_tecnica_2txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\hantavirose\comparacao_visual_hantavirose_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023txt_manual2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\hepatite\comparacao_visual_hepatite_a_protocolo_1txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\hepatites\comparacao_visual_hepatites_nota_tecnica_1txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\herpes\comparacao_visual_herpes_genital_protocolo_1.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\hiv\comparacao_visual_hiv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\hpv\comparacao_visual_hpv_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\influenza\comparacao_visual_influenza_guia_1txt_guiavsa2023txt_guiavsa2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\leishmaniose\comparacao_visual_leishmaniose_manual_1txt_manual2023txt_manual2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\leptospirose\comparacao_visual_leptospirose_nota_tecnica_1txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\linfogranuloma\comparacao_visual_linfogranuloma_venereo_protocolo_1txt_protocolo2023txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\m\comparacao_visual_m._kansasii_protocolo_1.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\malária\comparacao_visual_malaria_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\meningite\comparacao_visual_meningite_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\metapneumovírus\comparacao_visual_metapneumovirus_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\micobactérias\comparacao_visual_micobacterias_nao_tuberculosas_mnt_m_avium_protocolo_1txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\outras\comparacao_visual_outras_zoonoses_transmitidas_por_roedores_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\parainfluenza\comparacao_visual_parainfluenza_guia_1.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\peste\comparacao_visual_peste_manual_2txt_manual2023txt_manual2023txt_manual2023txt_manual2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\poliomielite\comparacao_visual_poliomielite_nota_tecnica_3txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\raiva\comparacao_visual_raiva_humana_protocolo_2.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\rinovírus\comparacao_visual_rinovirus_e_outros_respiratorios_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\rubéola\comparacao_visual_rubeola_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\sarampo\comparacao_visual_sarampo_protocolo_1.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\sífilis\comparacao_visual_sifilis_protocolo_1txt_protocolo2023txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\síndrome\comparacao_visual_sindrome_da_rubeola_congenita_src_manual_1txt_manual2023txt_manual2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\tuberculose\comparacao_visual_tuberculose_protocolo_14.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\tétano\comparacao_visual_tetano_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\varicela\comparacao_visual_varicela_nota_tecnica_1txt_notatecnica2023txt_notatecnica2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\vírus\comparacao_visual_virus_sincicial_respiratorio_vsr_guia_1txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023txt_guiavsa2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\zika\comparacao_visual_zika_protocolo_2txt_protocolo2023txt_protocolo2023.html
# ✅ Diferença salva em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_corrigidos\zoonoses\comparacao_visual_zoonoses_manual_1txt_manual2023txt_manual2023txt_manual2023txt_manual2023.html

# %% [markdown]
# # Geração de Relatório de Arquivos Textuais
# Como etapa complementar ao armazenamento final dos arquivos, foi implementada a geração automática de um relatório-resumo em formato .csv. Esse relatório tem como objetivo fornecer uma visão geral da estrutura dos textos organizados por subpasta (doença ou tema), permitindo uma verificação quantitativa dos arquivos.
#
# O que o relatório contém:
# - Nome da subpasta: Classificação do documento (ex: dengue, zika, etc.).
#
# - Nome do arquivo: Nome completo do arquivo .txt.
#
# - Tamanho do arquivo (em bytes): Pode indicar se o arquivo está muito pequeno ou grande.
#
# - Número de linhas: Pode sugerir a complexidade ou organização do texto.
#
# - Número total de caracteres: Útil para identificar arquivos potencialmente vazios ou incompletos.
#
# - O arquivo gerado, chamado resumo_corpus_final.csv, é salvo diretamente na pasta corpus_final.
#
# Exemplo de saída:
# | Subpasta    | Arquivo                       | Tamanho (bytes) | Nº de linhas | Nº de caracteres |
# | ----------- | ----------------------------- | --------------- | ------------ | ---------------- |
# | dengue      | dengue\_guiavsa2023.txt       | 12.304          | 455          | 11.982           |
# | tuberculose | protocolo\_tb\_manual2023.txt | 18.734          | 672          | 17.401           |

# %%
# Caminho para o diretório com os textos finais organizados por subpasta
PASTA_FINAL = r"C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final"

# Caminho para salvar o relatório final
RELATORIO_CSV = os.path.join(PASTA_FINAL, "resumo_corpus_final.csv")

# Obtém a lista de subpastas no corpus final
subpastas = [nome for nome in os.listdir(PASTA_FINAL) if os.path.isdir(os.path.join(PASTA_FINAL, nome))]

# === Geração do relatório em CSV === #
with open(RELATORIO_CSV, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)

    # Cabeçalho do relatório
    writer.writerow(['Subpasta', 'Arquivo', 'Tamanho (bytes)', 'Nº de linhas', 'Nº de caracteres'])

    # Percorre cada subpasta
    for sub in subpastas:
        caminho_sub = os.path.join(PASTA_FINAL, sub)
        for arquivo in os.listdir(caminho_sub):
            if arquivo.endswith(".txt"):
                caminho_arquivo = os.path.join(caminho_sub, arquivo)

                # Lê o conteúdo do arquivo
                with open(caminho_arquivo, 'r', encoding='utf-8', errors='ignore') as arq:
                    conteudo = arq.read()
                    num_linhas = conteudo.count('\n')
                    num_chars = len(conteudo)
                    tamanho = os.path.getsize(caminho_arquivo)

                    # Escreve os dados no relatório
                    writer.writerow([sub, arquivo, tamanho, num_linhas, num_chars])

print(f" Relatório salvo em: {RELATORIO_CSV}")
# Out:
#  Relatório salvo em: C:\Users\isisi\Documents\IAVS_PROJETO\corpus_final\resumo_corpus_final.csv
