# %% [markdown]
# # Processamento Automatizado de Documentos Técnicos – Projeto IAVS
# Este notebook reúne todos os scripts utilizados no processo de extração, limpeza e organização dos documentos técnicos normativos no âmbito do projeto IAVS (Inteligência Artificial para Vigilância em Saúde).
#
# O objetivo geral é estruturar uma base textual confiável e padronizada que possa ser utilizada em processos de classificação, análise e apoio a modelos de inteligência artificial.
#
# Etapas contempladas:
#
# - Preparação do Ambiente
#
# - Importação dos pacotes necessários.
#
# - Definição dos caminhos e criação automática das pastas que compõem o fluxo de trabalho.
#
# - Funções Utilitárias
#
# - Função de normalização de texto para padronizar nomes de arquivos.
#
# - Função para localização automatizada de arquivos PDF por similaridade textual (fuzzy matching).
#
# - Função de limpeza textual para corrigir formatações e eliminar ruídos típicos de extração.
#
# - Classificação e Renomeação
#
# - Leitura da planilha de controle (controle_documentos.xlsx).
#
# - Localização, categorização e cópia dos arquivos PDF com nomes padronizados por doença e tipo de documento.
#
# - Conversão de PDFs para Texto
#
# - Extração do conteúdo textual dos documentos PDF.
#
# - Geração de arquivos .txt para cada documento localizado.
#
# - Limpeza dos Arquivos de Texto
#
# - Remoção de quebras de linha indesejadas, espaços repetidos e artefatos como marcações de página.
#
# - Verificação dos Arquivos Gerados
#
# - Listagem final dos arquivos tratados e prontos para uso, como etapa de validação visual.
#
# **Observações:**
# Todas as operações são feitas de forma automatizada, com verificações para evitar retrabalho e perdas de informação.
#
# O pipeline é compatível com bases documentais de grande volume e pode ser reaplicado para outras áreas temáticas da vigilância em saúde.

# %% [markdown]
# ## Etapa 1 – Definição de Estrutura e Preparação do Ambiente
# Este trecho do código realiza a preparação inicial do ambiente de trabalho para o processamento automatizado de documentos no projeto IAVS (Inteligência Artificial para Vigilância em Saúde).
#
# **Objetivos:**
# - Importar os módulos necessários para manipulação de arquivos, textos, planilhas e PDFs;
#
# - Definir o diretório base do projeto e as subpastas que organizam os arquivos em diferentes estágios do fluxo (originais, convertidos, limpos e organizados);
#
# - Criar automaticamente as pastas exigidas pelo pipeline, garantindo que a estrutura esteja pronta mesmo em execuções futuras ou em novos ambientes.
#
# Essa etapa garante uma organização padronizada dos arquivos e prepara o caminho para a execução segura e escalável dos scripts de extração, limpeza e categorização dos documentos normativos da área da saúde.

# %%
# Importação dos módulos necessários
# %pip install pdfplumber pandas openpyxl
# Importando bibliotecas essenciais
import os   # Operações com diretórios e caminhos de arquivos
import pandas as pd        # Leitura e manipulação de planilhas (DataFrames)
import re # Expressões regulares para manipulação de texto
import hashlib
import csv
from pathlib import Path
import pdfplumber          # Extração de texto de arquivos PDF
import time  # Módulo para medir tempo de execução
import shutil      # Operações de cópia e movimentação de arquivos
import unicodedata # Manipulação de acentuação e caracteres Unicode
import difflib     # Comparação de similaridade entre strings
from collections import Counter  # Contagem de elementos (como palavras ou erros)
# Out:
# Requirement already satisfied: pdfplumber in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (0.11.7)
# Requirement already satisfied: pandas in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (2.3.1)
# Requirement already satisfied: openpyxl in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (3.1.5)
# Requirement already satisfied: pdfminer.six==20250506 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pdfplumber) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pdfplumber) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pdfminer.six==20250506->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pdfminer.six==20250506->pdfplumber) (45.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\isisi\anaconda3\envs\anaconda-toolbox\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Definição do diretório base do projeto
BASE_DIR = r"C:\Users\isisi\Documents\IAVS_PROJETO"

# Caminho da planilha de controle dos documentos
PLANILHA = os.path.join(BASE_DIR, "controle_documentos.xlsx")

# Definição das pastas utilizadas no fluxo de trabalho
PASTA_BRUTOS = os.path.join(BASE_DIR, "pdfs_brutos")           # PDF originais, sem tratamento
PASTA_CONVERTIDOS = os.path.join(BASE_DIR, "textos_convertidos")  # Arquivos .txt gerados a partir dos PDFs
PASTA_LIMPOS = os.path.join(BASE_DIR, "textos_limpos")         # Textos tratados e limpos (sem cabeçalho, rodapé etc.)
PASTA_FINAL = os.path.join(BASE_DIR, "organizados")            # Textos organizados por doença e tema

# Criação automática das pastas, se ainda não existirem
for pasta in [PASTA_BRUTOS, PASTA_CONVERTIDOS, PASTA_LIMPOS, PASTA_FINAL]:
    os.makedirs(pasta, exist_ok=True)

# %% [markdown]
# ## Etapa 2 – Funções de Normalização, Localização e Limpeza de Texto
# Esta etapa define funções auxiliares fundamentais para garantir a padronização dos nomes de arquivos, a localização dos PDFs corretos e a limpeza dos textos extraídos.
#
# Funções implementadas:
# - normalizar_texto(texto)
# - Padroniza o nome de documentos ou qualquer outro texto, tornando-o uniforme para fins de comparação e nomenclatura. Remove acentos, converte para minúsculas e substitui - caracteres especiais por underline (_). Essa função é essencial para que os nomes de arquivos e títulos da planilha sejam comparáveis de forma robusta.
#
# - localizar_pdf_local(nome_documento_original)
# Busca, dentro das subpastas do projeto, o arquivo PDF correspondente ao nome fornecido na planilha. Para isso, utiliza a função normalizar_texto e a técnica de fuzzy matching (semelhança textual aproximada) via difflib.get_close_matches, permitindo identificar arquivos mesmo que existam pequenas variações no nome.
#
# - limpar_texto(texto)
#
# - Remove ruídos comuns nos textos extraídos de PDFs, como cabeçalhos, rodapés e quebras de linha desnecessárias.
#
# A função:
#
# - Elimina linhas muito repetidas no corpo do texto;
#
# - Junta quebras de linha isoladas (geralmente causadas por limites de página);
#
# - Mantém as separações entre parágrafos com duplas quebras de linha.
#
# *Estas funções são reutilizadas em diversas etapas do pipeline e garantem a qualidade e a organização dos dados processados para uso posterior em análises, indexação e treinamento da IA.*

# %%
# === CONFIGURAÇÃO DO CAMINHO DO ARQUIVO DE CONTROLE ===
CAMINHO_PLANILHA = r"C:\Users\isisi\Documents\IAVS_PROJETO\controle_documentos.xlsx"
NOME_ABA = "docs"
LOG_DIAGNOSTICO = r"C:\Users\isisi\Documents\IAVS_PROJETO\log_diagnostico_etapa2.csv"

# === FUNÇÕES AUXILIARES ===

def calcular_hash(caminho_arquivo, limite=1024*1024):
    """Calcula hash de uma parte do arquivo (1 MB por padrão) para diagnóstico rápido."""
    sha256 = hashlib.sha256()
    with open(caminho_arquivo, 'rb') as f:
        sha256.update(f.read(limite))
    return sha256.hexdigest()

def normalizar_nome(nome):
    """Remove repetições consecutivas de sufixos no nome."""
    padrao = r'(txt_\w+\d{4})+'
    return re.sub(padrao, lambda m: m.group(1), nome)

def diagnosticar_planilha(planilha_path, aba, log_path):
    df = pd.read_excel(planilha_path, sheet_name=aba)
    hash_map = {}
    log_linhas = []

    # 🔄 Carrega os caminhos já processados anteriormente (se houver log salvo)
    arquivos_ja_processados = set()
    if os.path.exists(log_path):
        log_antigo = pd.read_csv(log_path)
        arquivos_ja_processados = set(log_antigo["Arquivo/Caminho"].dropna().unique())

    # 🔁 Loop sobre cada linha da planilha
    for idx, row in df.iterrows():
        caminho = str(row.get("Caminho", "")).strip()
        nome = str(row.get("Nome do arquivo", "")).strip()

        # ⏭️ Pula arquivos já processados antes
        if caminho in arquivos_ja_processados:
            continue

        if not caminho or not nome:
            log_linhas.append(["ERRO", f"Linha {idx+2}", "Caminho ou Nome do arquivo vazio", ""])
            continue

        if not os.path.isfile(caminho):
            log_linhas.append(["NÃO ENCONTRADO", caminho, "Arquivo não localizado", ""])
            continue

        # 🔎 Diagnóstico de duplicidade por hash
        hash_arquivo = calcular_hash(caminho)
        if hash_arquivo in hash_map:
            log_linhas.append(["DUPLICADO", caminho, "Hash igual a", hash_map[hash_arquivo]])
        else:
            hash_map[hash_arquivo] = caminho

        # 🧹 Diagnóstico de nome corrompido
        nome_base = os.path.basename(caminho).replace(".pdf", "")
        nome_normalizado = normalizar_nome(nome_base)
        if nome != nome_normalizado:
            log_linhas.append(["NOME_CORROMPIDO", caminho, "Nome informado difere do sugerido", nome_normalizado])

    # 💾 Salva ou atualiza o log
    if os.path.exists(log_path) and log_linhas:
        log_df_antigo = pd.read_csv(log_path)
        log_df_novo = pd.DataFrame(log_linhas, columns=["Tipo", "Arquivo/Caminho", "Info", "Referência/Sugestão"])
        log_df_final = pd.concat([log_df_antigo, log_df_novo], ignore_index=True)
        log_df_final.to_csv(log_path, index=False, encoding='utf-8')
        print(f"✅ Diagnóstico concluído. {len(log_linhas)} novos registros adicionados ao log.")
        print(f"📄 Log atualizado em: {log_path}")

    elif log_linhas:
        with open(log_path, mode='w', newline='', encoding='utf-8') as log_csv:
            writer = csv.writer(log_csv)
            writer.writerow(["Tipo", "Arquivo/Caminho", "Info", "Referência/Sugestão"])
            writer.writerows(log_linhas)
        print(f"✅ Diagnóstico concluído. {len(log_linhas)} registros salvos no log novo.")
        print(f"📄 Log salvo em: {log_path}")
    
    else:
        print("ℹ️ Nenhum novo arquivo a processar. Log mantido inalterado.")

# === EXECUTAR ===
if __name__ == "__main__":
    diagnosticar_planilha(CAMINHO_PLANILHA, NOME_ABA, LOG_DIAGNOSTICO)
# Out:
# ℹ️ Nenhum novo arquivo a processar. Log mantido inalterado.

# %% [markdown]
# ##  Etapa 3 – Classificação e Renomeação dos Documentos por Doença e Tipo
# Este trecho do script realiza a leitura da planilha de controle (controle_documentos.xlsx) e organiza os documentos PDF brutos em uma estrutura padronizada baseada nas doenças abordadas e no tipo de documento.
#
# **Objetivos:**
# - Ler os metadados dos documentos a partir da planilha preenchida manualmente;
#
# - Ignorar registros incompletos ou genéricos (como documentos marcados com “Diversas doenças”);
#
# - Utilizar a função localizar_pdf_local() para encontrar, via fuzzy matching, o caminho correto do PDF nas subpastas do projeto;
#
# - Para cada doença mencionada no documento:
#
# - Criar uma chave única combinando o nome da doença com o tipo de documento (ex: tuberculose_protocolo);
#
# - Utilizar um contador para evitar sobrescrições (ex: tuberculose_protocolo_1.pdf, tuberculose_protocolo_2.pdf...);
#
# - Copiar o arquivo PDF correspondente para a pasta pdfs_brutos, já com o novo nome padronizado.
#
# **Resultado esperado:**
# Ao final da execução, a pasta pdfs_brutos conterá todos os documentos localizados e renomeados de forma padronizada e rastreável, facilitando os próximos passos de extração de texto, organização temática e posterior uso pela IA.

# %%
# === CONFIGURAÇÕES ===
PLANILHA = r"C:\Users\isisi\Documents\IAVS_PROJETO\controle_documentos.xlsx"
NOME_ABA = "docs"
PASTA_BRUTOS = r"C:\Users\isisi\Documents\IAVS_PROJETO\pdfs_brutos"

# Garante que a pasta de destino existe
os.makedirs(PASTA_BRUTOS, exist_ok=True)

# Carrega a planilha de controle com os metadados dos documentos
df = pd.read_excel(PLANILHA, sheet_name=NOME_ABA)

# Dicionário para contar quantas vezes uma combinação (doença + tipo) já foi usada no nome de arquivos
contador_map = {}

# Itera sobre cada linha da planilha
for _, row in df.iterrows():
    nome_doc = str(row.get("Nome do Documento", "")).strip()
    tipo = str(row.get("Tipo", "")).lower().replace(" ", "_").strip()
    doencas_raw = str(row.get("Doenças abordadas", "")).strip()
    caminho_pdf = str(row.get("Caminho", "")).strip()

    # Ignora entradas incompletas ou genéricas
    if not nome_doc or not tipo or not doencas_raw or not caminho_pdf:
        continue
    if doencas_raw.lower().startswith("diversas") or not os.path.isfile(caminho_pdf):
        continue

    # Separa múltiplas doenças por delimitadores comuns
    doencas_lista = [d.strip().lower().replace(" ", "_") for d in re.split(r'[;,/]', doencas_raw)]

    for doenca in doencas_lista:
        chave = (doenca, tipo)
        contador_map[chave] = contador_map.get(chave, 0) + 1
        novo_nome = f"{doenca}_{tipo}_{contador_map[chave]}.pdf"
        destino = os.path.join(PASTA_BRUTOS, novo_nome)

        if os.path.exists(destino):
            print(f"⏭️ Já existente, ignorado: {novo_nome}")
            continue

        try:
            shutil.copy(caminho_pdf, destino)
            print(f"✅ Copiado: {novo_nome}")
        except Exception as e:
            print(f"❌ Erro ao copiar {caminho_pdf} → {destino}: {e}")
# Out:
# ⏭️ Já existente, ignorado: dengue_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: chikungunya_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: zika_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: febre_amarela_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: febre_do_nilo_ocidental_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: arboviroses_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: covid-19_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: dengue_protocolo_1.pdf
# ⏭️ Já existente, ignorado: sarampo_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: rubéola_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: coqueluche_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: difteria_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: tétano_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: hepatites_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: varicela_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: entre_outras_doenças_imunopreveníveis_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: dengue_protocolo_2.pdf
# ⏭️ Já existente, ignorado: chikungunya_protocolo_1.pdf
# ⏭️ Já existente, ignorado: zika_protocolo_1.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_1.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_2.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_3.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_4.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_5.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_6.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_7.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_8.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_9.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_10.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_11.pdf
# ⏭️ Já existente, ignorado: hepatite_d_(delta)_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: coinfecção_com_hepatite_b_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.pdf
# ⏭️ Já existente, ignorado: m._kansasii_protocolo_1.pdf
# ⏭️ Já existente, ignorado: m._abscessus_protocolo_1.pdf
# ⏭️ Já existente, ignorado: entre_outras_protocolo_1.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_12.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_13.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_14.pdf
# ⏭️ Já existente, ignorado: tuberculose_protocolo_15.pdf
# ⏭️ Já existente, ignorado: dengue_protocolo_3.pdf
# ⏭️ Já existente, ignorado: chikungunya_protocolo_2.pdf
# ⏭️ Já existente, ignorado: hepatites_protocolo_1.pdf
# ⏭️ Já existente, ignorado: zika_protocolo_2.pdf
# ⏭️ Já existente, ignorado: febre_amarela_protocolo_1.pdf
# ⏭️ Já existente, ignorado: sarampo_protocolo_1.pdf
# ⏭️ Já existente, ignorado: rubéola_protocolo_1.pdf
# ⏭️ Já existente, ignorado: leptospirose_protocolo_1.pdf
# ⏭️ Já existente, ignorado: entre_outras_protocolo_2.pdf
# ⏭️ Já existente, ignorado: dengue_protocolo_4.pdf
# ⏭️ Já existente, ignorado: chikungunya_protocolo_3.pdf
# ⏭️ Já existente, ignorado: zika_protocolo_3.pdf
# ⏭️ Já existente, ignorado: hanseníase_protocolo_1.pdf
# ⏭️ Já existente, ignorado: hanseníase_protocolo_2.pdf
# ⏭️ Já existente, ignorado: hanseníase_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: hanseníase_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: hanseníase_protocolo_3.pdf
# ⏭️ Já existente, ignorado: hanseníase_diretriz_nacional_1.pdf
# ⏭️ Já existente, ignorado: febre_amarela_protocolo_2.pdf
# ⏭️ Já existente, ignorado: febre_amarela_protocolo_3.pdf
# ⏭️ Já existente, ignorado: covid-19_guia_1.pdf
# ⏭️ Já existente, ignorado: influenza_guia_1.pdf
# ⏭️ Já existente, ignorado: vírus_sincicial_respiratório_(vsr)_guia_1.pdf
# ⏭️ Já existente, ignorado: adenovírus_guia_1.pdf
# ⏭️ Já existente, ignorado: metapneumovírus_guia_1.pdf
# ⏭️ Já existente, ignorado: parainfluenza_guia_1.pdf
# ⏭️ Já existente, ignorado: rinovírus_e_outros_respiratórios_guia_1.pdf
# ⏭️ Já existente, ignorado: influenza_guia_2.pdf
# ⏭️ Já existente, ignorado: hepatite_a_protocolo_1.pdf
# ⏭️ Já existente, ignorado: hepatite_b_protocolo_1.pdf
# ⏭️ Já existente, ignorado: hepatite_c_protocolo_1.pdf
# ⏭️ Já existente, ignorado: hepatite_d_protocolo_1.pdf
# ⏭️ Já existente, ignorado: hepatite_e_protocolo_1.pdf
# ⏭️ Já existente, ignorado: sífilis_protocolo_1.pdf
# ⏭️ Já existente, ignorado: gonorreia_protocolo_1.pdf
# ⏭️ Já existente, ignorado: clamídia_protocolo_1.pdf
# ⏭️ Já existente, ignorado: hepatite_b_e_c_(ist)_protocolo_1.pdf
# ⏭️ Já existente, ignorado: hpv_protocolo_1.pdf
# ⏭️ Já existente, ignorado: herpes_genital_protocolo_1.pdf
# ⏭️ Já existente, ignorado: cancro_mole_protocolo_1.pdf
# ⏭️ Já existente, ignorado: linfogranuloma_venéreo_protocolo_1.pdf
# ⏭️ Já existente, ignorado: cólera_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: leptospirose_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: leptospirose_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: leptospirose_nota_técnica_3.pdf
# ⏭️ Já existente, ignorado: zoonoses_manual_1.pdf
# ⏭️ Já existente, ignorado: raiva_humana_protocolo_1.pdf
# ⏭️ Já existente, ignorado: raiva_humana_protocolo_2.pdf
# ⏭️ Já existente, ignorado: leptospirose_manual_1.pdf
# ⏭️ Já existente, ignorado: hantavirose_manual_1.pdf
# ⏭️ Já existente, ignorado: peste_manual_1.pdf
# ⏭️ Já existente, ignorado: outras_zoonoses_transmitidas_por_roedores_manual_1.pdf
# ⏭️ Já existente, ignorado: leishmaniose_manual_1.pdf
# ⏭️ Já existente, ignorado: hantavirose_manual_2.pdf
# ⏭️ Já existente, ignorado: peste_manual_2.pdf
# ⏭️ Já existente, ignorado: sarampo_protocolo_2.pdf
# ⏭️ Já existente, ignorado: rubéola_protocolo_2.pdf
# ⏭️ Já existente, ignorado: síndrome_da_rubéola_congênita_(src)_protocolo_1.pdf
# ⏭️ Já existente, ignorado: sarampo_protocolo_3.pdf
# ⏭️ Já existente, ignorado: sarampo_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: rubéola_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: síndrome_da_rubéola_congênita_(src)_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: rubéola_nota_técnica_3.pdf
# ⏭️ Já existente, ignorado: síndrome_da_rubéola_congênita_(src)_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: poliomielite_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: poliomielite_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: poliomielite_nota_técnica_3.pdf
# ⏭️ Já existente, ignorado: poliomielite_diretriz_nacional_1.pdf
# ⏭️ Já existente, ignorado: coqueluche_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: coqueluche_nota_técnica_3.pdf
# ⏭️ Já existente, ignorado: meningite_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: malária_guia_1.pdf
# ⏭️ Já existente, ignorado: malária_manual_1.pdf
# ⏭️ Já existente, ignorado: hepatite_a_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: hiv_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: hpv_nota_técnica_1.pdf
# ⏭️ Já existente, ignorado: hepatite_a_nota_técnica_2.pdf
# ⏭️ Já existente, ignorado: sífilis_manual_1.pdf

# %% [markdown]
# **Etapa 4 – Conversão de PDFs para Texto (.txt)**
# Este bloco realiza a conversão dos arquivos PDF classificados na etapa anterior para arquivos de texto simples (.txt), permitindo que seu conteúdo possa ser tratado, limpo e analisado posteriormente.
#
# Objetivos:
# - Ler os PDFs localizados na pasta pdfs_brutos;
#
# - Verificar se a conversão já foi feita anteriormente para evitar retrabalho;
#
# - Utilizar a biblioteca pdfplumber para extrair o texto de cada página;
#
# - Salvar o conteúdo textual extraído em arquivos .txt com codificação UTF-8;
#
# - Exibir mensagens de progresso, avisos de falhas e medir o tempo total da operação.
#
# *Essa etapa é fundamental para garantir que todo o conteúdo dos documentos esteja disponível em formato editável, possibilitando sua limpeza e categorização por inteligência artificial.*

# %%
# === CONFIGURAÇÕES ===
PASTA_BRUTOS = r"C:\Users\isisi\Documents\IAVS_PROJETO\pdfs_brutos"
PASTA_CONVERTIDOS = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_convertidos"

# Garante que a pasta de destino existe
os.makedirs(PASTA_CONVERTIDOS, exist_ok=True)

# ⏱️ Início da contagem de tempo
start = time.time()

# Itera sobre todos os arquivos da pasta de PDFs brutos
for arquivo in os.listdir(PASTA_BRUTOS):
    if arquivo.endswith(".pdf"):
        # Define o nome e caminho do arquivo .txt correspondente
        nome_txt = arquivo.replace(".pdf", ".txt")
        caminho_txt = os.path.join(PASTA_CONVERTIDOS, nome_txt)

        # ✅ Pula se o arquivo já foi convertido anteriormente
        if os.path.exists(caminho_txt):
            print(f"⏭️ Já convertido: {nome_txt}")
            continue

        # Caminho completo do PDF de origem
        caminho_pdf = os.path.join(PASTA_BRUTOS, arquivo)
        print(f"🔄 Convertendo: {arquivo}")

        try:
            # Abre o PDF com pdfplumber e extrai o texto de cada página
            with pdfplumber.open(caminho_pdf) as pdf:
                texto = "\n".join(page.extract_text() or '' for page in pdf.pages)

            # Verifica se o texto extraído está vazio
            if not texto.strip():
                print(f"⚠️ Texto vazio: {arquivo}")
                continue

            # Salva o texto extraído em um arquivo .txt
            with open(caminho_txt, "w", encoding="utf-8") as f:
                f.write(texto)

            print(f"✅ Texto salvo: {nome_txt}")

        except Exception as e:
            # Exibe erro caso a conversão falhe
            print(f"❌ Erro ao converter {arquivo}: {e}")

# ⏱️ Exibe tempo total de execução da conversão
print(f"⏱️ Conversão finalizada em {time.time() - start:.2f} segundos")
# Out:
# ⏭️ Já convertido: adenovírus_guia_1.txt
# ⏭️ Já convertido: arboviroses_nota_técnica_1.txt
# ⏭️ Já convertido: cancro_mole_protocolo_1.txt
# ⏭️ Já convertido: chikungunya_nota_técnica_1.txt
# ⏭️ Já convertido: chikungunya_protocolo_1.txt
# ⏭️ Já convertido: chikungunya_protocolo_2.txt
# ⏭️ Já convertido: chikungunya_protocolo_3.txt
# ⏭️ Já convertido: clamídia_protocolo_1.txt
# ⏭️ Já convertido: coinfecção_com_hepatite_b_nota_técnica_1.txt
# ⏭️ Já convertido: coqueluche_nota_técnica_1.txt
# ⏭️ Já convertido: coqueluche_nota_técnica_2.txt
# ⏭️ Já convertido: coqueluche_nota_técnica_3.txt
# ⏭️ Já convertido: covid-19_guia_1.txt
# ⏭️ Já convertido: covid-19_nota_técnica_1.txt
# ⏭️ Já convertido: cólera_nota_técnica_1.txt
# ⏭️ Já convertido: dengue_nota_técnica_1.txt
# ⏭️ Já convertido: dengue_protocolo_1.txt
# ⏭️ Já convertido: dengue_protocolo_2.txt
# ⏭️ Já convertido: dengue_protocolo_3.txt
# ⏭️ Já convertido: dengue_protocolo_4.txt
# ⏭️ Já convertido: difteria_nota_técnica_1.txt
# ⏭️ Já convertido: entre_outras_doenças_imunopreveníveis_nota_técnica_1.txt
# ⏭️ Já convertido: entre_outras_protocolo_1.txt
# ⏭️ Já convertido: entre_outras_protocolo_2.txt
# ⏭️ Já convertido: febre_amarela_nota_técnica_1.txt
# ⏭️ Já convertido: febre_amarela_protocolo_1.txt
# ⏭️ Já convertido: febre_amarela_protocolo_2.txt
# ⏭️ Já convertido: febre_amarela_protocolo_3.txt
# ⏭️ Já convertido: febre_do_nilo_ocidental_nota_técnica_1.txt
# ⏭️ Já convertido: gonorreia_protocolo_1.txt
# ⏭️ Já convertido: hanseníase_diretriz_nacional_1.txt
# ⏭️ Já convertido: hanseníase_nota_técnica_1.txt
# ⏭️ Já convertido: hanseníase_nota_técnica_2.txt
# ⏭️ Já convertido: hanseníase_protocolo_1.txt
# ⏭️ Já convertido: hanseníase_protocolo_2.txt
# ⏭️ Já convertido: hanseníase_protocolo_3.txt
# ⏭️ Já convertido: hantavirose_manual_1.txt
# ⏭️ Já convertido: hantavirose_manual_2.txt
# ⏭️ Já convertido: hepatites_nota_técnica_1.txt
# ⏭️ Já convertido: hepatites_protocolo_1.txt
# ⏭️ Já convertido: hepatite_a_nota_técnica_1.txt
# ⏭️ Já convertido: hepatite_a_nota_técnica_2.txt
# ⏭️ Já convertido: hepatite_a_protocolo_1.txt
# ⏭️ Já convertido: hepatite_b_e_c_(ist)_protocolo_1.txt
# ⏭️ Já convertido: hepatite_b_protocolo_1.txt
# ⏭️ Já convertido: hepatite_c_protocolo_1.txt
# ⏭️ Já convertido: hepatite_d_(delta)_nota_técnica_1.txt
# ⏭️ Já convertido: hepatite_d_protocolo_1.txt
# ⏭️ Já convertido: hepatite_e_protocolo_1.txt
# ⏭️ Já convertido: herpes_genital_protocolo_1.txt
# ⏭️ Já convertido: hiv_nota_técnica_1.txt
# ⏭️ Já convertido: hpv_nota_técnica_1.txt
# ⏭️ Já convertido: hpv_protocolo_1.txt
# ⏭️ Já convertido: influenza_guia_1.txt
# ⏭️ Já convertido: influenza_guia_2.txt
# ⏭️ Já convertido: leishmaniose_manual_1.txt
# ⏭️ Já convertido: leptospirose_manual_1.txt
# ⏭️ Já convertido: leptospirose_nota_técnica_1.txt
# ⏭️ Já convertido: leptospirose_nota_técnica_2.txt
# ⏭️ Já convertido: leptospirose_nota_técnica_3.txt
# ⏭️ Já convertido: leptospirose_protocolo_1.txt
# ⏭️ Já convertido: linfogranuloma_venéreo_protocolo_1.txt
# ⏭️ Já convertido: m._abscessus_protocolo_1.txt
# ⏭️ Já convertido: m._kansasii_protocolo_1.txt
# ⏭️ Já convertido: malária_guia_1.txt
# ⏭️ Já convertido: malária_manual_1.txt
# ⏭️ Já convertido: meningite_nota_técnica_1.txt
# ⏭️ Já convertido: metapneumovírus_guia_1.txt
# ⏭️ Já convertido: micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.txt
# ⏭️ Já convertido: outras_zoonoses_transmitidas_por_roedores_manual_1.txt
# ⏭️ Já convertido: parainfluenza_guia_1.txt
# ⏭️ Já convertido: peste_manual_1.txt
# ⏭️ Já convertido: peste_manual_2.txt
# ⏭️ Já convertido: poliomielite_diretriz_nacional_1.txt
# 🔄 Convertendo: poliomielite_nota_técnica_1.pdf
# ⚠️ Texto vazio: poliomielite_nota_técnica_1.pdf
# ⏭️ Já convertido: poliomielite_nota_técnica_2.txt
# ⏭️ Já convertido: poliomielite_nota_técnica_3.txt
# ⏭️ Já convertido: raiva_humana_protocolo_1.txt
# ⏭️ Já convertido: raiva_humana_protocolo_2.txt
# ⏭️ Já convertido: rinovírus_e_outros_respiratórios_guia_1.txt
# ⏭️ Já convertido: rubéola_nota_técnica_1.txt
# ⏭️ Já convertido: rubéola_nota_técnica_2.txt
# ⏭️ Já convertido: rubéola_nota_técnica_3.txt
# ⏭️ Já convertido: rubéola_protocolo_1.txt
# ⏭️ Já convertido: rubéola_protocolo_2.txt
# ⏭️ Já convertido: sarampo_nota_técnica_1.txt
# ⏭️ Já convertido: sarampo_nota_técnica_2.txt
# ⏭️ Já convertido: sarampo_protocolo_1.txt
# ⏭️ Já convertido: sarampo_protocolo_2.txt
# ⏭️ Já convertido: sarampo_protocolo_3.txt
# ⏭️ Já convertido: sífilis_manual_1.txt
# ⏭️ Já convertido: sífilis_protocolo_1.txt
# ⏭️ Já convertido: síndrome_da_rubéola_congênita_(src)_nota_técnica_1.txt
# ⏭️ Já convertido: síndrome_da_rubéola_congênita_(src)_nota_técnica_2.txt
# ⏭️ Já convertido: síndrome_da_rubéola_congênita_(src)_protocolo_1.txt
# ⏭️ Já convertido: tuberculose_protocolo_1.txt
# ⏭️ Já convertido: tuberculose_protocolo_10.txt
# ⏭️ Já convertido: tuberculose_protocolo_11.txt
# 🔄 Convertendo: tuberculose_protocolo_12.pdf
# ⚠️ Texto vazio: tuberculose_protocolo_12.pdf
# ⏭️ Já convertido: tuberculose_protocolo_13.txt
# ⏭️ Já convertido: tuberculose_protocolo_14.txt
# ⏭️ Já convertido: tuberculose_protocolo_15.txt
# ⏭️ Já convertido: tuberculose_protocolo_2.txt
# ⏭️ Já convertido: tuberculose_protocolo_3.txt
# ⏭️ Já convertido: tuberculose_protocolo_4.txt
# ⏭️ Já convertido: tuberculose_protocolo_5.txt
# ⏭️ Já convertido: tuberculose_protocolo_6.txt
# ⏭️ Já convertido: tuberculose_protocolo_7.txt
# ⏭️ Já convertido: tuberculose_protocolo_8.txt
# ⏭️ Já convertido: tuberculose_protocolo_9.txt
# ⏭️ Já convertido: tétano_nota_técnica_1.txt
# ⏭️ Já convertido: varicela_nota_técnica_1.txt
# ⏭️ Já convertido: vírus_sincicial_respiratório_(vsr)_guia_1.txt
# ⏭️ Já convertido: zika_nota_técnica_1.txt
# ⏭️ Já convertido: zika_protocolo_1.txt
# ⏭️ Já convertido: zika_protocolo_2.txt
# ⏭️ Já convertido: zika_protocolo_3.txt
# ⏭️ Já convertido: zoonoses_manual_1.txt
# ⏱️ Conversão finalizada em 54.08 segundos

# %% [markdown]
# ## Etapa 5 – Limpeza dos Textos Extraídos
# Após a conversão dos PDFs em arquivos .txt, esta etapa realiza uma limpeza estruturada do conteúdo textual para remover ruídos típicos da extração, como espaços excessivos, quebras de linha desnecessárias, artefatos de paginação e formatações indesejadas.
#
# **Objetivos:**
# - Processar todos os arquivos .txt gerados anteriormente;
#
# - Aplicar uma função de limpeza que corrige:
#
# - Quebras de linha duplas ou múltiplas;
#
# - Espaços repetidos e tabulações;
#
# - Espaços no início de linhas;
#
# - Padrões comuns de numeração de páginas (“Página X de Y”);
#
# - Salvar os textos tratados na pasta textos_limpos, preservando o nome do arquivo original.
#
# *Essa limpeza é essencial para garantir que o conteúdo esteja formatado de maneira uniforme e pronto para ser classificado, indexado e posteriormente analisado por modelos de inteligência artificial.*

# %%
# === CONFIGURAÇÕES ===
PASTA_CONVERTIDOS = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_convertidos"
PASTA_LIMPOS = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_limpos"
LOG_DIAGNOSTICO = os.path.join(PASTA_LIMPOS, "log_diagnostico.csv")
os.makedirs(PASTA_LIMPOS, exist_ok=True)

def limpar_texto(texto):
    """
    Realiza limpeza básica do texto extraído:
    - Remove múltiplas quebras de linha
    - Substitui espaços e tabulações repetidas por um único espaço
    - Remove espaços no início das linhas
    - Elimina marcações de página como "Página 3 de 12"
    """
    texto = re.sub(r'\n{2,}', '\n\n', texto)
    texto = re.sub(r'[ \t]+', ' ', texto)
    texto = re.sub(r'^\s+', '', texto, flags=re.MULTILINE)
    texto = re.sub(r'Página\s+\d+\s+de\s+\d+', '', texto, flags=re.IGNORECASE)
    return texto.strip()

def calcular_hash(caminho_arquivo, limite=1024*1024):
    """Calcula hash parcial (1MB) de um arquivo."""
    sha256 = hashlib.sha256()
    with open(caminho_arquivo, 'rb') as f:
        sha256.update(f.read(limite))
    return sha256.hexdigest()

# === CARREGA HASHES JÁ PROCESSADOS DO LOG ===
hash_map = {}
if os.path.exists(LOG_DIAGNOSTICO):
    with open(LOG_DIAGNOSTICO, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        next(reader)  # pula o cabeçalho
        for linha in reader:
            if linha[0] == "DUPLICADO":
                continue
            hash_map[linha[1]] = linha[3]  # caminho → hash salvo

# === PROCESSA ARQUIVOS .TXT ===
log_linhas = []

print(f"Limpando arquivos em: {PASTA_CONVERTIDOS}")
for arquivo in os.listdir(PASTA_CONVERTIDOS):
    if arquivo.endswith(".txt"):
        caminho_origem = os.path.join(PASTA_CONVERTIDOS, arquivo)
        caminho_destino = os.path.join(PASTA_LIMPOS, arquivo)

        hash_origem = calcular_hash(caminho_origem)

        # Se já processado e hash bate, pula
        if caminho_origem in hash_map and hash_map[caminho_origem] == hash_origem:
            print(f"⏭️ Já limpo: {arquivo}")
            continue

        try:
            with open(caminho_origem, "r", encoding="utf-8", errors="ignore") as f:
                conteudo = f.read()

            texto_limpo = limpar_texto(conteudo)

            with open(caminho_destino, "w", encoding="utf-8") as f:
                f.write(texto_limpo)

            print(f"✅ Limpo e salvo: {arquivo}")
            log_linhas.append(["LIMPO", caminho_origem, "Hash original", hash_origem])

        except Exception as e:
            print(f"❌ Erro ao processar {arquivo}: {e}")
            log_linhas.append(["ERRO", caminho_origem, "Exceção", str(e)])

# === SALVA LOG FINAL ===
with open(LOG_DIAGNOSTICO, mode='a', newline='', encoding='utf-8') as log_csv:
    writer = csv.writer(log_csv)
    if os.stat(LOG_DIAGNOSTICO).st_size == 0:
        writer.writerow(["Tipo", "Arquivo", "Info", "Referência/Sugestão"])
    writer.writerows(log_linhas)

print("🏁 Finalizado.")
# Out:
# Limpando arquivos em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_convertidos
# ⏭️ Já limpo: adenovírus_guia_1.txt
# ⏭️ Já limpo: arboviroses_nota_técnica_1.txt
# ⏭️ Já limpo: cancro_mole_protocolo_1.txt
# ⏭️ Já limpo: chikungunya_nota_técnica_1.txt
# ⏭️ Já limpo: chikungunya_protocolo_1.txt
# ⏭️ Já limpo: chikungunya_protocolo_2.txt
# ⏭️ Já limpo: chikungunya_protocolo_3.txt
# ⏭️ Já limpo: clamídia_protocolo_1.txt
# ⏭️ Já limpo: coinfecção_com_hepatite_b_nota_técnica_1.txt
# ⏭️ Já limpo: coqueluche_nota_técnica_1.txt
# ⏭️ Já limpo: coqueluche_nota_técnica_2.txt
# ⏭️ Já limpo: coqueluche_nota_técnica_3.txt
# ⏭️ Já limpo: covid-19_guia_1.txt
# ⏭️ Já limpo: covid-19_nota_técnica_1.txt
# ⏭️ Já limpo: cólera_nota_técnica_1.txt
# ⏭️ Já limpo: dengue_nota_técnica_1.txt
# ⏭️ Já limpo: dengue_protocolo_1.txt
# ⏭️ Já limpo: dengue_protocolo_2.txt
# ⏭️ Já limpo: dengue_protocolo_3.txt
# ⏭️ Já limpo: dengue_protocolo_4.txt
# ⏭️ Já limpo: difteria_nota_técnica_1.txt
# ⏭️ Já limpo: entre_outras_doenças_imunopreveníveis_nota_técnica_1.txt
# ⏭️ Já limpo: entre_outras_protocolo_1.txt
# ⏭️ Já limpo: entre_outras_protocolo_2.txt
# ⏭️ Já limpo: febre_amarela_nota_técnica_1.txt
# ⏭️ Já limpo: febre_amarela_protocolo_1.txt
# ⏭️ Já limpo: febre_amarela_protocolo_2.txt
# ⏭️ Já limpo: febre_amarela_protocolo_3.txt
# ⏭️ Já limpo: febre_do_nilo_ocidental_nota_técnica_1.txt
# ⏭️ Já limpo: gonorreia_protocolo_1.txt
# ⏭️ Já limpo: hanseníase_diretriz_nacional_1.txt
# ⏭️ Já limpo: hanseníase_nota_técnica_1.txt
# ⏭️ Já limpo: hanseníase_nota_técnica_2.txt
# ⏭️ Já limpo: hanseníase_protocolo_1.txt
# ⏭️ Já limpo: hanseníase_protocolo_2.txt
# ⏭️ Já limpo: hanseníase_protocolo_3.txt
# ⏭️ Já limpo: hantavirose_manual_1.txt
# ⏭️ Já limpo: hantavirose_manual_2.txt
# ⏭️ Já limpo: hepatites_nota_técnica_1.txt
# ⏭️ Já limpo: hepatites_protocolo_1.txt
# ⏭️ Já limpo: hepatite_a_nota_técnica_1.txt
# ⏭️ Já limpo: hepatite_a_nota_técnica_2.txt
# ⏭️ Já limpo: hepatite_a_protocolo_1.txt
# ⏭️ Já limpo: hepatite_b_e_c_(ist)_protocolo_1.txt
# ⏭️ Já limpo: hepatite_b_protocolo_1.txt
# ⏭️ Já limpo: hepatite_c_protocolo_1.txt
# ⏭️ Já limpo: hepatite_d_(delta)_nota_técnica_1.txt
# ⏭️ Já limpo: hepatite_d_protocolo_1.txt
# ⏭️ Já limpo: hepatite_e_protocolo_1.txt
# ⏭️ Já limpo: herpes_genital_protocolo_1.txt
# ⏭️ Já limpo: hiv_nota_técnica_1.txt
# ⏭️ Já limpo: hpv_nota_técnica_1.txt
# ⏭️ Já limpo: hpv_protocolo_1.txt
# ⏭️ Já limpo: influenza_guia_1.txt
# ⏭️ Já limpo: influenza_guia_2.txt
# ⏭️ Já limpo: leishmaniose_manual_1.txt
# ⏭️ Já limpo: leptospirose_manual_1.txt
# ⏭️ Já limpo: leptospirose_nota_técnica_1.txt
# ⏭️ Já limpo: leptospirose_nota_técnica_2.txt
# ⏭️ Já limpo: leptospirose_nota_técnica_3.txt
# ⏭️ Já limpo: leptospirose_protocolo_1.txt
# ⏭️ Já limpo: linfogranuloma_venéreo_protocolo_1.txt
# ⏭️ Já limpo: m._abscessus_protocolo_1.txt
# ⏭️ Já limpo: m._kansasii_protocolo_1.txt
# ⏭️ Já limpo: malária_guia_1.txt
# ⏭️ Já limpo: malária_manual_1.txt
# ⏭️ Já limpo: meningite_nota_técnica_1.txt
# ⏭️ Já limpo: metapneumovírus_guia_1.txt
# ⏭️ Já limpo: micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.txt
# ⏭️ Já limpo: outras_zoonoses_transmitidas_por_roedores_manual_1.txt
# ⏭️ Já limpo: parainfluenza_guia_1.txt
# ⏭️ Já limpo: peste_manual_1.txt
# ⏭️ Já limpo: peste_manual_2.txt
# ⏭️ Já limpo: poliomielite_diretriz_nacional_1.txt
# ⏭️ Já limpo: poliomielite_nota_técnica_2.txt
# ⏭️ Já limpo: poliomielite_nota_técnica_3.txt
# ⏭️ Já limpo: raiva_humana_protocolo_1.txt
# ⏭️ Já limpo: raiva_humana_protocolo_2.txt
# ⏭️ Já limpo: rinovírus_e_outros_respiratórios_guia_1.txt
# ⏭️ Já limpo: rubéola_nota_técnica_1.txt
# ⏭️ Já limpo: rubéola_nota_técnica_2.txt
# ⏭️ Já limpo: rubéola_nota_técnica_3.txt
# ⏭️ Já limpo: rubéola_protocolo_1.txt
# ⏭️ Já limpo: rubéola_protocolo_2.txt
# ⏭️ Já limpo: sarampo_nota_técnica_1.txt
# ⏭️ Já limpo: sarampo_nota_técnica_2.txt
# ⏭️ Já limpo: sarampo_protocolo_1.txt
# ⏭️ Já limpo: sarampo_protocolo_2.txt
# ⏭️ Já limpo: sarampo_protocolo_3.txt
# ⏭️ Já limpo: sífilis_manual_1.txt
# ⏭️ Já limpo: sífilis_protocolo_1.txt
# ⏭️ Já limpo: síndrome_da_rubéola_congênita_(src)_nota_técnica_1.txt
# ⏭️ Já limpo: síndrome_da_rubéola_congênita_(src)_nota_técnica_2.txt
# ⏭️ Já limpo: síndrome_da_rubéola_congênita_(src)_protocolo_1.txt
# ⏭️ Já limpo: tuberculose_protocolo_1.txt
# ⏭️ Já limpo: tuberculose_protocolo_10.txt
# ⏭️ Já limpo: tuberculose_protocolo_11.txt
# ⏭️ Já limpo: tuberculose_protocolo_13.txt
# ⏭️ Já limpo: tuberculose_protocolo_14.txt
# ⏭️ Já limpo: tuberculose_protocolo_15.txt
# ⏭️ Já limpo: tuberculose_protocolo_2.txt
# ⏭️ Já limpo: tuberculose_protocolo_3.txt
# ⏭️ Já limpo: tuberculose_protocolo_4.txt
# ⏭️ Já limpo: tuberculose_protocolo_5.txt
# ⏭️ Já limpo: tuberculose_protocolo_6.txt
# ⏭️ Já limpo: tuberculose_protocolo_7.txt
# ⏭️ Já limpo: tuberculose_protocolo_8.txt
# ⏭️ Já limpo: tuberculose_protocolo_9.txt
# ⏭️ Já limpo: tétano_nota_técnica_1.txt
# ⏭️ Já limpo: varicela_nota_técnica_1.txt
# ⏭️ Já limpo: vírus_sincicial_respiratório_(vsr)_guia_1.txt
# ⏭️ Já limpo: zika_nota_técnica_1.txt
# ⏭️ Já limpo: zika_protocolo_1.txt
# ⏭️ Já limpo: zika_protocolo_2.txt
# ⏭️ Já limpo: zika_protocolo_3.txt
# ⏭️ Já limpo: zoonoses_manual_1.txt
# 🏁 Finalizado.

# %%
# === CONFIGURAÇÕES ===
PASTA_ORIGEM = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_convertidos"
PASTA_DESTINO = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_limpos"
os.makedirs(PASTA_DESTINO, exist_ok=True)

# === PADRÕES E SÍMBOLOS A REMOVER ===
CARACTERES_CORROMPIDOS = ['', '', '']

PADROES_LINHAS_REMOVER = [
    r'^Página\s+\d+\s+de\s+\d+',
    r'^ISBN\s+',
    r'^202\d+.*',
    r'^\d{1,3}$',
    r'^[A-ZÀ-Ú\s]{2,}$',
    r'^http[s]?://',
    r'^Ministério da Saúde',
    r'^Coordenação-Geral|^Departamento|^Secretaria|^Editora|^Projeto gráfico',
    r'^Ficha Catalográfica',
    r'^Catalogação na fonte',
    r'^Lista de abreviaturas e siglas$',
    r'^Sumário$',
    r'^.*TABELA\s+\d+.*$',
    r'^[^\w\s]*$',
    r'^.{5,}\.{3,}\s*\d{1,3}$',
]

PADROES_TRECHOS_REMOVER = [
    r'Ministério da Saúde.*?www\.saude\.gov\.br.*?\n\n',
    r'©? ?202\d+.*?(Creative Commons|Licença|Reprodução|Distribuição).*?\n\n',
    r'Projeto gráfico:.*?Revisão:.*?\n\n',
]

# === FUNÇÕES ===

def remover_blocos_de_sumario(texto): #remover blocos de sumário
    """
    Remove linhas que parecem ser sumários, mantendo apenas as linhas recentes.
    Um sumário é identificado por um padrão específico de numeração e texto.
    """
    linhas = texto.splitlines()
    linhas_filtradas = []
    padrao_sumario = re.compile(r'^\d+(\.\d+)*\s+.+?\.{3,}\s*\d{1,3}$')
    linhas_recentes = []

    for linha in linhas:
        linha_strip = linha.strip()
        if padrao_sumario.match(linha_strip):
            linhas_recentes.append(linha_strip)
            continue
        elif linhas_recentes:
            linhas_recentes = []
        linhas_filtradas.append(linha)

    return "\n".join(linhas_filtradas)

def remover_bloco_institucional(texto): #remover bloco institucional
    match = re.search(r'(?i)\n\s*(1[\.\s]|INTRODUÇÃO|APRESENTAÇÃO)\b', texto)
    if match:
        return texto[match.start():]
    return texto

def limpar_texto_avancado(texto):
    for char in CARACTERES_CORROMPIDOS:
        texto = texto.replace(char, '')

    for padrao in PADROES_TRECHOS_REMOVER:
        texto = re.sub(padrao, '', texto, flags=re.DOTALL | re.IGNORECASE)

    linhas = texto.splitlines()
    linhas_filtradas = []
    for linha in linhas:
        if any(re.match(p, linha.strip(), re.IGNORECASE) for p in PADROES_LINHAS_REMOVER):
            continue
        if len(linha.strip()) < 3:
            continue
        linhas_filtradas.append(linha)

    texto_base = "\n".join(linhas_filtradas)
    texto_sem_sumario = remover_blocos_de_sumario(texto_base)
    texto_sem_cabecalho = remover_bloco_institucional(texto_sem_sumario)
    texto_final = re.sub(r'\n{2,}', '\n\n', texto_sem_cabecalho)

    return texto_final.strip()

# === EXECUÇÃO ===

print(f"🔍 Limpando arquivos em: {PASTA_ORIGEM}")
for arquivo in os.listdir(PASTA_ORIGEM):
    if arquivo.endswith(".txt"):
        origem = os.path.join(PASTA_ORIGEM, arquivo)
        destino = os.path.join(PASTA_DESTINO, arquivo)

        with open(origem, "r", encoding="utf-8", errors="ignore") as f:
            conteudo = f.read()

        texto_limpo = limpar_texto_avancado(conteudo)

        with open(destino, "w", encoding="utf-8") as f:
            f.write(texto_limpo)

        print(f"✅ Arquivo limpo e salvo: {arquivo}")

print("🏁 Limpeza avançada com sumário, ficha institucional e cabeçalho finalizada.")
# Out:
# 🔍 Limpando arquivos em: C:\Users\isisi\Documents\IAVS_PROJETO\textos_convertidos
# ✅ Arquivo limpo e salvo: adenovírus_guia_1.txt
# ✅ Arquivo limpo e salvo: arboviroses_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: cancro_mole_protocolo_1.txt
# ✅ Arquivo limpo e salvo: chikungunya_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: chikungunya_protocolo_1.txt
# ✅ Arquivo limpo e salvo: chikungunya_protocolo_2.txt
# ✅ Arquivo limpo e salvo: chikungunya_protocolo_3.txt
# ✅ Arquivo limpo e salvo: clamídia_protocolo_1.txt
# ✅ Arquivo limpo e salvo: coinfecção_com_hepatite_b_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: coqueluche_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: coqueluche_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: coqueluche_nota_técnica_3.txt
# ✅ Arquivo limpo e salvo: covid-19_guia_1.txt
# ✅ Arquivo limpo e salvo: covid-19_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: cólera_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: dengue_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: dengue_protocolo_1.txt
# ✅ Arquivo limpo e salvo: dengue_protocolo_2.txt
# ✅ Arquivo limpo e salvo: dengue_protocolo_3.txt
# ✅ Arquivo limpo e salvo: dengue_protocolo_4.txt
# ✅ Arquivo limpo e salvo: difteria_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: entre_outras_doenças_imunopreveníveis_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: entre_outras_protocolo_1.txt
# ✅ Arquivo limpo e salvo: entre_outras_protocolo_2.txt
# ✅ Arquivo limpo e salvo: febre_amarela_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: febre_amarela_protocolo_1.txt
# ✅ Arquivo limpo e salvo: febre_amarela_protocolo_2.txt
# ✅ Arquivo limpo e salvo: febre_amarela_protocolo_3.txt
# ✅ Arquivo limpo e salvo: febre_do_nilo_ocidental_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: gonorreia_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hanseníase_diretriz_nacional_1.txt
# ✅ Arquivo limpo e salvo: hanseníase_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: hanseníase_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: hanseníase_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hanseníase_protocolo_2.txt
# ✅ Arquivo limpo e salvo: hanseníase_protocolo_3.txt
# ✅ Arquivo limpo e salvo: hantavirose_manual_1.txt
# ✅ Arquivo limpo e salvo: hantavirose_manual_2.txt
# ✅ Arquivo limpo e salvo: hepatites_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: hepatites_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hepatite_a_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: hepatite_a_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: hepatite_a_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hepatite_b_e_c_(ist)_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hepatite_b_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hepatite_c_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hepatite_d_(delta)_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: hepatite_d_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hepatite_e_protocolo_1.txt
# ✅ Arquivo limpo e salvo: herpes_genital_protocolo_1.txt
# ✅ Arquivo limpo e salvo: hiv_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: hpv_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: hpv_protocolo_1.txt
# ✅ Arquivo limpo e salvo: influenza_guia_1.txt
# ✅ Arquivo limpo e salvo: influenza_guia_2.txt
# ✅ Arquivo limpo e salvo: leishmaniose_manual_1.txt
# ✅ Arquivo limpo e salvo: leptospirose_manual_1.txt
# ✅ Arquivo limpo e salvo: leptospirose_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: leptospirose_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: leptospirose_nota_técnica_3.txt
# ✅ Arquivo limpo e salvo: leptospirose_protocolo_1.txt
# ✅ Arquivo limpo e salvo: linfogranuloma_venéreo_protocolo_1.txt
# ✅ Arquivo limpo e salvo: m._abscessus_protocolo_1.txt
# ✅ Arquivo limpo e salvo: m._kansasii_protocolo_1.txt
# ✅ Arquivo limpo e salvo: malária_guia_1.txt
# ✅ Arquivo limpo e salvo: malária_manual_1.txt
# ✅ Arquivo limpo e salvo: meningite_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: metapneumovírus_guia_1.txt
# ✅ Arquivo limpo e salvo: micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.txt
# ✅ Arquivo limpo e salvo: outras_zoonoses_transmitidas_por_roedores_manual_1.txt
# ✅ Arquivo limpo e salvo: parainfluenza_guia_1.txt
# ✅ Arquivo limpo e salvo: peste_manual_1.txt
# ✅ Arquivo limpo e salvo: peste_manual_2.txt
# ✅ Arquivo limpo e salvo: poliomielite_diretriz_nacional_1.txt
# ✅ Arquivo limpo e salvo: poliomielite_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: poliomielite_nota_técnica_3.txt
# ✅ Arquivo limpo e salvo: raiva_humana_protocolo_1.txt
# ✅ Arquivo limpo e salvo: raiva_humana_protocolo_2.txt
# ✅ Arquivo limpo e salvo: rinovírus_e_outros_respiratórios_guia_1.txt
# ✅ Arquivo limpo e salvo: rubéola_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: rubéola_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: rubéola_nota_técnica_3.txt
# ✅ Arquivo limpo e salvo: rubéola_protocolo_1.txt
# ✅ Arquivo limpo e salvo: rubéola_protocolo_2.txt
# ✅ Arquivo limpo e salvo: sarampo_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: sarampo_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: sarampo_protocolo_1.txt
# ✅ Arquivo limpo e salvo: sarampo_protocolo_2.txt
# ✅ Arquivo limpo e salvo: sarampo_protocolo_3.txt
# ✅ Arquivo limpo e salvo: sífilis_manual_1.txt
# ✅ Arquivo limpo e salvo: sífilis_protocolo_1.txt
# ✅ Arquivo limpo e salvo: síndrome_da_rubéola_congênita_(src)_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: síndrome_da_rubéola_congênita_(src)_nota_técnica_2.txt
# ✅ Arquivo limpo e salvo: síndrome_da_rubéola_congênita_(src)_protocolo_1.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_1.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_10.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_11.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_13.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_14.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_15.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_2.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_3.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_4.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_5.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_6.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_7.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_8.txt
# ✅ Arquivo limpo e salvo: tuberculose_protocolo_9.txt
# ✅ Arquivo limpo e salvo: tétano_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: varicela_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: vírus_sincicial_respiratório_(vsr)_guia_1.txt
# ✅ Arquivo limpo e salvo: zika_nota_técnica_1.txt
# ✅ Arquivo limpo e salvo: zika_protocolo_1.txt
# ✅ Arquivo limpo e salvo: zika_protocolo_2.txt
# ✅ Arquivo limpo e salvo: zika_protocolo_3.txt
# ✅ Arquivo limpo e salvo: zoonoses_manual_1.txt
# 🏁 Limpeza avançada com sumário, ficha institucional e cabeçalho finalizada.

# %%
# === CONFIGURAÇÕES ===
# Pasta onde os arquivos limpos estão armazenados
PASTA_LIMPOS = r"C:\Users\isisi\Documents\IAVS_PROJETO\textos_limpos" # Pasta de destino para os arquivos limpos
# Caminho do log de saída
LOG_SAIDA = r"C:\Users\isisi\Documents\IAVS_PROJETO\log_qualidade_limpos.csv" # Garante que a pasta de destino existe

dados = [] # Cria uma lista para armazenar os dados dos arquivos

for arquivo in os.listdir(PASTA_LIMPOS):#para cada arquivo na pasta de arquivos limpos
    # Verifica se o arquivo é um .txt
    if arquivo.endswith(".txt"):# se o arquivo termina com .txt
        # Define o caminho completo do arquivo
        caminho = os.path.join(PASTA_LIMPOS, arquivo)#concatena o caminho da pasta com o nome do arquivo

        # Lê o conteúdo do arquivo
        with open(caminho, "r", encoding="utf-8", errors="ignore") as f:# abre o arquivo para leitura
            # Lê o conteúdo do arquivo
            conteudo = f.read()

        n_linhas = len(conteudo.strip().splitlines())# conta o número de linhas no conteúdo
        # Conta o número de palavras e o tamanho total do conteúdo
        # Usa split() para contar palavras, que separa por espaços em branco
        # e len() para contar o número total de caracteres
        n_palavras = len(conteudo.split())
        tamanho = len(conteudo)

        status = "✅ OK"
        if tamanho < 500 or n_linhas < 5:
            status = "⚠️ Suspeito (vazio ou ruidoso)"# se o tamanho do conteúdo for menor que 500 caracteres ou o número de linhas for menor que 5, marca como suspeito

        # Adiciona os dados do arquivo à lista

        dados.append({
            "Arquivo": arquivo,
            "Linhas": n_linhas,
            "Palavras": n_palavras,
            "Caracteres": tamanho,
            "Status": status
        })

# Salva log como CSV
df = pd.DataFrame(dados)
df.to_csv(LOG_SAIDA, index=False, encoding="utf-8")

print(f"📄 Log de qualidade salvo em: {LOG_SAIDA}")
# Out:
# 📄 Log de qualidade salvo em: C:\Users\isisi\Documents\IAVS_PROJETO\log_qualidade_limpos.csv

# %% [markdown]
# ## Etapa 6 – Verificação dos Arquivos Limpos
# Esta etapa realiza uma verificação simples e rápida para conferir se os arquivos .txt limpos foram gerados corretamente e estão disponíveis na pasta de destino (textos_limpos).
#
# **Objetivos:**
# - Listar todos os arquivos presentes na pasta textos_limpos;
#
# - Garantir visualmente que o processo de limpeza foi concluído com sucesso para cada documento convertido.
#
# *Essa etapa funciona como um checkpoint antes de seguir para a organização final por doença e tema. Ela ajuda a identificar rapidamente eventuais falhas ou ausências de arquivos.*

# %%
# Exibe no terminal os arquivos que foram salvos após a limpeza
print("Arquivos encontrados em PASTA_LIMPOS:")

# Lista o conteúdo da pasta de textos limpos
print(os.listdir(PASTA_LIMPOS))
# Out:
# Arquivos encontrados em PASTA_LIMPOS:
# ['adenovírus_guia_1.txt', 'arboviroses_nota_técnica_1.txt', 'cancro_mole_protocolo_1.txt', 'chikungunya_nota_técnica_1.txt', 'chikungunya_protocolo_1.txt', 'chikungunya_protocolo_2.txt', 'chikungunya_protocolo_3.txt', 'clamídia_protocolo_1.txt', 'coinfecção_com_hepatite_b_nota_técnica_1.txt', 'coqueluche_nota_técnica_1.txt', 'coqueluche_nota_técnica_2.txt', 'coqueluche_nota_técnica_3.txt', 'covid-19_guia_1.txt', 'covid-19_nota_técnica_1.txt', 'cólera_nota_técnica_1.txt', 'dengue_nota_técnica_1.txt', 'dengue_protocolo_1.txt', 'dengue_protocolo_2.txt', 'dengue_protocolo_3.txt', 'dengue_protocolo_4.txt', 'difteria_nota_técnica_1.txt', 'entre_outras_doenças_imunopreveníveis_nota_técnica_1.txt', 'entre_outras_protocolo_1.txt', 'entre_outras_protocolo_2.txt', 'febre_amarela_nota_técnica_1.txt', 'febre_amarela_protocolo_1.txt', 'febre_amarela_protocolo_2.txt', 'febre_amarela_protocolo_3.txt', 'febre_do_nilo_ocidental_nota_técnica_1.txt', 'gonorreia_protocolo_1.txt', 'hanseníase_diretriz_nacional_1.txt', 'hanseníase_nota_técnica_1.txt', 'hanseníase_nota_técnica_2.txt', 'hanseníase_protocolo_1.txt', 'hanseníase_protocolo_2.txt', 'hanseníase_protocolo_3.txt', 'hantavirose_manual_1.txt', 'hantavirose_manual_2.txt', 'hepatites_nota_técnica_1.txt', 'hepatites_protocolo_1.txt', 'hepatite_a_nota_técnica_1.txt', 'hepatite_a_nota_técnica_2.txt', 'hepatite_a_protocolo_1.txt', 'hepatite_b_e_c_(ist)_protocolo_1.txt', 'hepatite_b_protocolo_1.txt', 'hepatite_c_protocolo_1.txt', 'hepatite_d_(delta)_nota_técnica_1.txt', 'hepatite_d_protocolo_1.txt', 'hepatite_e_protocolo_1.txt', 'herpes_genital_protocolo_1.txt', 'hiv_nota_técnica_1.txt', 'hpv_nota_técnica_1.txt', 'hpv_protocolo_1.txt', 'influenza_guia_1.txt', 'influenza_guia_2.txt', 'leishmaniose_manual_1.txt', 'leptospirose_manual_1.txt', 'leptospirose_nota_técnica_1.txt', 'leptospirose_nota_técnica_2.txt', 'leptospirose_nota_técnica_3.txt', 'leptospirose_protocolo_1.txt', 'linfogranuloma_venéreo_protocolo_1.txt', 'log_diagnostico.csv', 'm._abscessus_protocolo_1.txt', 'm._kansasii_protocolo_1.txt', 'malária_guia_1.txt', 'malária_manual_1.txt', 'meningite_nota_técnica_1.txt', 'metapneumovírus_guia_1.txt', 'micobactérias_não_tuberculosas_(mnt)_–_m._avium_protocolo_1.txt', 'outras_zoonoses_transmitidas_por_roedores_manual_1.txt', 'parainfluenza_guia_1.txt', 'peste_manual_1.txt', 'peste_manual_2.txt', 'poliomielite_diretriz_nacional_1.txt', 'poliomielite_nota_técnica_2.txt', 'poliomielite_nota_técnica_3.txt', 'raiva_humana_protocolo_1.txt', 'raiva_humana_protocolo_2.txt', 'rinovírus_e_outros_respiratórios_guia_1.txt', 'rubéola_nota_técnica_1.txt', 'rubéola_nota_técnica_2.txt', 'rubéola_nota_técnica_3.txt', 'rubéola_protocolo_1.txt', 'rubéola_protocolo_2.txt', 'sarampo_nota_técnica_1.txt', 'sarampo_nota_técnica_2.txt', 'sarampo_protocolo_1.txt', 'sarampo_protocolo_2.txt', 'sarampo_protocolo_3.txt', 'sífilis_manual_1.txt', 'sífilis_protocolo_1.txt', 'síndrome_da_rubéola_congênita_(src)_nota_técnica_1.txt', 'síndrome_da_rubéola_congênita_(src)_nota_técnica_2.txt', 'síndrome_da_rubéola_congênita_(src)_protocolo_1.txt', 'tuberculose_protocolo_1.txt', 'tuberculose_protocolo_10.txt', 'tuberculose_protocolo_11.txt', 'tuberculose_protocolo_13.txt', 'tuberculose_protocolo_14.txt', 'tuberculose_protocolo_15.txt', 'tuberculose_protocolo_2.txt', 'tuberculose_protocolo_3.txt', 'tuberculose_protocolo_4.txt', 'tuberculose_protocolo_5.txt', 'tuberculose_protocolo_6.txt', 'tuberculose_protocolo_7.txt', 'tuberculose_protocolo_8.txt', 'tuberculose_protocolo_9.txt', 'tétano_nota_técnica_1.txt', 'varicela_nota_técnica_1.txt', 'vírus_sincicial_respiratório_(vsr)_guia_1.txt', 'zika_nota_técnica_1.txt', 'zika_protocolo_1.txt', 'zika_protocolo_2.txt', 'zika_protocolo_3.txt', 'zoonoses_manual_1.txt']
